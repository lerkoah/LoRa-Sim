# %%
import simpy
import random
import numpy as np
import math
import sys
import matplotlib.pyplot as plt
# %matplotlib inline
import os

# random.seed(123)

# %%
# check for collisions at base station
# Note: called before a packet (or rather node) is inserted into the list
def checkcollision(packet):
    col = 0 # flag needed since there might be several collisions for packet
    processing = 0
    for i in range(0,len(packetsAtBS)):
        if packetsAtBS[i].packet.processed == 1:
            processing = processing + 1
    if (processing > maxBSReceives):
        print "too long:", len(packetsAtBS)
        packet.processed = 0
    else:
        packet.processed = 1

    if packetsAtBS:
        print "CHECK node {} (sf:{} bw:{} freq:{:.6e}) others: {}".format(
             packet.nodeid, packet.sf, packet.bw, packet.freq,
             len(packetsAtBS))
        for other in packetsAtBS:
            if other.nodeid != packet.nodeid:
                print ">> node {} (sf:{} bw:{} freq:{:.6e})".format(
                   other.nodeid, other.packet.sf, other.packet.bw, other.packet.freq)
               # simple collision
                if frequencyCollision(packet, other.packet) and sfCollision(packet, other.packet):
                    if full_collision:
                        if timingCollision(packet, other.packet):
                           # check who collides in the power domain
                            c = powerCollision(packet, other.packet)
                           # mark all the collided packets
                           # either this one, the other one, or both
                            for p in c:
                                p.collided = 1
                                if p == packet:
                                    col = 1
                        else:
                           # no timing collision, all fine
                           pass
                    else:
                        packet.collided = 1
                        other.packet.collided = 1  # other also got lost, if it wasn't lost already
                        col = 1
        return col
    return 0

def transmit(env,node):
    while True:
        yield env.timeout(random.expovariate(1.0/float(node.period)))
#         yield env.timeout(np.random.exponential(1.0/float(node.period)))

        # time sending and receiving
        # packet arrives -> add to base station

        node.sent = node.sent + 1
        node.transmitionTime = node.transmitionTime + node.packet.rectime
        if (node in packetsAtBS):
            print "ERROR: packet already in"
        else:
            sensitivity = sensi[node.packet.sf - 7, [125,250,500].index(node.packet.bw) + 1]
            if node.packet.rssi - np.abs(np.random.rand(0,16))< sensitivity:
                print "node {}: packet will be lost".format(node.nodeid)
                node.packet.lost = True
            else:
                node.packet.lost = False
                # adding packet if no collision
                if (checkcollision(node.packet)==1):
                    node.packet.collided = 1
                else:
                    node.packet.collided = 0
                packetsAtBS.append(node)
                node.packet.addTime = env.now

        yield env.timeout(node.packet.rectime)

        if node.packet.lost:
            global nrLost
            nrLost += 1
        if node.packet.collided == 1:
            global nrCollisions
            nrCollisions = nrCollisions +1
        if node.packet.collided == 0 and not node.packet.lost:
            global nrReceived
            nrReceived = nrReceived + 1
        if node.packet.processed == 1:
            global nrProcessed
            nrProcessed = nrProcessed + 1

        # complete packet has been received by base station
        # can remove it
        if (node in packetsAtBS):
            packetsAtBS.remove(node)
            # reset the packet
        node.packet.collided = 0
        node.packet.processed = 0
        node.packet.lost = False
        
def timingCollision(p1, p2):
    # assuming p1 is the freshly arrived packet and this is the last check
    # we've already determined that p1 is a weak packet, so the only
    # way we can win is by being late enough (only the first n - 5 preamble symbols overlap)

    # assuming 8 preamble symbols
    Npream = 8

    # we can lose at most (Npream - 5) * Tsym of our preamble
    Tpreamb = 2**p1.sf/(1.0*p1.bw) * (Npream - 5)

    # check whether p2 ends in p1's critical section
    p2_end = p2.addTime + p2.rectime
    p1_cs = env.now + Tpreamb
    print "collision timing node {} ({},{},{}) node {} ({},{})".format(
        p1.nodeid, env.now - env.now, p1_cs - env.now, p1.rectime,
        p2.nodeid, p2.addTime - env.now, p2_end - env.now
    )
    if p1_cs < p2_end:
        # p1 collided with p2 and lost
        print "not late enough"
        return True
    print "saved by the preamble"
    return False

# %%
# turn on/off graphics
graphics = 0

# do the full collision check
full_collision = False

# experiments:
# 0: packet with longest airtime, aloha-style experiment
# 0: one with 3 frequencies, 1 with 1 frequency
# 2: with shortest packets, still aloha-style
# 3: with shortest possible packets depending on distance



# this is an array with measured values for sensitivity
# see paper, Table 3
sf7 = np.array([7,-126.5,-124.25,-120.75])
sf8 = np.array([8,-127.25,-126.75,-124.0])
sf9 = np.array([9,-131.25,-128.25,-127.5])
sf10 = np.array([10,-132.75,-130.25,-128.75])
sf11 = np.array([11,-134.5,-132.75,-128.75])
sf12 = np.array([12,-133.25,-132.25,-132.25])

# %%
from loraDir import frequencyCollision, sfCollision, powerCollision, airtime#, timingCollision

# %%
class myNode():
    def __init__(self, nodeid, bs, period, packetlen, x, y):
        self.nodeid = nodeid
        self.period = period
        self.bs = bs
        assert np.sqrt((x-bsx)**2+(y-bsy)**2) < maxDist, "Max distance error"
        self.x = x
        self.y = y
        
        self.dist = np.sqrt((self.x-bsx)*(self.x-bsx)+(self.y-bsy)*(self.y-bsy))
        print('node %d' %nodeid, "x", self.x, "y", self.y, "dist: ", self.dist)
        
#         self.packet = myPacket(self.nodeid, packetlen, self.dist)
        self.packet = None
        self.setPacket(packetlen)
        self.sent = 0

        # graphics for node
        global graphics
        if (graphics == 1):
            global ax
            ax.add_artist(plt.Circle((self.x, self.y), 2, fill=True, color='blue'))
        
        self.transmitionTime = 0
        
    def setPacket(self, packetlen):
        if self.packet != None:
            assert self.packet == None, "ERROR: Existing Packet association\nfrequency: {}; symTime: {}\nbw: {}; sf: {}; cr: {}; rssi: {}".format(self.packet.freq, self.packet.symTime,
                                                                                                             self.packet.bw, self.packet.sf, self.packet.cr, self.packet.rssi)
        self.packet = myPacket(self.nodeid, packetlen, self.dist)

# %%
#
# this function creates a packet (associated with a node)
# it also sets all parameters, currently random
#
class myPacket():
    def __init__(self, nodeid, plen, distance):
        global experiment
        global Ptx
        global gamma
        global d0
        global var
        global Lpld0
        global GL

        self.nodeid = nodeid
        self.txpow = Ptx

        # randomize configuration values
        self.sf = random.randint(6,12)
        self.cr = random.randint(1,4)
        self.bw = random.choice([125, 250, 500])

        # for certain experiments override these
        if experiment==1 or experiment == 0:
            self.sf = 12
            self.cr = 4
            self.bw = 125

        # for certain experiments override these
        if experiment==2:
            self.sf = 6
            self.cr = 1
            self.bw = 500
        # lorawan
        if experiment == 4:
            self.sf = 12
            self.cr = 1
            self.bw = 125


        # for experiment 3 find the best setting
        # OBS, some hardcoded values
        Prx = self.txpow  ## zero path loss by default

        # log-shadow
        Lpl = Lpld0 + 10*gamma*math.log10(distance/d0)
        print "Lpl:", Lpl
        Prx = self.txpow - GL - Lpl

        if (experiment == 3) or (experiment == 5):
            minairtime = 9999
            minsf = 0
            minbw = 0

            print "Prx:", Prx

            for i in range(0,6):
                for j in range(1,4):
                    if (sensi[i,j] < Prx):
                        self.sf = int(sensi[i,0])
                        if j==1:
                            self.bw = 125
                        elif j==2:
                            self.bw = 250
                        else:
                            self.bw=500
                        at = airtime(self.sf, 1, plen, self.bw)
                        if at < minairtime:
                            minairtime = at
                            minsf = self.sf
                            minbw = self.bw
                            minsensi = sensi[i, j]
            if (minairtime == 9999):
                print "does not reach base station"
                exit(-1)
            print "best sf:", minsf, " best bw: ", minbw, "best airtime:", minairtime
            self.rectime = minairtime
            self.sf = minsf
            self.bw = minbw
            self.cr = 1

            if experiment == 5:
                # reduce the txpower if there's room left
                self.txpow = max(2, self.txpow - math.floor(Prx - minsensi))
                Prx = self.txpow - GL - Lpl
                print 'minsesi {} best txpow {}'.format(minsensi, self.txpow)

        # transmission range, needs update XXX
        self.transRange = 150
        self.pl = plen
        self.symTime = (2.0**self.sf)/self.bw
        self.arriveTime = 0
        self.rssi = Prx
        # frequencies: lower bound + number of 61 Hz steps
        self.freq = 860000000 + self.bw*random.randint(0,64)

#         # for certain experiments override these and
#         # choose some random frequences
#         if experiment == 1:
#             self.freq = random.choice([860000000, 864000000, 868000000])
#         else:
#             self.freq = 860000000

        print "frequency" ,self.freq, "symTime ", self.symTime
        print "bw", self.bw, "sf", self.sf, "cr", self.cr, "rssi", self.rssi
        self.rectime = airtime(self.sf,self.cr,self.pl,self.bw)
        print "rectime node ", self.nodeid, "  ", self.rectime
        # denote if packet is collided
        self.collided = 0
        self.processed = 0

# %%
nrNodes = 70
avgSendTime = 15*60*1000
experiment = 4
simtime = 7*24*60*60*1000

full_collision = False

print "Nodes:", nrNodes
print "AvgSendTime (exp. distributed):",avgSendTime
print "Experiment: ", experiment
print "Simtime: ", simtime
print "Full Collision: ", full_collision
# Out:
# Nodes: 70
# AvgSendTime (exp. distributed): 900000
# Experiment:  4
# Simtime:  604800000
# Full Collision:  False

# %%
# global stuff
#Rnd = random.seed(12345)
nodes = []
packetsAtBS = []
env = simpy.Environment()

# maximum number of packets the BS can receive at the same time
maxBSReceives = 8


# max distance: 300m in city, 3000 m outside (5 km Utz experiment)
# also more unit-disc like according to Utz
bsId = 1
nrCollisions = 0
nrReceived = 0
nrProcessed = 0
nrLost = 0

Ptx = 14
gamma = 2.08
d0 = 40.0
var = 0           # variance ignored for now
Lpld0 = 127.41
GL = 0

sensi = np.array([sf7,sf8,sf9,sf10,sf11,sf12])
if experiment in [0,1,4]:
    minsensi = sensi[5,2]  # 5th row is SF12, 2nd column is BW125
elif experiment == 2:
    minsensi = -112.0   # no experiments, so value from datasheet
elif experiment in [3,5]:
    minsensi = np.amin(sensi) ## Experiment 3 can use any setting, so take minimum
Lpl = Ptx - minsensi
print "amin", minsensi, "Lpl", Lpl
maxDist = d0*(math.e**((Lpl-Lpld0)/(10.0*gamma)))
print "maxDist:", maxDist

# base station placement
bsx = maxDist+10
bsy = maxDist+10
xmax = bsx + maxDist + 20
ymax = bsy + maxDist + 20
# Out:
# amin -132.25 Lpl 146.25
# maxDist: 98.9533656272

# %%
# prepare graphics and add sink
if (graphics == 1):
    plt.ion()
    plt.figure()
    ax = plt.gcf().gca()
    # XXX should be base station position
    ax.add_artist(plt.Circle((bsx, bsy), 3, fill=True, color='green'))
    ax.add_artist(plt.Circle((bsx, bsy), maxDist, fill=False, color='green'))

for i in range(0,nrNodes):
    # this is very complex prodecure for placing nodes
    # and ensure minimum distance between each pair of nodes
    found = 0
    rounds = 0
    while (found == 0 and rounds < 100):
        a = random.random()
        b = random.random()
        if b<a:
            a,b = b,a
        posx = b*maxDist*np.cos(2*math.pi*a/b)+bsx
        posy = b*maxDist*np.sin(2*math.pi*a/b)+bsy
        if len(nodes) > 0:
            for index, n in enumerate(nodes):
                dist = np.sqrt(((abs(n.x-posx))**2)+((abs(n.y-posy))**2))
                if dist >= 10:
                    found = 1
                else:
                    rounds = rounds + 1
                    if rounds == 100:
                        print "could not place new node, giving up"
                        exit(-1)
        else:
            print "first node"
            found = 1

    # myNode takes period (in ms), base station id packetlen (in Bytes)
    # 1000000 = 16 min
    node = myNode(i,bsId, avgSendTime,20, posx, posy)
    nodes.append(node)
    env.process(transmit(env,node))
# Out:
# first node
# ('node 0', 'x', 156.86330186341399, 'y', 176.87439780012096, 'dist: ', 83.118160480056687)
# Lpl: 134.016827381
# frequency 860002625 symTime  32.768
# bw 125 sf 12 cr 1 rssi -120.016827381
# sf 12  cr 1 pl 20 bw 125
# rectime node  0    1318.912
# ('node 1', 'x', 128.37152803972307, 'y', 137.28698544171831, 'dist: ', 34.349076308845525)
# Lpl: 126.034185487
# frequency 860005750 symTime  32.768
# bw 125 sf 12 cr 1 rssi -112.034185487
# sf 12  cr 1 pl 20 bw 125
# rectime node  1    1318.912
# ('node 2', 'x', 74.105208030160327, 'y', 90.286601534092995, 'dist: ', 39.532798656532627)
# Lpl: 127.30386944
# frequency 860001000 symTime  32.768
# bw 125 sf 12 cr 1 rssi -113.30386944
# sf 12  cr 1 pl 20 bw 125
# rectime node  2    1318.912
# ('node 3', 'x', 156.97915181643782, 'y', 47.451831405662098, 'dist: ', 78.03149909298115)
# Lpl: 133.446367149
# frequency 860004500 symTime  32.768
# bw 125 sf 12 cr 1 rssi -119.446367149
# sf 12  cr 1 pl 20 bw 125
# rectime node  3    1318.912
# ('node 4', 'x', 158.15478014367173, 'y', 91.134536452174473, 'dist: ', 52.328671525170307)
# Lpl: 129.836938136
# frequency 860005250 symTime  32.768
# bw 125 sf 12 cr 1 rssi -115.836938136
# sf 12  cr 1 pl 20 bw 125
# rectime node  4    1318.912
# ('node 5', 'x', 175.45629632091715, 'y', 53.509726752909408, 'dist: ', 86.583121233157527)
# Lpl: 134.385763523
# frequency 860001500 symTime  32.768
# bw 125 sf 12 cr 1 rssi -120.385763523
# sf 12  cr 1 pl 20 bw 125
# rectime node  5    1318.912
# ('node 6', 'x', 51.754564497564552, 'y', 61.462205691890595, 'dist: ', 74.34455677904657)
# Lpl: 133.009135055
# frequency 860005875 symTime  32.768
# bw 125 sf 12 cr 1 rssi -119.009135055
# sf 12  cr 1 pl 20 bw 125
# rectime node  6    1318.912
# ('node 7', 'x', 168.05144418583703, 'y', 132.93084556889221, 'dist: ', 63.776974165240759)
# Lpl: 131.624161524
# frequency 860006250 symTime  32.768
# bw 125 sf 12 cr 1 rssi -117.624161524
# sf 12  cr 1 pl 20 bw 125
# rectime node  7    1318.912
# ('node 8', 'x', 114.17281029442684, 'y', 153.94978592373684, 'dist: ', 45.298128461723906)
# Lpl: 128.533621569
# frequency 860001750 symTime  32.768
# bw 125 sf 12 cr 1 rssi -114.533621569
# sf 12  cr 1 pl 20 bw 125
# rectime node  8    1318.912
# ('node 9', 'x', 41.846037041920582, 'y', 46.003579718976944, 'dist: ', 92.011244398437213)
# Lpl: 134.93504299
# frequency 860002875 symTime  32.768
# bw 125 sf 12 cr 1 rssi -120.93504299
# sf 12  cr 1 pl 20 bw 125
# rectime node  9    1318.912
# ('node 10', 'x', 87.556772435409712, 'y', 147.41706552653361, 'dist: ', 44.014434111553506)
# Lpl: 128.27393073
# frequency 860007250 symTime  32.768
# bw 125 sf 12 cr 1 rssi -114.27393073
# sf 12  cr 1 pl 20 bw 125
# rectime node  10    1318.912
# ('node 11', 'x', 75.595623524651785, 'y', 126.42154767610535, 'dist: ', 37.654698807379241)
# Lpl: 126.864191085
# frequency 860007250 symTime  32.768
# bw 125 sf 12 cr 1 rssi -112.864191085
# sf 12  cr 1 pl 20 bw 125
# rectime node  11    1318.912
# ('node 12', 'x', 171.03929185351842, 'y', 144.62942335646829, 'dist: ', 71.606168243232062)
# Lpl: 132.67012122
# frequency 860006125 symTime  32.768
# bw 125 sf 12 cr 1 rssi -118.67012122
# sf 12  cr 1 pl 20 bw 125
# rectime node  12    1318.912
# ('node 13', 'x', 75.020314075670768, 'y', 153.98972784531045, 'dist: ', 56.389058419512082)
# Lpl: 130.512004911
# frequency 860005375 symTime  32.768
# bw 125 sf 12 cr 1 rssi -116.512004911
# sf 12  cr 1 pl 20 bw 125
# rectime node  13    1318.912
# ('node 14', 'x', 183.69062976854684, 'y', 89.140725118859791, 'dist: ', 77.318816437164841)
# Lpl: 133.363484287
# frequency 860004750 symTime  32.768
# bw 125 sf 12 cr 1 rssi -119.363484287
# sf 12  cr 1 pl 20 bw 125
# rectime node  14    1318.912
# ('node 15', 'x', 158.34752224574513, 'y', 115.67099196639622, 'dist: ', 49.848863695055272)
# Lpl: 129.398381651
# frequency 860000250 symTime  32.768
# bw 125 sf 12 cr 1 rssi -115.398381651
# sf 12  cr 1 pl 20 bw 125
# rectime node  15    1318.912
# ('node 16', 'x', 38.371208727101234, 'y', 41.390080769409792, 'dist: ', 97.70690013223502)
# Lpl: 135.477597068
# frequency 860008000 symTime  32.768
# bw 125 sf 12 cr 1 rssi -121.477597068
# sf 12  cr 1 pl 20 bw 125
# rectime node  16    1318.912
# ('node 17', 'x', 97.576657122447784, 'y', 132.34700781566272, 'dist: ', 26.013304120073773)
# Lpl: 123.523218961
# frequency 860002500 symTime  32.768
# bw 125 sf 12 cr 1 rssi -109.523218961
# sf 12  cr 1 pl 20 bw 125
# rectime node  17    1318.912
# ('node 18', 'x', 106.78658283723452, 'y', 201.34591401757149, 'dist: ', 92.41795250773761)
# Lpl: 134.974884107
# frequency 860003375 symTime  32.768
# bw 125 sf 12 cr 1 rssi -120.974884107
# sf 12  cr 1 pl 20 bw 125
# rectime node  18    1318.912
# ('node 19', 'x', 44.184027862402132, 'y', 138.07998323896803, 'dist: ', 71.017089267260459)
# Lpl: 132.595499838
# frequency 860000875 symTime  32.768
# bw 125 sf 12 cr 1 rssi -118.595499838
# sf 12  cr 1 pl 20 bw 125
# rectime node  19    1318.912
# ('node 20', 'x', 99.958627381642174, 'y', 52.298229726489083, 'dist: ', 57.364708140430132)
# Lpl: 130.666963778
# frequency 860005375 symTime  32.768
# bw 125 sf 12 cr 1 rssi -116.666963778
# sf 12  cr 1 pl 20 bw 125
# rectime node  20    1318.912
# ('node 21', 'x', 128.44732021560603, 'y', 143.30135791711626, 'dist: ', 39.494288699011221)
# Lpl: 127.295065547
# frequency 860005625 symTime  32.768
# bw 125 sf 12 cr 1 rssi -113.295065547
# sf 12  cr 1 pl 20 bw 125
# rectime node  21    1318.912
# ('node 22', 'x', 164.69617475288527, 'y', 118.15142924970287, 'dist: ', 56.496594088702494)
# Lpl: 130.529215335
# frequency 860002375 symTime  32.768
# bw 125 sf 12 cr 1 rssi -116.529215335
# sf 12  cr 1 pl 20 bw 125
# rectime node  22    1318.912
# ('node 23', 'x', 178.59865126226936, 'y', 117.32254843398495, 'dist: ', 70.146340118645426)
# Lpl: 132.484056527
# frequency 860004125 symTime  32.768
# bw 125 sf 12 cr 1 rssi -118.484056527
# sf 12  cr 1 pl 20 bw 125
# rectime node  23    1318.912
# ('node 24', 'x', 58.524790941226719, 'y', 153.04209844262348, 'dist: ', 66.984009331547455)
# Lpl: 132.067351865
# frequency 860007750 symTime  32.768
# bw 125 sf 12 cr 1 rssi -118.067351865
# sf 12  cr 1 pl 20 bw 125
# rectime node  24    1318.912
# ('node 25', 'x', 73.023434872318447, 'y', 32.464814173003859, 'dist: ', 84.507150156754534)
# Lpl: 134.166536069
# frequency 860004125 symTime  32.768
# bw 125 sf 12 cr 1 rssi -120.166536069
# sf 12  cr 1 pl 20 bw 125
# rectime node  25    1318.912
# ('node 26', 'x', 166.44576154038253, 'y', 104.56333461764915, 'dist: ', 57.659760319488299)
# Lpl: 130.713307102
# frequency 860002875 symTime  32.768
# bw 125 sf 12 cr 1 rssi -116.713307102
# sf 12  cr 1 pl 20 bw 125
# rectime node  26    1318.912
# ('node 27', 'x', 150.5439709123583, 'y', 97.694588244726134, 'dist: ', 43.087567999746035)
# Lpl: 128.081673402
# frequency 860006375 symTime  32.768
# bw 125 sf 12 cr 1 rssi -114.081673402
# sf 12  cr 1 pl 20 bw 125
# rectime node  27    1318.912
# ('node 28', 'x', 52.87141901360264, 'y', 34.936917265306249, 'dist: ', 92.863444713646246)
# Lpl: 135.018323802
# frequency 860004375 symTime  32.768
# bw 125 sf 12 cr 1 rssi -121.018323802
# sf 12  cr 1 pl 20 bw 125
# rectime node  28    1318.912
# ('node 29', 'x', 115.17433614209931, 'y', 76.917972197731217, 'dist: ', 32.633830702648488)
# Lpl: 125.571447749
# frequency 860002125 symTime  32.768
# bw 125 sf 12 cr 1 rssi -111.571447749
# sf 12  cr 1 pl 20 bw 125
# rectime node  29    1318.912
# ('node 30', 'x', 152.07324367360215, 'y', 99.552728104654875, 'dist: ', 44.132707469240302)
# Lpl: 128.298172068
# frequency 860000125 symTime  32.768
# bw 125 sf 12 cr 1 rssi -114.298172068
# sf 12  cr 1 pl 20 bw 125
# rectime node  30    1318.912
# ('node 31', 'x', 100.39581106596748, 'y', 27.544319980023218, 'dist: ', 81.857586412354948)
# Lpl: 133.878778033
# frequency 860002250 symTime  32.768
# bw 125 sf 12 cr 1 rssi -119.878778033
# sf 12  cr 1 pl 20 bw 125
# rectime node  31    1318.912
# ('node 32', 'x', 46.289727195773686, 'y', 74.362036085176783, 'dist: ', 71.577172764459192)
# Lpl: 132.666462615
# frequency 860003125 symTime  32.768
# bw 125 sf 12 cr 1 rssi -118.666462615
# sf 12  cr 1 pl 20 bw 125
# rectime node  32    1318.912
# ('node 33', 'x', 174.12535246821187, 'y', 139.25644263215409, 'dist: ', 71.872556269896307)
# Lpl: 132.703664485
# frequency 860001000 symTime  32.768
# bw 125 sf 12 cr 1 rssi -118.703664485
# sf 12  cr 1 pl 20 bw 125
# rectime node  33    1318.912
# ('node 34', 'x', 102.21406019378718, 'y', 197.79019800414966, 'dist: ', 89.09209294034919)
# Lpl: 134.643806738
# frequency 860003125 symTime  32.768
# bw 125 sf 12 cr 1 rssi -120.643806738
# sf 12  cr 1 pl 20 bw 125
# rectime node  34    1318.912
# ('node 35', 'x', 33.13785902713245, 'y', 170.62491371298708, 'dist: ', 97.731115231143235)
# Lpl: 135.479835557
# frequency 860002500 symTime  32.768
# bw 125 sf 12 cr 1 rssi -121.479835557
# sf 12  cr 1 pl 20 bw 125
# rectime node  35    1318.912
# ('node 36', 'x', 95.388637520104396, 'y', 64.615864665291014, 'dist: ', 46.366106588423065)
# Lpl: 128.744125269
# frequency 860007125 symTime  32.768
# bw 125 sf 12 cr 1 rssi -114.744125269
# sf 12  cr 1 pl 20 bw 125
# rectime node  36    1318.912
# ('node 37', 'x', 85.837442829413177, 'y', 30.574795655081715, 'dist: ', 81.716253693322926)
# Lpl: 133.8631679
# frequency 860000625 symTime  32.768
# bw 125 sf 12 cr 1 rssi -119.8631679
# sf 12  cr 1 pl 20 bw 125
# rectime node  37    1318.912
# ('node 38', 'x', 155.11344014487182, 'y', 118.10183103463166, 'dist: ', 47.057910055439059)
# Lpl: 128.877910995
# frequency 860001750 symTime  32.768
# bw 125 sf 12 cr 1 rssi -114.877910995
# sf 12  cr 1 pl 20 bw 125
# rectime node  38    1318.912
# ('node 39', 'x', 192.29850964175077, 'y', 95.153351313416337, 'dist: ', 84.479899537488095)
# Lpl: 134.163622666
# frequency 860004000 symTime  32.768
# bw 125 sf 12 cr 1 rssi -120.163622666
# sf 12  cr 1 pl 20 bw 125
# rectime node  39    1318.912
# ('node 40', 'x', 117.21476428821855, 'y', 143.72940269002743, 'dist: ', 35.743859075786951)
# Lpl: 126.393742115
# frequency 860004875 symTime  32.768
# bw 125 sf 12 cr 1 rssi -112.393742115
# sf 12  cr 1 pl 20 bw 125
# rectime node  40    1318.912
# ('node 41', 'x', 51.021715842765154, 'y', 161.08637058725802, 'dist: ', 77.935397945427042)
# Lpl: 133.435235132
# frequency 860008000 symTime  32.768
# bw 125 sf 12 cr 1 rssi -119.435235132
# sf 12  cr 1 pl 20 bw 125
# rectime node  41    1318.912
# ('node 42', 'x', 207.22699650709819, 'y', 112.39881270082962, 'dist: ', 98.334010555105621)
# Lpl: 135.535390227
# frequency 860005125 symTime  32.768
# bw 125 sf 12 cr 1 rssi -121.535390227
# sf 12  cr 1 pl 20 bw 125
# rectime node  42    1318.912
# ('node 43', 'x', 164.56654238087395, 'y', 147.06864257886784, 'dist: ', 67.42106322013916)
# Lpl: 132.126100598
# frequency 860007250 symTime  32.768
# bw 125 sf 12 cr 1 rssi -118.126100598
# sf 12  cr 1 pl 20 bw 125
# rectime node  43    1318.912
# ('node 44', 'x', 105.10045219507681, 'y', 29.024650924442369, 'dist: ', 80.021524454071638)
# Lpl: 133.67385405
# frequency 860007000 symTime  32.768
# bw 125 sf 12 cr 1 rssi -119.67385405
# sf 12  cr 1 pl 20 bw 125
# rectime node  44    1318.912
# ('node 45', 'x', 124.28032093473561, 'y', 190.25244823703378, 'dist: ', 82.731229848201423)
# Lpl: 133.974677373
# frequency 860007750 symTime  32.768
# bw 125 sf 12 cr 1 rssi -119.974677373
# sf 12  cr 1 pl 20 bw 125
# rectime node  45    1318.912
# ('node 46', 'x', 173.64879367523264, 'y', 141.25108367173817, 'dist: ', 72.309342419903146)
# Lpl: 132.758395952
# frequency 860001250 symTime  32.768
# bw 125 sf 12 cr 1 rssi -118.758395952
# sf 12  cr 1 pl 20 bw 125
# rectime node  46    1318.912
# ('node 47', 'x', 164.50493118852654, 'y', 65.044553953101456, 'dist: ', 70.809322683848293)
# Lpl: 132.569033337
# frequency 860002750 symTime  32.768
# bw 125 sf 12 cr 1 rssi -118.569033337
# sf 12  cr 1 pl 20 bw 125
# rectime node  47    1318.912
# ('node 48', 'x', 174.5404538576922, 'y', 67.615607832889992, 'dist: ', 77.527262056740028)
# Lpl: 133.387804673
# frequency 860003750 symTime  32.768
# bw 125 sf 12 cr 1 rssi -119.387804673
# sf 12  cr 1 pl 20 bw 125
# rectime node  48    1318.912
# ('node 49', 'x', 106.16245606709589, 'y', 10.850017789367016, 'dist: ', 98.143038638344279)
# Lpl: 135.517829784
# frequency 860003375 symTime  32.768
# bw 125 sf 12 cr 1 rssi -121.517829784
# sf 12  cr 1 pl 20 bw 125
# rectime node  49    1318.912
# ('node 50', 'x', 55.242852989532473, 'y', 45.663052818182798, 'dist: ', 83.008932430606137)
# Lpl: 134.004948613
# frequency 860003375 symTime  32.768
# bw 125 sf 12 cr 1 rssi -120.004948613
# sf 12  cr 1 pl 20 bw 125
# rectime node  50    1318.912
# ('node 51', 'x', 196.55432865738399, 'y', 138.88474150759728, 'dist: ', 92.57330061040615)
# Lpl: 134.990055746
# frequency 860005875 symTime  32.768
# bw 125 sf 12 cr 1 rssi -120.990055746
# sf 12  cr 1 pl 20 bw 125
# rectime node  51    1318.912
# ('node 52', 'x', 133.98940266678886, 'y', 130.28508751763823, 'dist: ', 32.891419997574232)
# Lpl: 125.642470746
# frequency 860004500 symTime  32.768
# bw 125 sf 12 cr 1 rssi -111.642470746
# sf 12  cr 1 pl 20 bw 125
# rectime node  52    1318.912
# ('node 53', 'x', 195.34794314730914, 'y', 151.82340861136151, 'dist: ', 96.446169495407489)
# Lpl: 135.360279841
# frequency 860002500 symTime  32.768
# bw 125 sf 12 cr 1 rssi -121.360279841
# sf 12  cr 1 pl 20 bw 125
# rectime node  53    1318.912
# ('node 54', 'x', 122.2439601241765, 'y', 41.114945697224456, 'dist: ', 69.12807765793093)
# Lpl: 132.351965365
# frequency 860001750 symTime  32.768
# bw 125 sf 12 cr 1 rssi -118.351965365
# sf 12  cr 1 pl 20 bw 125
# rectime node  54    1318.912
# ('node 55', 'x', 21.278502005523222, 'y', 134.56345298539705, 'dist: ', 91.338700919033059)
# Lpl: 134.868772654
# frequency 860001500 symTime  32.768
# bw 125 sf 12 cr 1 rssi -120.868772654
# sf 12  cr 1 pl 20 bw 125
# rectime node  55    1318.912
# ('node 56', 'x', 120.58984548928618, 'y', 136.6545853480597, 'dist: ', 30.04605194701163)
# Lpl: 124.825130387
# frequency 860003000 symTime  32.768
# bw 125 sf 12 cr 1 rssi -110.825130387
# sf 12  cr 1 pl 20 bw 125
# rectime node  56    1318.912
# ('node 57', 'x', 86.344766079360582, 'y', 147.85764574762243, 'dist: ', 44.996575260815277)
# Lpl: 128.473284957
# frequency 860002125 symTime  32.768
# bw 125 sf 12 cr 1 rssi -114.473284957
# sf 12  cr 1 pl 20 bw 125
# rectime node  57    1318.912
# ('node 58', 'x', 128.40548497705367, 'y', 84.338041317924535, 'dist: ', 31.373542006792352)
# Lpl: 125.21567407
# frequency 860002250 symTime  32.768
# bw 125 sf 12 cr 1 rssi -111.21567407
# sf 12  cr 1 pl 20 bw 125
# rectime node  58    1318.912
# ('node 59', 'x', 130.88586531989969, 'y', 129.11844641139683, 'dist: ', 29.793707822320219)
# Lpl: 124.748942913
# frequency 860000875 symTime  32.768
# bw 125 sf 12 cr 1 rssi -110.748942913
# sf 12  cr 1 pl 20 bw 125
# rectime node  59    1318.912
# ('node 60', 'x', 48.613931292768157, 'y', 115.35307525129399, 'dist: ', 60.677867621350003)
# Lpl: 131.174182631
# frequency 860006500 symTime  32.768
# bw 125 sf 12 cr 1 rssi -117.174182631
# sf 12  cr 1 pl 20 bw 125
# rectime node  60    1318.912
# ('node 61', 'x', 58.969734712150981, 'y', 170.3677577853704, 'dist: ', 79.183905710749912)
# Lpl: 133.578800102
# frequency 860002250 symTime  32.768
# bw 125 sf 12 cr 1 rssi -119.578800102
# sf 12  cr 1 pl 20 bw 125
# rectime node  61    1318.912
# ('node 62', 'x', 179.03962018868515, 'y', 137.00597008541104, 'dist: ', 75.491931326084398)
# Lpl: 133.147483333
# frequency 860006500 symTime  32.768
# bw 125 sf 12 cr 1 rssi -119.147483333
# sf 12  cr 1 pl 20 bw 125
# rectime node  62    1318.912
# ('node 63', 'x', 41.624895287404073, 'y', 173.80874317396507, 'dist: ', 93.48445279847509)
# Lpl: 135.078531498
# frequency 860007625 symTime  32.768
# bw 125 sf 12 cr 1 rssi -121.078531498
# sf 12  cr 1 pl 20 bw 125
# rectime node  63    1318.912
# ('node 64', 'x', 101.56360782647073, 'y', 118.73012121864305, 'dist: ', 12.255344558524548)
# Lpl: 116.72432312
# frequency 860004625 symTime  32.768
# bw 125 sf 12 cr 1 rssi -102.72432312
# sf 12  cr 1 pl 20 bw 125
# rectime node  64    1318.912
# ('node 65', 'x', 93.809325953657563, 'y', 171.56640952813081, 'dist: ', 64.418438386628338)
# Lpl: 131.714564186
# frequency 860002375 symTime  32.768
# bw 125 sf 12 cr 1 rssi -117.714564186
# sf 12  cr 1 pl 20 bw 125
# rectime node  65    1318.912
# ('node 66', 'x', 116.59984796687046, 'y', 190.59006210019317, 'dist: ', 81.994017484149182)
# Lpl: 133.893821237
# frequency 860000500 symTime  32.768
# bw 125 sf 12 cr 1 rssi -119.893821237
# sf 12  cr 1 pl 20 bw 125
# rectime node  66    1318.912
# ('node 67', 'x', 152.46915109522524, 'y', 81.006956588627588, 'dist: ', 51.71678028502722)
# Lpl: 129.73068695
# frequency 860005625 symTime  32.768
# bw 125 sf 12 cr 1 rssi -115.73068695
# sf 12  cr 1 pl 20 bw 125
# rectime node  67    1318.912
# ('node 68', 'x', 74.477915488185005, 'y', 59.09531293995952, 'dist: ', 60.616681532847913)
# Lpl: 131.16506905
# frequency 860004000 symTime  32.768
# bw 125 sf 12 cr 1 rssi -117.16506905
# sf 12  cr 1 pl 20 bw 125
# rectime node  68    1318.912
# ('node 69', 'x', 80.359212950496172, 'y', 117.34644309213836, 'dist: ', 29.800491885737504)
# Lpl: 124.750999578
# frequency 860005750 symTime  32.768
# bw 125 sf 12 cr 1 rssi -110.750999578
# sf 12  cr 1 pl 20 bw 125
# rectime node  69    1318.912

# %%
#prepare show
if (graphics == 1):
    plt.xlim([0, xmax])
    plt.ylim([0, ymax])
    plt.draw()
    plt.show()

# start simulation
env.run(until=simtime)
print("----------------------------")
print("----------------------------")

# print stats and save into file
print "nrCollisions ", nrCollisions

# compute energy
# Transmit consumption in mA from -2 to +17 dBm
TX = [22, 22, 22, 23,                                      # RFO/PA0: -2..1
      24, 24, 24, 25, 25, 25, 25, 26, 31, 32, 34, 35, 44,  # PA_BOOST/PA1: 2..14
      82, 85, 90,                                          # PA_BOOST/PA1: 15..17
      105, 115, 125]                                       # PA_BOOST/PA1+PA2: 18..20
# mA = 90    # current draw for TX = 17 dBm
V = 3.0     # voltage XXX
sent = sum(n.sent for n in nodes)
energy = sum(node.packet.rectime * TX[int(node.packet.txpow)+2] * V * node.sent for node in nodes) / 1e6
timeTotal = sum(n.transmitionTime for n in nodes)


print "energy (in J): ", energy
print "sent packets: ", sent
print "collisions: ", nrCollisions
print "received packets: ", nrReceived
print "processed packets: ", nrProcessed
print "lost packets: ", nrLost
print "Total time to fly: ", timeTotal

# data extraction rate
der = (sent-nrCollisions)/float(sent)
print "DER:", der
der = (nrReceived)/float(sent)
print "DER method 2:", der

# this can be done to keep graphics visible
if (graphics == 1):
    raw_input('Press Enter to continue ...')
# print("----------------------------")
# print("Saving at"),
# # save experiment data into a dat file that can be read by e.g. gnuplot
# # name of file would be:  exp0.dat for experiment 0
# fname = "exp" + str(experiment) + ".dat"
# print fname+'...',
# if os.path.isfile(fname):
#     res = "\n" + str(nrNodes) + " " + str(nrCollisions) + " "  + str(sent) + " " + str(energy) + " " + str(nrReceived) + " " + str(nrProcessed) + " " + str(timeTotal)
# else:
#     res = "#nrNodes nrCollisions nrTransmissions OverallEnergy nrReceived nrProcessed timeToFly\n" + str(nrNodes) + " " + str(nrCollisions) + " "  + str(sent) + " " + str(energy) + " " + str(nrReceived) + " " + str(nrProcessed) + " " + str(timeTotal)
# with open(fname, "a") as myfile:
#     myfile.write(res)
# myfile.close()
# print('done.')
print("----------------------------")
print("----------------------------")
# with open('nodes.txt','w') as nfile:
#     for n in nodes:
#         nfile.write("{} {} {}\n".format(n.x, n.y, n.nodeid))
# with open('basestation.txt', 'w') as bfile:
#     bfile.write("{} {} {}\n".format(bsx, bsy, 0))
# Out:
# CHECK node 40 (sf:12 bw:125 freq:8.600049e+08) others: 1
# >> node 9 (sf:12 bw:125 freq:8.600029e+08)
# no frequency coll
# CHECK node 5 (sf:12 bw:125 freq:8.600015e+08) others: 1
# >> node 49 (sf:12 bw:125 freq:8.600034e+08)
# no frequency coll
# CHECK node 0 (sf:12 bw:125 freq:8.600026e+08) others: 1
# >> node 50 (sf:12 bw:125 freq:8.600034e+08)
# no frequency coll
# CHECK node 2 (sf:12 bw:125 freq:8.600010e+08) others: 1
# >> node 13 (sf:12 bw:125 freq:8.600054e+08)
# no frequency coll
# CHECK node 14 (sf:12 bw:125 freq:8.600048e+08) others: 1
# >> node 40 (sf:12 bw:125 freq:8.600049e+08)
# no frequency coll
# CHECK node 48 (sf:12 bw:125 freq:8.600038e+08) others: 1
# >> node 2 (sf:12 bw:125 freq:8.600010e+08)
# no frequency coll
# CHECK node 62 (sf:12 bw:125 freq:8.600065e+08) others: 1
# >> node 43 (sf:12 bw:125 freq:8.600072e+08)
# no frequency coll
# CHECK node 20 (sf:12 bw:125 freq:8.600054e+08) others: 1
# >> node 62 (sf:12 bw:125 freq:8.600065e+08)
# no frequency coll
# CHECK node 26 (sf:12 bw:125 freq:8.600029e+08) others: 1
# >> node 36 (sf:12 bw:125 freq:8.600071e+08)
# no frequency coll
# CHECK node 49 (sf:12 bw:125 freq:8.600034e+08) others: 1
# >> node 33 (sf:12 bw:125 freq:8.600010e+08)
# no frequency coll
# CHECK node 60 (sf:12 bw:125 freq:8.600065e+08) others: 1
# >> node 28 (sf:12 bw:125 freq:8.600044e+08)
# no frequency coll
# CHECK node 60 (sf:12 bw:125 freq:8.600065e+08) others: 1
# >> node 24 (sf:12 bw:125 freq:8.600078e+08)
# no frequency coll
# CHECK node 33 (sf:12 bw:125 freq:8.600010e+08) others: 1
# >> node 17 (sf:12 bw:125 freq:8.600025e+08)
# no frequency coll
# CHECK node 26 (sf:12 bw:125 freq:8.600029e+08) others: 1
# >> node 50 (sf:12 bw:125 freq:8.600034e+08)
# no frequency coll
# CHECK node 57 (sf:12 bw:125 freq:8.600021e+08) others: 1
# >> node 9 (sf:12 bw:125 freq:8.600029e+08)
# no frequency coll
# CHECK node 48 (sf:12 bw:125 freq:8.600038e+08) others: 1
# >> node 57 (sf:12 bw:125 freq:8.600021e+08)
# no frequency coll
# CHECK node 42 (sf:12 bw:125 freq:8.600051e+08) others: 1
# >> node 14 (sf:12 bw:125 freq:8.600048e+08)
# no frequency coll
# CHECK node 3 (sf:12 bw:125 freq:8.600045e+08) others: 1
# >> node 4 (sf:12 bw:125 freq:8.600052e+08)
# no frequency coll
# CHECK node 61 (sf:12 bw:125 freq:8.600022e+08) others: 1
# >> node 0 (sf:12 bw:125 freq:8.600026e+08)
# no frequency coll
# CHECK node 52 (sf:12 bw:125 freq:8.600045e+08) others: 1
# >> node 55 (sf:12 bw:125 freq:8.600015e+08)
# no frequency coll
# CHECK node 0 (sf:12 bw:125 freq:8.600026e+08) others: 1
# >> node 59 (sf:12 bw:125 freq:8.600009e+08)
# no frequency coll
# CHECK node 6 (sf:12 bw:125 freq:8.600059e+08) others: 1
# >> node 36 (sf:12 bw:125 freq:8.600071e+08)
# no frequency coll
# CHECK node 23 (sf:12 bw:125 freq:8.600041e+08) others: 1
# >> node 37 (sf:12 bw:125 freq:8.600006e+08)
# no frequency coll
# CHECK node 16 (sf:12 bw:125 freq:8.600080e+08) others: 1
# >> node 26 (sf:12 bw:125 freq:8.600029e+08)
# no frequency coll
# CHECK node 4 (sf:12 bw:125 freq:8.600052e+08) others: 1
# >> node 20 (sf:12 bw:125 freq:8.600054e+08)
# no frequency coll
# CHECK node 50 (sf:12 bw:125 freq:8.600034e+08) others: 1
# >> node 54 (sf:12 bw:125 freq:8.600018e+08)
# no frequency coll
# CHECK node 18 (sf:12 bw:125 freq:8.600034e+08) others: 1
# >> node 55 (sf:12 bw:125 freq:8.600015e+08)
# no frequency coll
# CHECK node 67 (sf:12 bw:125 freq:8.600056e+08) others: 1
# >> node 59 (sf:12 bw:125 freq:8.600009e+08)
# no frequency coll
# CHECK node 19 (sf:12 bw:125 freq:8.600009e+08) others: 1
# >> node 0 (sf:12 bw:125 freq:8.600026e+08)
# no frequency coll
# CHECK node 26 (sf:12 bw:125 freq:8.600029e+08) others: 1
# >> node 6 (sf:12 bw:125 freq:8.600059e+08)
# no frequency coll
# CHECK node 11 (sf:12 bw:125 freq:8.600072e+08) others: 2
# >> node 6 (sf:12 bw:125 freq:8.600059e+08)
# no frequency coll
# >> node 26 (sf:12 bw:125 freq:8.600029e+08)
# no frequency coll
# CHECK node 15 (sf:12 bw:125 freq:8.600002e+08) others: 1
# >> node 34 (sf:12 bw:125 freq:8.600031e+08)
# no frequency coll
# CHECK node 59 (sf:12 bw:125 freq:8.600009e+08) others: 1
# >> node 21 (sf:12 bw:125 freq:8.600056e+08)
# no frequency coll
# CHECK node 44 (sf:12 bw:125 freq:8.600070e+08) others: 1
# >> node 58 (sf:12 bw:125 freq:8.600022e+08)
# no frequency coll
# CHECK node 43 (sf:12 bw:125 freq:8.600072e+08) others: 1
# >> node 44 (sf:12 bw:125 freq:8.600070e+08)
# no frequency coll
# CHECK node 34 (sf:12 bw:125 freq:8.600031e+08) others: 1
# >> node 25 (sf:12 bw:125 freq:8.600041e+08)
# no frequency coll
# CHECK node 33 (sf:12 bw:125 freq:8.600010e+08) others: 1
# >> node 38 (sf:12 bw:125 freq:8.600018e+08)
# no frequency coll
# CHECK node 1 (sf:12 bw:125 freq:8.600058e+08) others: 1
# >> node 37 (sf:12 bw:125 freq:8.600006e+08)
# no frequency coll
# CHECK node 61 (sf:12 bw:125 freq:8.600022e+08) others: 1
# >> node 67 (sf:12 bw:125 freq:8.600056e+08)
# no frequency coll
# CHECK node 6 (sf:12 bw:125 freq:8.600059e+08) others: 1
# >> node 66 (sf:12 bw:125 freq:8.600005e+08)
# no frequency coll
# CHECK node 6 (sf:12 bw:125 freq:8.600059e+08) others: 1
# >> node 55 (sf:12 bw:125 freq:8.600015e+08)
# no frequency coll
# CHECK node 8 (sf:12 bw:125 freq:8.600018e+08) others: 1
# >> node 11 (sf:12 bw:125 freq:8.600072e+08)
# no frequency coll
# CHECK node 33 (sf:12 bw:125 freq:8.600010e+08) others: 1
# >> node 8 (sf:12 bw:125 freq:8.600018e+08)
# no frequency coll
# CHECK node 26 (sf:12 bw:125 freq:8.600029e+08) others: 1
# >> node 5 (sf:12 bw:125 freq:8.600015e+08)
# no frequency coll
# CHECK node 23 (sf:12 bw:125 freq:8.600041e+08) others: 1
# >> node 36 (sf:12 bw:125 freq:8.600071e+08)
# no frequency coll
# CHECK node 45 (sf:12 bw:125 freq:8.600078e+08) others: 1
# >> node 38 (sf:12 bw:125 freq:8.600018e+08)
# no frequency coll
# CHECK node 47 (sf:12 bw:125 freq:8.600028e+08) others: 1
# >> node 44 (sf:12 bw:125 freq:8.600070e+08)
# no frequency coll
# CHECK node 9 (sf:12 bw:125 freq:8.600029e+08) others: 1
# >> node 37 (sf:12 bw:125 freq:8.600006e+08)
# no frequency coll
# CHECK node 48 (sf:12 bw:125 freq:8.600038e+08) others: 1
# >> node 50 (sf:12 bw:125 freq:8.600034e+08)
# no frequency coll
# CHECK node 26 (sf:12 bw:125 freq:8.600029e+08) others: 2
# >> node 50 (sf:12 bw:125 freq:8.600034e+08)
# no frequency coll
# >> node 48 (sf:12 bw:125 freq:8.600038e+08)
# no frequency coll
# CHECK node 4 (sf:12 bw:125 freq:8.600052e+08) others: 1
# >> node 35 (sf:12 bw:125 freq:8.600025e+08)
# no frequency coll
# CHECK node 43 (sf:12 bw:125 freq:8.600072e+08) others: 1
# >> node 36 (sf:12 bw:125 freq:8.600071e+08)
# no frequency coll
# CHECK node 50 (sf:12 bw:125 freq:8.600034e+08) others: 1
# >> node 43 (sf:12 bw:125 freq:8.600072e+08)
# no frequency coll
# CHECK node 27 (sf:12 bw:125 freq:8.600064e+08) others: 1
# >> node 60 (sf:12 bw:125 freq:8.600065e+08)
# no frequency coll
# CHECK node 23 (sf:12 bw:125 freq:8.600041e+08) others: 1
# >> node 65 (sf:12 bw:125 freq:8.600024e+08)
# no frequency coll
# CHECK node 33 (sf:12 bw:125 freq:8.600010e+08) others: 1
# >> node 21 (sf:12 bw:125 freq:8.600056e+08)
# no frequency coll
# CHECK node 29 (sf:12 bw:125 freq:8.600021e+08) others: 1
# >> node 3 (sf:12 bw:125 freq:8.600045e+08)
# no frequency coll
# CHECK node 47 (sf:12 bw:125 freq:8.600028e+08) others: 2
# >> node 3 (sf:12 bw:125 freq:8.600045e+08)
# no frequency coll
# >> node 29 (sf:12 bw:125 freq:8.600021e+08)
# no frequency coll
# CHECK node 40 (sf:12 bw:125 freq:8.600049e+08) others: 1
# >> node 43 (sf:12 bw:125 freq:8.600072e+08)
# no frequency coll
# CHECK node 39 (sf:12 bw:125 freq:8.600040e+08) others: 1
# >> node 62 (sf:12 bw:125 freq:8.600065e+08)
# no frequency coll
# CHECK node 66 (sf:12 bw:125 freq:8.600005e+08) others: 1
# >> node 50 (sf:12 bw:125 freq:8.600034e+08)
# no frequency coll
# CHECK node 62 (sf:12 bw:125 freq:8.600065e+08) others: 1
# >> node 36 (sf:12 bw:125 freq:8.600071e+08)
# no frequency coll
# CHECK node 7 (sf:12 bw:125 freq:8.600062e+08) others: 1
# >> node 29 (sf:12 bw:125 freq:8.600021e+08)
# no frequency coll
# CHECK node 6 (sf:12 bw:125 freq:8.600059e+08) others: 1
# >> node 31 (sf:12 bw:125 freq:8.600022e+08)
# no frequency coll
# CHECK node 0 (sf:12 bw:125 freq:8.600026e+08) others: 1
# >> node 61 (sf:12 bw:125 freq:8.600022e+08)
# no frequency coll
# CHECK node 32 (sf:12 bw:125 freq:8.600031e+08) others: 1
# >> node 64 (sf:12 bw:125 freq:8.600046e+08)
# no frequency coll
# CHECK node 17 (sf:12 bw:125 freq:8.600025e+08) others: 1
# >> node 59 (sf:12 bw:125 freq:8.600009e+08)
# no frequency coll
# CHECK node 69 (sf:12 bw:125 freq:8.600058e+08) others: 1
# >> node 55 (sf:12 bw:125 freq:8.600015e+08)
# no frequency coll
# CHECK node 12 (sf:12 bw:125 freq:8.600061e+08) others: 1
# >> node 24 (sf:12 bw:125 freq:8.600078e+08)
# no frequency coll
# CHECK node 23 (sf:12 bw:125 freq:8.600041e+08) others: 1
# >> node 20 (sf:12 bw:125 freq:8.600054e+08)
# no frequency coll
# CHECK node 8 (sf:12 bw:125 freq:8.600018e+08) others: 1
# >> node 35 (sf:12 bw:125 freq:8.600025e+08)
# no frequency coll
# CHECK node 62 (sf:12 bw:125 freq:8.600065e+08) others: 1
# >> node 61 (sf:12 bw:125 freq:8.600022e+08)
# no frequency coll
# CHECK node 36 (sf:12 bw:125 freq:8.600071e+08) others: 1
# >> node 47 (sf:12 bw:125 freq:8.600028e+08)
# no frequency coll
# CHECK node 8 (sf:12 bw:125 freq:8.600018e+08) others: 1
# >> node 36 (sf:12 bw:125 freq:8.600071e+08)
# no frequency coll
# CHECK node 68 (sf:12 bw:125 freq:8.600040e+08) others: 1
# >> node 69 (sf:12 bw:125 freq:8.600058e+08)
# no frequency coll
# CHECK node 29 (sf:12 bw:125 freq:8.600021e+08) others: 1
# >> node 27 (sf:12 bw:125 freq:8.600064e+08)
# no frequency coll
# CHECK node 24 (sf:12 bw:125 freq:8.600078e+08) others: 1
# >> node 45 (sf:12 bw:125 freq:8.600078e+08)
# frequency coll 125
# collision sf node 24 and node 45
# CHECK node 52 (sf:12 bw:125 freq:8.600045e+08) others: 1
# >> node 9 (sf:12 bw:125 freq:8.600029e+08)
# no frequency coll
# CHECK node 53 (sf:12 bw:125 freq:8.600025e+08) others: 1
# >> node 34 (sf:12 bw:125 freq:8.600031e+08)
# no frequency coll
# CHECK node 8 (sf:12 bw:125 freq:8.600018e+08) others: 1
# >> node 46 (sf:12 bw:125 freq:8.600012e+08)
# no frequency coll
# CHECK node 47 (sf:12 bw:125 freq:8.600028e+08) others: 1
# >> node 44 (sf:12 bw:125 freq:8.600070e+08)
# no frequency coll
# CHECK node 12 (sf:12 bw:125 freq:8.600061e+08) others: 1
# >> node 16 (sf:12 bw:125 freq:8.600080e+08)
# no frequency coll
# CHECK node 11 (sf:12 bw:125 freq:8.600072e+08) others: 1
# >> node 68 (sf:12 bw:125 freq:8.600040e+08)
# no frequency coll
# CHECK node 62 (sf:12 bw:125 freq:8.600065e+08) others: 1
# >> node 26 (sf:12 bw:125 freq:8.600029e+08)
# no frequency coll
# CHECK node 57 (sf:12 bw:125 freq:8.600021e+08) others: 1
# >> node 39 (sf:12 bw:125 freq:8.600040e+08)
# no frequency coll
# CHECK node 48 (sf:12 bw:125 freq:8.600038e+08) others: 1
# >> node 57 (sf:12 bw:125 freq:8.600021e+08)
# no frequency coll
# CHECK node 11 (sf:12 bw:125 freq:8.600072e+08) others: 1
# >> node 25 (sf:12 bw:125 freq:8.600041e+08)
# no frequency coll
# CHECK node 6 (sf:12 bw:125 freq:8.600059e+08) others: 1
# >> node 16 (sf:12 bw:125 freq:8.600080e+08)
# no frequency coll
# CHECK node 63 (sf:12 bw:125 freq:8.600076e+08) others: 1
# >> node 40 (sf:12 bw:125 freq:8.600049e+08)
# no frequency coll
# CHECK node 59 (sf:12 bw:125 freq:8.600009e+08) others: 1
# >> node 29 (sf:12 bw:125 freq:8.600021e+08)
# no frequency coll
# CHECK node 52 (sf:12 bw:125 freq:8.600045e+08) others: 1
# >> node 59 (sf:12 bw:125 freq:8.600009e+08)
# no frequency coll
# CHECK node 13 (sf:12 bw:125 freq:8.600054e+08) others: 1
# >> node 61 (sf:12 bw:125 freq:8.600022e+08)
# no frequency coll
# CHECK node 10 (sf:12 bw:125 freq:8.600072e+08) others: 1
# >> node 17 (sf:12 bw:125 freq:8.600025e+08)
# no frequency coll
# CHECK node 68 (sf:12 bw:125 freq:8.600040e+08) others: 1
# >> node 34 (sf:12 bw:125 freq:8.600031e+08)
# no frequency coll
# CHECK node 20 (sf:12 bw:125 freq:8.600054e+08) others: 1
# >> node 44 (sf:12 bw:125 freq:8.600070e+08)
# no frequency coll
# CHECK node 54 (sf:12 bw:125 freq:8.600018e+08) others: 1
# >> node 60 (sf:12 bw:125 freq:8.600065e+08)
# no frequency coll
# CHECK node 21 (sf:12 bw:125 freq:8.600056e+08) others: 2
# >> node 60 (sf:12 bw:125 freq:8.600065e+08)
# no frequency coll
# >> node 54 (sf:12 bw:125 freq:8.600018e+08)
# no frequency coll
# CHECK node 11 (sf:12 bw:125 freq:8.600072e+08) others: 2
# >> node 54 (sf:12 bw:125 freq:8.600018e+08)
# no frequency coll
# >> node 21 (sf:12 bw:125 freq:8.600056e+08)
# no frequency coll
# CHECK node 63 (sf:12 bw:125 freq:8.600076e+08) others: 1
# >> node 64 (sf:12 bw:125 freq:8.600046e+08)
# no frequency coll
# CHECK node 59 (sf:12 bw:125 freq:8.600009e+08) others: 1
# >> node 10 (sf:12 bw:125 freq:8.600072e+08)
# no frequency coll
# CHECK node 0 (sf:12 bw:125 freq:8.600026e+08) others: 1
# >> node 37 (sf:12 bw:125 freq:8.600006e+08)
# no frequency coll
# CHECK node 34 (sf:12 bw:125 freq:8.600031e+08) others: 1
# >> node 0 (sf:12 bw:125 freq:8.600026e+08)
# no frequency coll
# CHECK node 53 (sf:12 bw:125 freq:8.600025e+08) others: 1
# >> node 5 (sf:12 bw:125 freq:8.600015e+08)
# no frequency coll
# CHECK node 24 (sf:12 bw:125 freq:8.600078e+08) others: 1
# >> node 51 (sf:12 bw:125 freq:8.600059e+08)
# no frequency coll
# CHECK node 67 (sf:12 bw:125 freq:8.600056e+08) others: 2
# >> node 51 (sf:12 bw:125 freq:8.600059e+08)
# no frequency coll
# >> node 24 (sf:12 bw:125 freq:8.600078e+08)
# no frequency coll
# CHECK node 68 (sf:12 bw:125 freq:8.600040e+08) others: 1
# >> node 5 (sf:12 bw:125 freq:8.600015e+08)
# no frequency coll
# CHECK node 64 (sf:12 bw:125 freq:8.600046e+08) others: 1
# >> node 12 (sf:12 bw:125 freq:8.600061e+08)
# no frequency coll
# CHECK node 6 (sf:12 bw:125 freq:8.600059e+08) others: 1
# >> node 41 (sf:12 bw:125 freq:8.600080e+08)
# no frequency coll
# CHECK node 10 (sf:12 bw:125 freq:8.600072e+08) others: 1
# >> node 54 (sf:12 bw:125 freq:8.600018e+08)
# no frequency coll
# CHECK node 40 (sf:12 bw:125 freq:8.600049e+08) others: 1
# >> node 25 (sf:12 bw:125 freq:8.600041e+08)
# no frequency coll
# CHECK node 31 (sf:12 bw:125 freq:8.600022e+08) others: 1
# >> node 20 (sf:12 bw:125 freq:8.600054e+08)
# no frequency coll
# CHECK node 37 (sf:12 bw:125 freq:8.600006e+08) others: 2
# >> node 20 (sf:12 bw:125 freq:8.600054e+08)
# no frequency coll
# >> node 31 (sf:12 bw:125 freq:8.600022e+08)
# no frequency coll
# CHECK node 12 (sf:12 bw:125 freq:8.600061e+08) others: 2
# >> node 31 (sf:12 bw:125 freq:8.600022e+08)
# no frequency coll
# >> node 37 (sf:12 bw:125 freq:8.600006e+08)
# no frequency coll
# CHECK node 45 (sf:12 bw:125 freq:8.600078e+08) others: 1
# >> node 36 (sf:12 bw:125 freq:8.600071e+08)
# no frequency coll
# CHECK node 28 (sf:12 bw:125 freq:8.600044e+08) others: 2
# >> node 36 (sf:12 bw:125 freq:8.600071e+08)
# no frequency coll
# >> node 45 (sf:12 bw:125 freq:8.600078e+08)
# no frequency coll
# CHECK node 6 (sf:12 bw:125 freq:8.600059e+08) others: 1
# >> node 52 (sf:12 bw:125 freq:8.600045e+08)
# no frequency coll
# CHECK node 19 (sf:12 bw:125 freq:8.600009e+08) others: 1
# >> node 6 (sf:12 bw:125 freq:8.600059e+08)
# no frequency coll
# CHECK node 7 (sf:12 bw:125 freq:8.600062e+08) others: 1
# >> node 10 (sf:12 bw:125 freq:8.600072e+08)
# no frequency coll
# CHECK node 63 (sf:12 bw:125 freq:8.600076e+08) others: 1
# >> node 57 (sf:12 bw:125 freq:8.600021e+08)
# no frequency coll
# CHECK node 60 (sf:12 bw:125 freq:8.600065e+08) others: 1
# >> node 44 (sf:12 bw:125 freq:8.600070e+08)
# no frequency coll
# CHECK node 20 (sf:12 bw:125 freq:8.600054e+08) others: 1
# >> node 11 (sf:12 bw:125 freq:8.600072e+08)
# no frequency coll
# CHECK node 58 (sf:12 bw:125 freq:8.600022e+08) others: 2
# >> node 11 (sf:12 bw:125 freq:8.600072e+08)
# no frequency coll
# >> node 20 (sf:12 bw:125 freq:8.600054e+08)
# no frequency coll
# CHECK node 47 (sf:12 bw:125 freq:8.600028e+08) others: 1
# >> node 34 (sf:12 bw:125 freq:8.600031e+08)
# no frequency coll
# CHECK node 59 (sf:12 bw:125 freq:8.600009e+08) others: 1
# >> node 58 (sf:12 bw:125 freq:8.600022e+08)
# no frequency coll
# CHECK node 5 (sf:12 bw:125 freq:8.600015e+08) others: 2
# >> node 58 (sf:12 bw:125 freq:8.600022e+08)
# no frequency coll
# >> node 59 (sf:12 bw:125 freq:8.600009e+08)
# no frequency coll
# CHECK node 17 (sf:12 bw:125 freq:8.600025e+08) others: 1
# >> node 39 (sf:12 bw:125 freq:8.600040e+08)
# no frequency coll
# CHECK node 49 (sf:12 bw:125 freq:8.600034e+08) others: 1
# >> node 31 (sf:12 bw:125 freq:8.600022e+08)
# no frequency coll
# CHECK node 55 (sf:12 bw:125 freq:8.600015e+08) others: 1
# >> node 58 (sf:12 bw:125 freq:8.600022e+08)
# no frequency coll
# CHECK node 18 (sf:12 bw:125 freq:8.600034e+08) others: 1
# >> node 30 (sf:12 bw:125 freq:8.600001e+08)
# no frequency coll
# CHECK node 69 (sf:12 bw:125 freq:8.600058e+08) others: 1
# >> node 4 (sf:12 bw:125 freq:8.600052e+08)
# no frequency coll
# CHECK node 30 (sf:12 bw:125 freq:8.600001e+08) others: 1
# >> node 38 (sf:12 bw:125 freq:8.600018e+08)
# no frequency coll
# CHECK node 39 (sf:12 bw:125 freq:8.600040e+08) others: 1
# >> node 27 (sf:12 bw:125 freq:8.600064e+08)
# no frequency coll
# CHECK node 29 (sf:12 bw:125 freq:8.600021e+08) others: 1
# >> node 31 (sf:12 bw:125 freq:8.600022e+08)
# no frequency coll
# CHECK node 13 (sf:12 bw:125 freq:8.600054e+08) others: 1
# >> node 27 (sf:12 bw:125 freq:8.600064e+08)
# no frequency coll
# CHECK node 9 (sf:12 bw:125 freq:8.600029e+08) others: 1
# >> node 12 (sf:12 bw:125 freq:8.600061e+08)
# no frequency coll
# CHECK node 37 (sf:12 bw:125 freq:8.600006e+08) others: 1
# >> node 3 (sf:12 bw:125 freq:8.600045e+08)
# no frequency coll
# CHECK node 12 (sf:12 bw:125 freq:8.600061e+08) others: 1
# >> node 21 (sf:12 bw:125 freq:8.600056e+08)
# no frequency coll
# CHECK node 64 (sf:12 bw:125 freq:8.600046e+08) others: 1
# >> node 37 (sf:12 bw:125 freq:8.600006e+08)
# no frequency coll
# CHECK node 33 (sf:12 bw:125 freq:8.600010e+08) others: 1
# >> node 67 (sf:12 bw:125 freq:8.600056e+08)
# no frequency coll
# CHECK node 9 (sf:12 bw:125 freq:8.600029e+08) others: 1
# >> node 16 (sf:12 bw:125 freq:8.600080e+08)
# no frequency coll
# CHECK node 55 (sf:12 bw:125 freq:8.600015e+08) others: 1
# >> node 3 (sf:12 bw:125 freq:8.600045e+08)
# no frequency coll
# CHECK node 1 (sf:12 bw:125 freq:8.600058e+08) others: 1
# >> node 11 (sf:12 bw:125 freq:8.600072e+08)
# no frequency coll
# CHECK node 17 (sf:12 bw:125 freq:8.600025e+08) others: 1
# >> node 55 (sf:12 bw:125 freq:8.600015e+08)
# no frequency coll
# CHECK node 4 (sf:12 bw:125 freq:8.600052e+08) others: 1
# >> node 17 (sf:12 bw:125 freq:8.600025e+08)
# no frequency coll
# CHECK node 50 (sf:12 bw:125 freq:8.600034e+08) others: 1
# >> node 0 (sf:12 bw:125 freq:8.600026e+08)
# no frequency coll
# CHECK node 5 (sf:12 bw:125 freq:8.600015e+08) others: 1
# >> node 64 (sf:12 bw:125 freq:8.600046e+08)
# no frequency coll
# CHECK node 37 (sf:12 bw:125 freq:8.600006e+08) others: 1
# >> node 29 (sf:12 bw:125 freq:8.600021e+08)
# no frequency coll
# CHECK node 61 (sf:12 bw:125 freq:8.600022e+08) others: 1
# >> node 65 (sf:12 bw:125 freq:8.600024e+08)
# no frequency coll
# CHECK node 36 (sf:12 bw:125 freq:8.600071e+08) others: 1
# >> node 56 (sf:12 bw:125 freq:8.600030e+08)
# no frequency coll
# CHECK node 29 (sf:12 bw:125 freq:8.600021e+08) others: 1
# >> node 36 (sf:12 bw:125 freq:8.600071e+08)
# no frequency coll
# CHECK node 8 (sf:12 bw:125 freq:8.600018e+08) others: 1
# >> node 50 (sf:12 bw:125 freq:8.600034e+08)
# no frequency coll
# CHECK node 57 (sf:12 bw:125 freq:8.600021e+08) others: 1
# >> node 47 (sf:12 bw:125 freq:8.600028e+08)
# no frequency coll
# CHECK node 53 (sf:12 bw:125 freq:8.600025e+08) others: 1
# >> node 42 (sf:12 bw:125 freq:8.600051e+08)
# no frequency coll
# CHECK node 15 (sf:12 bw:125 freq:8.600002e+08) others: 1
# >> node 53 (sf:12 bw:125 freq:8.600025e+08)
# no frequency coll
# CHECK node 47 (sf:12 bw:125 freq:8.600028e+08) others: 1
# >> node 69 (sf:12 bw:125 freq:8.600058e+08)
# no frequency coll
# CHECK node 11 (sf:12 bw:125 freq:8.600072e+08) others: 1
# >> node 7 (sf:12 bw:125 freq:8.600062e+08)
# no frequency coll
# CHECK node 32 (sf:12 bw:125 freq:8.600031e+08) others: 1
# >> node 10 (sf:12 bw:125 freq:8.600072e+08)
# no frequency coll
# CHECK node 48 (sf:12 bw:125 freq:8.600038e+08) others: 1
# >> node 0 (sf:12 bw:125 freq:8.600026e+08)
# no frequency coll
# CHECK node 27 (sf:12 bw:125 freq:8.600064e+08) others: 1
# >> node 49 (sf:12 bw:125 freq:8.600034e+08)
# no frequency coll
# CHECK node 41 (sf:12 bw:125 freq:8.600080e+08) others: 1
# >> node 36 (sf:12 bw:125 freq:8.600071e+08)
# no frequency coll
# CHECK node 61 (sf:12 bw:125 freq:8.600022e+08) others: 1
# >> node 26 (sf:12 bw:125 freq:8.600029e+08)
# no frequency coll
# CHECK node 27 (sf:12 bw:125 freq:8.600064e+08) others: 1
# >> node 55 (sf:12 bw:125 freq:8.600015e+08)
# no frequency coll
# CHECK node 17 (sf:12 bw:125 freq:8.600025e+08) others: 1
# >> node 54 (sf:12 bw:125 freq:8.600018e+08)
# no frequency coll
# CHECK node 59 (sf:12 bw:125 freq:8.600009e+08) others: 1
# >> node 67 (sf:12 bw:125 freq:8.600056e+08)
# no frequency coll
# CHECK node 52 (sf:12 bw:125 freq:8.600045e+08) others: 1
# >> node 61 (sf:12 bw:125 freq:8.600022e+08)
# no frequency coll
# CHECK node 35 (sf:12 bw:125 freq:8.600025e+08) others: 1
# >> node 37 (sf:12 bw:125 freq:8.600006e+08)
# no frequency coll
# CHECK node 20 (sf:12 bw:125 freq:8.600054e+08) others: 1
# >> node 60 (sf:12 bw:125 freq:8.600065e+08)
# no frequency coll
# CHECK node 41 (sf:12 bw:125 freq:8.600080e+08) others: 1
# >> node 4 (sf:12 bw:125 freq:8.600052e+08)
# no frequency coll
# CHECK node 58 (sf:12 bw:125 freq:8.600022e+08) others: 1
# >> node 21 (sf:12 bw:125 freq:8.600056e+08)
# no frequency coll
# CHECK node 46 (sf:12 bw:125 freq:8.600012e+08) others: 1
# >> node 56 (sf:12 bw:125 freq:8.600030e+08)
# no frequency coll
# CHECK node 60 (sf:12 bw:125 freq:8.600065e+08) others: 1
# >> node 3 (sf:12 bw:125 freq:8.600045e+08)
# no frequency coll
# CHECK node 31 (sf:12 bw:125 freq:8.600022e+08) others: 2
# >> node 3 (sf:12 bw:125 freq:8.600045e+08)
# no frequency coll
# >> node 60 (sf:12 bw:125 freq:8.600065e+08)
# no frequency coll
# CHECK node 51 (sf:12 bw:125 freq:8.600059e+08) others: 1
# >> node 17 (sf:12 bw:125 freq:8.600025e+08)
# no frequency coll
# CHECK node 26 (sf:12 bw:125 freq:8.600029e+08) others: 1
# >> node 23 (sf:12 bw:125 freq:8.600041e+08)
# no frequency coll
# CHECK node 35 (sf:12 bw:125 freq:8.600025e+08) others: 1
# >> node 38 (sf:12 bw:125 freq:8.600018e+08)
# no frequency coll
# CHECK node 60 (sf:12 bw:125 freq:8.600065e+08) others: 1
# >> node 50 (sf:12 bw:125 freq:8.600034e+08)
# no frequency coll
# CHECK node 22 (sf:12 bw:125 freq:8.600024e+08) others: 1
# >> node 36 (sf:12 bw:125 freq:8.600071e+08)
# no frequency coll
# CHECK node 31 (sf:12 bw:125 freq:8.600022e+08) others: 2
# >> node 36 (sf:12 bw:125 freq:8.600071e+08)
# no frequency coll
# >> node 22 (sf:12 bw:125 freq:8.600024e+08)
# no frequency coll
# CHECK node 24 (sf:12 bw:125 freq:8.600078e+08) others: 1
# >> node 31 (sf:12 bw:125 freq:8.600022e+08)
# no frequency coll
# CHECK node 23 (sf:12 bw:125 freq:8.600041e+08) others: 1
# >> node 10 (sf:12 bw:125 freq:8.600072e+08)
# no frequency coll
# CHECK node 57 (sf:12 bw:125 freq:8.600021e+08) others: 1
# >> node 58 (sf:12 bw:125 freq:8.600022e+08)
# no frequency coll
# CHECK node 22 (sf:12 bw:125 freq:8.600024e+08) others: 1
# >> node 67 (sf:12 bw:125 freq:8.600056e+08)
# no frequency coll
# CHECK node 63 (sf:12 bw:125 freq:8.600076e+08) others: 1
# >> node 9 (sf:12 bw:125 freq:8.600029e+08)
# no frequency coll
# CHECK node 49 (sf:12 bw:125 freq:8.600034e+08) others: 1
# >> node 63 (sf:12 bw:125 freq:8.600076e+08)
# no frequency coll
# CHECK node 7 (sf:12 bw:125 freq:8.600062e+08) others: 1
# >> node 17 (sf:12 bw:125 freq:8.600025e+08)
# no frequency coll
# CHECK node 29 (sf:12 bw:125 freq:8.600021e+08) others: 1
# >> node 25 (sf:12 bw:125 freq:8.600041e+08)
# no frequency coll
# CHECK node 66 (sf:12 bw:125 freq:8.600005e+08) others: 1
# >> node 41 (sf:12 bw:125 freq:8.600080e+08)
# no frequency coll
# CHECK node 6 (sf:12 bw:125 freq:8.600059e+08) others: 1
# >> node 69 (sf:12 bw:125 freq:8.600058e+08)
# no frequency coll
# CHECK node 68 (sf:12 bw:125 freq:8.600040e+08) others: 1
# >> node 48 (sf:12 bw:125 freq:8.600038e+08)
# no frequency coll
# CHECK node 3 (sf:12 bw:125 freq:8.600045e+08) others: 1
# >> node 68 (sf:12 bw:125 freq:8.600040e+08)
# no frequency coll
# CHECK node 64 (sf:12 bw:125 freq:8.600046e+08) others: 1
# >> node 43 (sf:12 bw:125 freq:8.600072e+08)
# no frequency coll
# CHECK node 60 (sf:12 bw:125 freq:8.600065e+08) others: 1
# >> node 4 (sf:12 bw:125 freq:8.600052e+08)
# no frequency coll
# CHECK node 17 (sf:12 bw:125 freq:8.600025e+08) others: 1
# >> node 68 (sf:12 bw:125 freq:8.600040e+08)
# no frequency coll
# CHECK node 23 (sf:12 bw:125 freq:8.600041e+08) others: 1
# >> node 28 (sf:12 bw:125 freq:8.600044e+08)
# no frequency coll
# CHECK node 31 (sf:12 bw:125 freq:8.600022e+08) others: 1
# >> node 46 (sf:12 bw:125 freq:8.600012e+08)
# no frequency coll
# CHECK node 11 (sf:12 bw:125 freq:8.600072e+08) others: 1
# >> node 56 (sf:12 bw:125 freq:8.600030e+08)
# no frequency coll
# CHECK node 59 (sf:12 bw:125 freq:8.600009e+08) others: 1
# >> node 62 (sf:12 bw:125 freq:8.600065e+08)
# no frequency coll
# CHECK node 25 (sf:12 bw:125 freq:8.600041e+08) others: 1
# >> node 57 (sf:12 bw:125 freq:8.600021e+08)
# no frequency coll
# CHECK node 6 (sf:12 bw:125 freq:8.600059e+08) others: 1
# >> node 1 (sf:12 bw:125 freq:8.600058e+08)
# no frequency coll
# CHECK node 58 (sf:12 bw:125 freq:8.600022e+08) others: 1
# >> node 2 (sf:12 bw:125 freq:8.600010e+08)
# no frequency coll
# CHECK node 30 (sf:12 bw:125 freq:8.600001e+08) others: 1
# >> node 47 (sf:12 bw:125 freq:8.600028e+08)
# no frequency coll
# CHECK node 63 (sf:12 bw:125 freq:8.600076e+08) others: 1
# >> node 6 (sf:12 bw:125 freq:8.600059e+08)
# no frequency coll
# CHECK node 65 (sf:12 bw:125 freq:8.600024e+08) others: 1
# >> node 38 (sf:12 bw:125 freq:8.600018e+08)
# no frequency coll
# CHECK node 39 (sf:12 bw:125 freq:8.600040e+08) others: 1
# >> node 10 (sf:12 bw:125 freq:8.600072e+08)
# no frequency coll
# CHECK node 0 (sf:12 bw:125 freq:8.600026e+08) others: 1
# >> node 15 (sf:12 bw:125 freq:8.600002e+08)
# no frequency coll
# CHECK node 58 (sf:12 bw:125 freq:8.600022e+08) others: 1
# >> node 27 (sf:12 bw:125 freq:8.600064e+08)
# no frequency coll
# CHECK node 46 (sf:12 bw:125 freq:8.600012e+08) others: 1
# >> node 12 (sf:12 bw:125 freq:8.600061e+08)
# no frequency coll
# CHECK node 32 (sf:12 bw:125 freq:8.600031e+08) others: 1
# >> node 67 (sf:12 bw:125 freq:8.600056e+08)
# no frequency coll
# CHECK node 67 (sf:12 bw:125 freq:8.600056e+08) others: 1
# >> node 32 (sf:12 bw:125 freq:8.600031e+08)
# no frequency coll
# CHECK node 45 (sf:12 bw:125 freq:8.600078e+08) others: 1
# >> node 60 (sf:12 bw:125 freq:8.600065e+08)
# no frequency coll
# CHECK node 43 (sf:12 bw:125 freq:8.600072e+08) others: 1
# >> node 37 (sf:12 bw:125 freq:8.600006e+08)
# no frequency coll
# CHECK node 69 (sf:12 bw:125 freq:8.600058e+08) others: 1
# >> node 43 (sf:12 bw:125 freq:8.600072e+08)
# no frequency coll
# CHECK node 51 (sf:12 bw:125 freq:8.600059e+08) others: 1
# >> node 28 (sf:12 bw:125 freq:8.600044e+08)
# no frequency coll
# CHECK node 27 (sf:12 bw:125 freq:8.600064e+08) others: 1
# >> node 26 (sf:12 bw:125 freq:8.600029e+08)
# no frequency coll
# CHECK node 36 (sf:12 bw:125 freq:8.600071e+08) others: 1
# >> node 62 (sf:12 bw:125 freq:8.600065e+08)
# no frequency coll
# CHECK node 36 (sf:12 bw:125 freq:8.600071e+08) others: 1
# >> node 27 (sf:12 bw:125 freq:8.600064e+08)
# no frequency coll
# CHECK node 42 (sf:12 bw:125 freq:8.600051e+08) others: 1
# >> node 11 (sf:12 bw:125 freq:8.600072e+08)
# no frequency coll
# CHECK node 30 (sf:12 bw:125 freq:8.600001e+08) others: 1
# >> node 51 (sf:12 bw:125 freq:8.600059e+08)
# no frequency coll
# CHECK node 56 (sf:12 bw:125 freq:8.600030e+08) others: 1
# >> node 7 (sf:12 bw:125 freq:8.600062e+08)
# no frequency coll
# CHECK node 10 (sf:12 bw:125 freq:8.600072e+08) others: 1
# >> node 26 (sf:12 bw:125 freq:8.600029e+08)
# no frequency coll
# CHECK node 61 (sf:12 bw:125 freq:8.600022e+08) others: 1
# >> node 0 (sf:12 bw:125 freq:8.600026e+08)
# no frequency coll
# CHECK node 15 (sf:12 bw:125 freq:8.600002e+08) others: 1
# >> node 59 (sf:12 bw:125 freq:8.600009e+08)
# no frequency coll
# CHECK node 23 (sf:12 bw:125 freq:8.600041e+08) others: 1
# >> node 69 (sf:12 bw:125 freq:8.600058e+08)
# no frequency coll
# CHECK node 53 (sf:12 bw:125 freq:8.600025e+08) others: 1
# >> node 23 (sf:12 bw:125 freq:8.600041e+08)
# no frequency coll
# CHECK node 7 (sf:12 bw:125 freq:8.600062e+08) others: 1
# >> node 36 (sf:12 bw:125 freq:8.600071e+08)
# no frequency coll
# CHECK node 68 (sf:12 bw:125 freq:8.600040e+08) others: 1
# >> node 43 (sf:12 bw:125 freq:8.600072e+08)
# no frequency coll
# CHECK node 15 (sf:12 bw:125 freq:8.600002e+08) others: 2
# >> node 43 (sf:12 bw:125 freq:8.600072e+08)
# no frequency coll
# >> node 68 (sf:12 bw:125 freq:8.600040e+08)
# no frequency coll
# CHECK node 54 (sf:12 bw:125 freq:8.600018e+08) others: 1
# >> node 15 (sf:12 bw:125 freq:8.600002e+08)
# no frequency coll
# CHECK node 3 (sf:12 bw:125 freq:8.600045e+08) others: 1
# >> node 38 (sf:12 bw:125 freq:8.600018e+08)
# no frequency coll
# CHECK node 18 (sf:12 bw:125 freq:8.600034e+08) others: 1
# >> node 58 (sf:12 bw:125 freq:8.600022e+08)
# no frequency coll
# CHECK node 26 (sf:12 bw:125 freq:8.600029e+08) others: 1
# >> node 15 (sf:12 bw:125 freq:8.600002e+08)
# no frequency coll
# CHECK node 58 (sf:12 bw:125 freq:8.600022e+08) others: 1
# >> node 0 (sf:12 bw:125 freq:8.600026e+08)
# no frequency coll
# CHECK node 24 (sf:12 bw:125 freq:8.600078e+08) others: 1
# >> node 46 (sf:12 bw:125 freq:8.600012e+08)
# no frequency coll
# CHECK node 32 (sf:12 bw:125 freq:8.600031e+08) others: 1
# >> node 35 (sf:12 bw:125 freq:8.600025e+08)
# no frequency coll
# CHECK node 15 (sf:12 bw:125 freq:8.600002e+08) others: 1
# >> node 1 (sf:12 bw:125 freq:8.600058e+08)
# no frequency coll
# CHECK node 47 (sf:12 bw:125 freq:8.600028e+08) others: 1
# >> node 61 (sf:12 bw:125 freq:8.600022e+08)
# no frequency coll
# CHECK node 53 (sf:12 bw:125 freq:8.600025e+08) others: 1
# >> node 47 (sf:12 bw:125 freq:8.600028e+08)
# no frequency coll
# CHECK node 45 (sf:12 bw:125 freq:8.600078e+08) others: 1
# >> node 40 (sf:12 bw:125 freq:8.600049e+08)
# no frequency coll
# CHECK node 17 (sf:12 bw:125 freq:8.600025e+08) others: 1
# >> node 27 (sf:12 bw:125 freq:8.600064e+08)
# no frequency coll
# CHECK node 0 (sf:12 bw:125 freq:8.600026e+08) others: 1
# >> node 18 (sf:12 bw:125 freq:8.600034e+08)
# no frequency coll
# CHECK node 3 (sf:12 bw:125 freq:8.600045e+08) others: 1
# >> node 26 (sf:12 bw:125 freq:8.600029e+08)
# no frequency coll
# CHECK node 44 (sf:12 bw:125 freq:8.600070e+08) others: 1
# >> node 3 (sf:12 bw:125 freq:8.600045e+08)
# no frequency coll
# CHECK node 16 (sf:12 bw:125 freq:8.600080e+08) others: 1
# >> node 53 (sf:12 bw:125 freq:8.600025e+08)
# no frequency coll
# CHECK node 35 (sf:12 bw:125 freq:8.600025e+08) others: 1
# >> node 53 (sf:12 bw:125 freq:8.600025e+08)
# frequency coll 125
# collision sf node 35 and node 53
# CHECK node 29 (sf:12 bw:125 freq:8.600021e+08) others: 1
# >> node 40 (sf:12 bw:125 freq:8.600049e+08)
# no frequency coll
# CHECK node 9 (sf:12 bw:125 freq:8.600029e+08) others: 2
# >> node 40 (sf:12 bw:125 freq:8.600049e+08)
# no frequency coll
# >> node 29 (sf:12 bw:125 freq:8.600021e+08)
# no frequency coll
# CHECK node 66 (sf:12 bw:125 freq:8.600005e+08) others: 1
# >> node 50 (sf:12 bw:125 freq:8.600034e+08)
# no frequency coll
# CHECK node 27 (sf:12 bw:125 freq:8.600064e+08) others: 1
# >> node 32 (sf:12 bw:125 freq:8.600031e+08)
# no frequency coll
# CHECK node 48 (sf:12 bw:125 freq:8.600038e+08) others: 1
# >> node 49 (sf:12 bw:125 freq:8.600034e+08)
# no frequency coll
# CHECK node 67 (sf:12 bw:125 freq:8.600056e+08) others: 1
# >> node 57 (sf:12 bw:125 freq:8.600021e+08)
# no frequency coll
# CHECK node 32 (sf:12 bw:125 freq:8.600031e+08) others: 1
# >> node 56 (sf:12 bw:125 freq:8.600030e+08)
# no frequency coll
# CHECK node 2 (sf:12 bw:125 freq:8.600010e+08) others: 1
# >> node 34 (sf:12 bw:125 freq:8.600031e+08)
# no frequency coll
# CHECK node 61 (sf:12 bw:125 freq:8.600022e+08) others: 1
# >> node 18 (sf:12 bw:125 freq:8.600034e+08)
# no frequency coll
# CHECK node 33 (sf:12 bw:125 freq:8.600010e+08) others: 1
# >> node 31 (sf:12 bw:125 freq:8.600022e+08)
# no frequency coll
# CHECK node 3 (sf:12 bw:125 freq:8.600045e+08) others: 1
# >> node 33 (sf:12 bw:125 freq:8.600010e+08)
# no frequency coll
# CHECK node 52 (sf:12 bw:125 freq:8.600045e+08) others: 2
# >> node 33 (sf:12 bw:125 freq:8.600010e+08)
# no frequency coll
# >> node 3 (sf:12 bw:125 freq:8.600045e+08)
# frequency coll 125
# collision sf node 52 and node 3
# CHECK node 4 (sf:12 bw:125 freq:8.600052e+08) others: 1
# >> node 64 (sf:12 bw:125 freq:8.600046e+08)
# no frequency coll
# CHECK node 59 (sf:12 bw:125 freq:8.600009e+08) others: 1
# >> node 55 (sf:12 bw:125 freq:8.600015e+08)
# no frequency coll
# CHECK node 27 (sf:12 bw:125 freq:8.600064e+08) others: 1
# >> node 7 (sf:12 bw:125 freq:8.600062e+08)
# no frequency coll
# CHECK node 43 (sf:12 bw:125 freq:8.600072e+08) others: 1
# >> node 12 (sf:12 bw:125 freq:8.600061e+08)
# no frequency coll
# CHECK node 42 (sf:12 bw:125 freq:8.600051e+08) others: 1
# >> node 37 (sf:12 bw:125 freq:8.600006e+08)
# no frequency coll
# CHECK node 68 (sf:12 bw:125 freq:8.600040e+08) others: 1
# >> node 32 (sf:12 bw:125 freq:8.600031e+08)
# no frequency coll
# CHECK node 50 (sf:12 bw:125 freq:8.600034e+08) others: 1
# >> node 6 (sf:12 bw:125 freq:8.600059e+08)
# no frequency coll
# CHECK node 60 (sf:12 bw:125 freq:8.600065e+08) others: 1
# >> node 23 (sf:12 bw:125 freq:8.600041e+08)
# no frequency coll
# CHECK node 1 (sf:12 bw:125 freq:8.600058e+08) others: 1
# >> node 20 (sf:12 bw:125 freq:8.600054e+08)
# no frequency coll
# CHECK node 16 (sf:12 bw:125 freq:8.600080e+08) others: 1
# >> node 3 (sf:12 bw:125 freq:8.600045e+08)
# no frequency coll
# CHECK node 49 (sf:12 bw:125 freq:8.600034e+08) others: 1
# >> node 4 (sf:12 bw:125 freq:8.600052e+08)
# no frequency coll
# CHECK node 25 (sf:12 bw:125 freq:8.600041e+08) others: 1
# >> node 9 (sf:12 bw:125 freq:8.600029e+08)
# no frequency coll
# CHECK node 56 (sf:12 bw:125 freq:8.600030e+08) others: 1
# >> node 3 (sf:12 bw:125 freq:8.600045e+08)
# no frequency coll
# CHECK node 8 (sf:12 bw:125 freq:8.600018e+08) others: 1
# >> node 24 (sf:12 bw:125 freq:8.600078e+08)
# no frequency coll
# CHECK node 16 (sf:12 bw:125 freq:8.600080e+08) others: 1
# >> node 6 (sf:12 bw:125 freq:8.600059e+08)
# no frequency coll
# CHECK node 39 (sf:12 bw:125 freq:8.600040e+08) others: 1
# >> node 18 (sf:12 bw:125 freq:8.600034e+08)
# no frequency coll
# CHECK node 62 (sf:12 bw:125 freq:8.600065e+08) others: 1
# >> node 11 (sf:12 bw:125 freq:8.600072e+08)
# no frequency coll
# CHECK node 40 (sf:12 bw:125 freq:8.600049e+08) others: 1
# >> node 60 (sf:12 bw:125 freq:8.600065e+08)
# no frequency coll
# CHECK node 62 (sf:12 bw:125 freq:8.600065e+08) others: 1
# >> node 4 (sf:12 bw:125 freq:8.600052e+08)
# no frequency coll
# CHECK node 14 (sf:12 bw:125 freq:8.600048e+08) others: 1
# >> node 3 (sf:12 bw:125 freq:8.600045e+08)
# no frequency coll
# CHECK node 5 (sf:12 bw:125 freq:8.600015e+08) others: 1
# >> node 35 (sf:12 bw:125 freq:8.600025e+08)
# no frequency coll
# CHECK node 59 (sf:12 bw:125 freq:8.600009e+08) others: 1
# >> node 52 (sf:12 bw:125 freq:8.600045e+08)
# no frequency coll
# CHECK node 17 (sf:12 bw:125 freq:8.600025e+08) others: 1
# >> node 0 (sf:12 bw:125 freq:8.600026e+08)
# no frequency coll
# CHECK node 36 (sf:12 bw:125 freq:8.600071e+08) others: 1
# >> node 14 (sf:12 bw:125 freq:8.600048e+08)
# no frequency coll
# CHECK node 14 (sf:12 bw:125 freq:8.600048e+08) others: 1
# >> node 18 (sf:12 bw:125 freq:8.600034e+08)
# no frequency coll
# CHECK node 5 (sf:12 bw:125 freq:8.600015e+08) others: 1
# >> node 44 (sf:12 bw:125 freq:8.600070e+08)
# no frequency coll
# CHECK node 59 (sf:12 bw:125 freq:8.600009e+08) others: 1
# >> node 13 (sf:12 bw:125 freq:8.600054e+08)
# no frequency coll
# CHECK node 26 (sf:12 bw:125 freq:8.600029e+08) others: 1
# >> node 5 (sf:12 bw:125 freq:8.600015e+08)
# no frequency coll
# CHECK node 16 (sf:12 bw:125 freq:8.600080e+08) others: 1
# >> node 30 (sf:12 bw:125 freq:8.600001e+08)
# no frequency coll
# CHECK node 43 (sf:12 bw:125 freq:8.600072e+08) others: 1
# >> node 1 (sf:12 bw:125 freq:8.600058e+08)
# no frequency coll
# CHECK node 41 (sf:12 bw:125 freq:8.600080e+08) others: 1
# >> node 42 (sf:12 bw:125 freq:8.600051e+08)
# no frequency coll
# CHECK node 57 (sf:12 bw:125 freq:8.600021e+08) others: 1
# >> node 46 (sf:12 bw:125 freq:8.600012e+08)
# no frequency coll
# CHECK node 54 (sf:12 bw:125 freq:8.600018e+08) others: 1
# >> node 36 (sf:12 bw:125 freq:8.600071e+08)
# no frequency coll
# CHECK node 62 (sf:12 bw:125 freq:8.600065e+08) others: 1
# >> node 13 (sf:12 bw:125 freq:8.600054e+08)
# no frequency coll
# CHECK node 31 (sf:12 bw:125 freq:8.600022e+08) others: 1
# >> node 0 (sf:12 bw:125 freq:8.600026e+08)
# no frequency coll
# CHECK node 56 (sf:12 bw:125 freq:8.600030e+08) others: 1
# >> node 50 (sf:12 bw:125 freq:8.600034e+08)
# no frequency coll
# CHECK node 32 (sf:12 bw:125 freq:8.600031e+08) others: 1
# >> node 10 (sf:12 bw:125 freq:8.600072e+08)
# no frequency coll
# CHECK node 38 (sf:12 bw:125 freq:8.600018e+08) others: 1
# >> node 27 (sf:12 bw:125 freq:8.600064e+08)
# no frequency coll
# CHECK node 60 (sf:12 bw:125 freq:8.600065e+08) others: 1
# >> node 53 (sf:12 bw:125 freq:8.600025e+08)
# no frequency coll
# CHECK node 48 (sf:12 bw:125 freq:8.600038e+08) others: 1
# >> node 50 (sf:12 bw:125 freq:8.600034e+08)
# no frequency coll
# CHECK node 29 (sf:12 bw:125 freq:8.600021e+08) others: 1
# >> node 38 (sf:12 bw:125 freq:8.600018e+08)
# no frequency coll
# CHECK node 60 (sf:12 bw:125 freq:8.600065e+08) others: 1
# >> node 67 (sf:12 bw:125 freq:8.600056e+08)
# no frequency coll
# CHECK node 22 (sf:12 bw:125 freq:8.600024e+08) others: 1
# >> node 38 (sf:12 bw:125 freq:8.600018e+08)
# no frequency coll
# CHECK node 35 (sf:12 bw:125 freq:8.600025e+08) others: 1
# >> node 26 (sf:12 bw:125 freq:8.600029e+08)
# no frequency coll
# CHECK node 1 (sf:12 bw:125 freq:8.600058e+08) others: 2
# >> node 26 (sf:12 bw:125 freq:8.600029e+08)
# no frequency coll
# >> node 35 (sf:12 bw:125 freq:8.600025e+08)
# no frequency coll
# CHECK node 24 (sf:12 bw:125 freq:8.600078e+08) others: 1
# >> node 2 (sf:12 bw:125 freq:8.600010e+08)
# no frequency coll
# CHECK node 24 (sf:12 bw:125 freq:8.600078e+08) others: 1
# >> node 67 (sf:12 bw:125 freq:8.600056e+08)
# no frequency coll
# CHECK node 7 (sf:12 bw:125 freq:8.600062e+08) others: 1
# >> node 25 (sf:12 bw:125 freq:8.600041e+08)
# no frequency coll
# CHECK node 11 (sf:12 bw:125 freq:8.600072e+08) others: 1
# >> node 69 (sf:12 bw:125 freq:8.600058e+08)
# no frequency coll
# CHECK node 4 (sf:12 bw:125 freq:8.600052e+08) others: 1
# >> node 24 (sf:12 bw:125 freq:8.600078e+08)
# no frequency coll
# CHECK node 32 (sf:12 bw:125 freq:8.600031e+08) others: 1
# >> node 42 (sf:12 bw:125 freq:8.600051e+08)
# no frequency coll
# CHECK node 36 (sf:12 bw:125 freq:8.600071e+08) others: 1
# >> node 47 (sf:12 bw:125 freq:8.600028e+08)
# no frequency coll
# CHECK node 17 (sf:12 bw:125 freq:8.600025e+08) others: 1
# >> node 44 (sf:12 bw:125 freq:8.600070e+08)
# no frequency coll
# CHECK node 4 (sf:12 bw:125 freq:8.600052e+08) others: 1
# >> node 13 (sf:12 bw:125 freq:8.600054e+08)
# no frequency coll
# CHECK node 41 (sf:12 bw:125 freq:8.600080e+08) others: 2
# >> node 13 (sf:12 bw:125 freq:8.600054e+08)
# no frequency coll
# >> node 4 (sf:12 bw:125 freq:8.600052e+08)
# no frequency coll
# CHECK node 20 (sf:12 bw:125 freq:8.600054e+08) others: 1
# >> node 13 (sf:12 bw:125 freq:8.600054e+08)
# frequency coll 125
# collision sf node 20 and node 13
# CHECK node 37 (sf:12 bw:125 freq:8.600006e+08) others: 1
# >> node 20 (sf:12 bw:125 freq:8.600054e+08)
# no frequency coll
# CHECK node 28 (sf:12 bw:125 freq:8.600044e+08) others: 1
# >> node 37 (sf:12 bw:125 freq:8.600006e+08)
# no frequency coll
# CHECK node 56 (sf:12 bw:125 freq:8.600030e+08) others: 1
# >> node 25 (sf:12 bw:125 freq:8.600041e+08)
# no frequency coll
# CHECK node 11 (sf:12 bw:125 freq:8.600072e+08) others: 1
# >> node 40 (sf:12 bw:125 freq:8.600049e+08)
# no frequency coll
# CHECK node 66 (sf:12 bw:125 freq:8.600005e+08) others: 1
# >> node 12 (sf:12 bw:125 freq:8.600061e+08)
# no frequency coll
# CHECK node 20 (sf:12 bw:125 freq:8.600054e+08) others: 1
# >> node 4 (sf:12 bw:125 freq:8.600052e+08)
# no frequency coll
# CHECK node 22 (sf:12 bw:125 freq:8.600024e+08) others: 1
# >> node 29 (sf:12 bw:125 freq:8.600021e+08)
# no frequency coll
# CHECK node 8 (sf:12 bw:125 freq:8.600018e+08) others: 1
# >> node 36 (sf:12 bw:125 freq:8.600071e+08)
# no frequency coll
# CHECK node 14 (sf:12 bw:125 freq:8.600048e+08) others: 1
# >> node 62 (sf:12 bw:125 freq:8.600065e+08)
# no frequency coll
# CHECK node 32 (sf:12 bw:125 freq:8.600031e+08) others: 1
# >> node 0 (sf:12 bw:125 freq:8.600026e+08)
# no frequency coll
# CHECK node 13 (sf:12 bw:125 freq:8.600054e+08) others: 1
# >> node 46 (sf:12 bw:125 freq:8.600012e+08)
# no frequency coll
# CHECK node 69 (sf:12 bw:125 freq:8.600058e+08) others: 2
# >> node 46 (sf:12 bw:125 freq:8.600012e+08)
# no frequency coll
# >> node 13 (sf:12 bw:125 freq:8.600054e+08)
# no frequency coll
# CHECK node 51 (sf:12 bw:125 freq:8.600059e+08) others: 1
# >> node 67 (sf:12 bw:125 freq:8.600056e+08)
# no frequency coll
# CHECK node 35 (sf:12 bw:125 freq:8.600025e+08) others: 1
# >> node 68 (sf:12 bw:125 freq:8.600040e+08)
# no frequency coll
# CHECK node 5 (sf:12 bw:125 freq:8.600015e+08) others: 1
# >> node 4 (sf:12 bw:125 freq:8.600052e+08)
# no frequency coll
# CHECK node 0 (sf:12 bw:125 freq:8.600026e+08) others: 1
# >> node 5 (sf:12 bw:125 freq:8.600015e+08)
# no frequency coll
# CHECK node 11 (sf:12 bw:125 freq:8.600072e+08) others: 1
# >> node 61 (sf:12 bw:125 freq:8.600022e+08)
# no frequency coll
# CHECK node 58 (sf:12 bw:125 freq:8.600022e+08) others: 1
# >> node 11 (sf:12 bw:125 freq:8.600072e+08)
# no frequency coll
# CHECK node 18 (sf:12 bw:125 freq:8.600034e+08) others: 1
# >> node 15 (sf:12 bw:125 freq:8.600002e+08)
# no frequency coll
# CHECK node 28 (sf:12 bw:125 freq:8.600044e+08) others: 1
# >> node 53 (sf:12 bw:125 freq:8.600025e+08)
# no frequency coll
# CHECK node 12 (sf:12 bw:125 freq:8.600061e+08) others: 1
# >> node 63 (sf:12 bw:125 freq:8.600076e+08)
# no frequency coll
# CHECK node 61 (sf:12 bw:125 freq:8.600022e+08) others: 1
# >> node 44 (sf:12 bw:125 freq:8.600070e+08)
# no frequency coll
# CHECK node 26 (sf:12 bw:125 freq:8.600029e+08) others: 1
# >> node 4 (sf:12 bw:125 freq:8.600052e+08)
# no frequency coll
# CHECK node 25 (sf:12 bw:125 freq:8.600041e+08) others: 1
# >> node 66 (sf:12 bw:125 freq:8.600005e+08)
# no frequency coll
# CHECK node 9 (sf:12 bw:125 freq:8.600029e+08) others: 1
# >> node 48 (sf:12 bw:125 freq:8.600038e+08)
# no frequency coll
# CHECK node 3 (sf:12 bw:125 freq:8.600045e+08) others: 1
# >> node 8 (sf:12 bw:125 freq:8.600018e+08)
# no frequency coll
# CHECK node 32 (sf:12 bw:125 freq:8.600031e+08) others: 1
# >> node 46 (sf:12 bw:125 freq:8.600012e+08)
# no frequency coll
# CHECK node 15 (sf:12 bw:125 freq:8.600002e+08) others: 1
# >> node 46 (sf:12 bw:125 freq:8.600012e+08)
# no frequency coll
# CHECK node 29 (sf:12 bw:125 freq:8.600021e+08) others: 1
# >> node 67 (sf:12 bw:125 freq:8.600056e+08)
# no frequency coll
# CHECK node 43 (sf:12 bw:125 freq:8.600072e+08) others: 1
# >> node 48 (sf:12 bw:125 freq:8.600038e+08)
# no frequency coll
# CHECK node 37 (sf:12 bw:125 freq:8.600006e+08) others: 1
# >> node 57 (sf:12 bw:125 freq:8.600021e+08)
# no frequency coll
# CHECK node 17 (sf:12 bw:125 freq:8.600025e+08) others: 1
# >> node 9 (sf:12 bw:125 freq:8.600029e+08)
# no frequency coll
# CHECK node 47 (sf:12 bw:125 freq:8.600028e+08) others: 1
# >> node 8 (sf:12 bw:125 freq:8.600018e+08)
# no frequency coll
# CHECK node 16 (sf:12 bw:125 freq:8.600080e+08) others: 1
# >> node 59 (sf:12 bw:125 freq:8.600009e+08)
# no frequency coll
# CHECK node 58 (sf:12 bw:125 freq:8.600022e+08) others: 1
# >> node 15 (sf:12 bw:125 freq:8.600002e+08)
# no frequency coll
# CHECK node 35 (sf:12 bw:125 freq:8.600025e+08) others: 1
# >> node 42 (sf:12 bw:125 freq:8.600051e+08)
# no frequency coll
# CHECK node 3 (sf:12 bw:125 freq:8.600045e+08) others: 1
# >> node 52 (sf:12 bw:125 freq:8.600045e+08)
# frequency coll 125
# collision sf node 3 and node 52
# CHECK node 32 (sf:12 bw:125 freq:8.600031e+08) others: 1
# >> node 31 (sf:12 bw:125 freq:8.600022e+08)
# no frequency coll
# CHECK node 57 (sf:12 bw:125 freq:8.600021e+08) others: 1
# >> node 54 (sf:12 bw:125 freq:8.600018e+08)
# no frequency coll
# CHECK node 23 (sf:12 bw:125 freq:8.600041e+08) others: 1
# >> node 28 (sf:12 bw:125 freq:8.600044e+08)
# no frequency coll
# CHECK node 64 (sf:12 bw:125 freq:8.600046e+08) others: 1
# >> node 59 (sf:12 bw:125 freq:8.600009e+08)
# no frequency coll
# CHECK node 50 (sf:12 bw:125 freq:8.600034e+08) others: 1
# >> node 57 (sf:12 bw:125 freq:8.600021e+08)
# no frequency coll
# CHECK node 64 (sf:12 bw:125 freq:8.600046e+08) others: 1
# >> node 41 (sf:12 bw:125 freq:8.600080e+08)
# no frequency coll
# CHECK node 0 (sf:12 bw:125 freq:8.600026e+08) others: 1
# >> node 55 (sf:12 bw:125 freq:8.600015e+08)
# no frequency coll
# CHECK node 52 (sf:12 bw:125 freq:8.600045e+08) others: 1
# >> node 16 (sf:12 bw:125 freq:8.600080e+08)
# no frequency coll
# CHECK node 32 (sf:12 bw:125 freq:8.600031e+08) others: 1
# >> node 24 (sf:12 bw:125 freq:8.600078e+08)
# no frequency coll
# CHECK node 63 (sf:12 bw:125 freq:8.600076e+08) others: 1
# >> node 32 (sf:12 bw:125 freq:8.600031e+08)
# no frequency coll
# CHECK node 40 (sf:12 bw:125 freq:8.600049e+08) others: 1
# >> node 63 (sf:12 bw:125 freq:8.600076e+08)
# no frequency coll
# CHECK node 63 (sf:12 bw:125 freq:8.600076e+08) others: 1
# >> node 12 (sf:12 bw:125 freq:8.600061e+08)
# no frequency coll
# CHECK node 64 (sf:12 bw:125 freq:8.600046e+08) others: 1
# >> node 59 (sf:12 bw:125 freq:8.600009e+08)
# no frequency coll
# CHECK node 57 (sf:12 bw:125 freq:8.600021e+08) others: 1
# >> node 42 (sf:12 bw:125 freq:8.600051e+08)
# no frequency coll
# CHECK node 59 (sf:12 bw:125 freq:8.600009e+08) others: 1
# >> node 48 (sf:12 bw:125 freq:8.600038e+08)
# no frequency coll
# CHECK node 40 (sf:12 bw:125 freq:8.600049e+08) others: 1
# >> node 26 (sf:12 bw:125 freq:8.600029e+08)
# no frequency coll
# CHECK node 37 (sf:12 bw:125 freq:8.600006e+08) others: 1
# >> node 52 (sf:12 bw:125 freq:8.600045e+08)
# no frequency coll
# CHECK node 23 (sf:12 bw:125 freq:8.600041e+08) others: 1
# >> node 1 (sf:12 bw:125 freq:8.600058e+08)
# no frequency coll
# CHECK node 3 (sf:12 bw:125 freq:8.600045e+08) others: 1
# >> node 10 (sf:12 bw:125 freq:8.600072e+08)
# no frequency coll
# CHECK node 45 (sf:12 bw:125 freq:8.600078e+08) others: 1
# >> node 27 (sf:12 bw:125 freq:8.600064e+08)
# no frequency coll
# CHECK node 54 (sf:12 bw:125 freq:8.600018e+08) others: 1
# >> node 55 (sf:12 bw:125 freq:8.600015e+08)
# no frequency coll
# CHECK node 21 (sf:12 bw:125 freq:8.600056e+08) others: 1
# >> node 69 (sf:12 bw:125 freq:8.600058e+08)
# no frequency coll
# CHECK node 43 (sf:12 bw:125 freq:8.600072e+08) others: 1
# >> node 42 (sf:12 bw:125 freq:8.600051e+08)
# no frequency coll
# CHECK node 4 (sf:12 bw:125 freq:8.600052e+08) others: 1
# >> node 33 (sf:12 bw:125 freq:8.600010e+08)
# no frequency coll
# CHECK node 12 (sf:12 bw:125 freq:8.600061e+08) others: 1
# >> node 52 (sf:12 bw:125 freq:8.600045e+08)
# no frequency coll
# CHECK node 52 (sf:12 bw:125 freq:8.600045e+08) others: 1
# >> node 29 (sf:12 bw:125 freq:8.600021e+08)
# no frequency coll
# CHECK node 43 (sf:12 bw:125 freq:8.600072e+08) others: 1
# >> node 66 (sf:12 bw:125 freq:8.600005e+08)
# no frequency coll
# CHECK node 63 (sf:12 bw:125 freq:8.600076e+08) others: 1
# >> node 31 (sf:12 bw:125 freq:8.600022e+08)
# no frequency coll
# CHECK node 3 (sf:12 bw:125 freq:8.600045e+08) others: 1
# >> node 62 (sf:12 bw:125 freq:8.600065e+08)
# no frequency coll
# CHECK node 52 (sf:12 bw:125 freq:8.600045e+08) others: 1
# >> node 3 (sf:12 bw:125 freq:8.600045e+08)
# frequency coll 125
# collision sf node 52 and node 3
# CHECK node 25 (sf:12 bw:125 freq:8.600041e+08) others: 1
# >> node 52 (sf:12 bw:125 freq:8.600045e+08)
# no frequency coll
# CHECK node 52 (sf:12 bw:125 freq:8.600045e+08) others: 1
# >> node 8 (sf:12 bw:125 freq:8.600018e+08)
# no frequency coll
# CHECK node 42 (sf:12 bw:125 freq:8.600051e+08) others: 1
# >> node 48 (sf:12 bw:125 freq:8.600038e+08)
# no frequency coll
# CHECK node 48 (sf:12 bw:125 freq:8.600038e+08) others: 1
# >> node 3 (sf:12 bw:125 freq:8.600045e+08)
# no frequency coll
# CHECK node 41 (sf:12 bw:125 freq:8.600080e+08) others: 1
# >> node 69 (sf:12 bw:125 freq:8.600058e+08)
# no frequency coll
# CHECK node 9 (sf:12 bw:125 freq:8.600029e+08) others: 1
# >> node 22 (sf:12 bw:125 freq:8.600024e+08)
# no frequency coll
# CHECK node 48 (sf:12 bw:125 freq:8.600038e+08) others: 1
# >> node 33 (sf:12 bw:125 freq:8.600010e+08)
# no frequency coll
# CHECK node 44 (sf:12 bw:125 freq:8.600070e+08) others: 1
# >> node 36 (sf:12 bw:125 freq:8.600071e+08)
# no frequency coll
# CHECK node 36 (sf:12 bw:125 freq:8.600071e+08) others: 1
# >> node 39 (sf:12 bw:125 freq:8.600040e+08)
# no frequency coll
# CHECK node 7 (sf:12 bw:125 freq:8.600062e+08) others: 1
# >> node 14 (sf:12 bw:125 freq:8.600048e+08)
# no frequency coll
# CHECK node 61 (sf:12 bw:125 freq:8.600022e+08) others: 1
# >> node 45 (sf:12 bw:125 freq:8.600078e+08)
# no frequency coll
# CHECK node 52 (sf:12 bw:125 freq:8.600045e+08) others: 1
# >> node 13 (sf:12 bw:125 freq:8.600054e+08)
# no frequency coll
# CHECK node 46 (sf:12 bw:125 freq:8.600012e+08) others: 1
# >> node 11 (sf:12 bw:125 freq:8.600072e+08)
# no frequency coll
# CHECK node 45 (sf:12 bw:125 freq:8.600078e+08) others: 1
# >> node 42 (sf:12 bw:125 freq:8.600051e+08)
# ...
# >> node 16 (sf:12 bw:125 freq:8.600080e+08)
# no frequency coll
# >> node 11 (sf:12 bw:125 freq:8.600072e+08)
# no frequency coll
# CHECK node 65 (sf:12 bw:125 freq:8.600024e+08) others: 1
# >> node 44 (sf:12 bw:125 freq:8.600070e+08)
# no frequency coll
# CHECK node 7 (sf:12 bw:125 freq:8.600062e+08) others: 1
# >> node 4 (sf:12 bw:125 freq:8.600052e+08)
# no frequency coll
# CHECK node 35 (sf:12 bw:125 freq:8.600025e+08) others: 1
# >> node 27 (sf:12 bw:125 freq:8.600064e+08)
# no frequency coll
# CHECK node 66 (sf:12 bw:125 freq:8.600005e+08) others: 1
# >> node 55 (sf:12 bw:125 freq:8.600015e+08)
# no frequency coll
# CHECK node 56 (sf:12 bw:125 freq:8.600030e+08) others: 1
# >> node 5 (sf:12 bw:125 freq:8.600015e+08)
# no frequency coll
# CHECK node 53 (sf:12 bw:125 freq:8.600025e+08) others: 1
# >> node 65 (sf:12 bw:125 freq:8.600024e+08)
# no frequency coll
# CHECK node 54 (sf:12 bw:125 freq:8.600018e+08) others: 1
# >> node 68 (sf:12 bw:125 freq:8.600040e+08)
# no frequency coll
# CHECK node 22 (sf:12 bw:125 freq:8.600024e+08) others: 1
# >> node 1 (sf:12 bw:125 freq:8.600058e+08)
# no frequency coll
# CHECK node 36 (sf:12 bw:125 freq:8.600071e+08) others: 1
# >> node 8 (sf:12 bw:125 freq:8.600018e+08)
# no frequency coll
# CHECK node 32 (sf:12 bw:125 freq:8.600031e+08) others: 1
# >> node 63 (sf:12 bw:125 freq:8.600076e+08)
# no frequency coll
# CHECK node 45 (sf:12 bw:125 freq:8.600078e+08) others: 1
# >> node 46 (sf:12 bw:125 freq:8.600012e+08)
# no frequency coll
# CHECK node 21 (sf:12 bw:125 freq:8.600056e+08) others: 1
# >> node 0 (sf:12 bw:125 freq:8.600026e+08)
# no frequency coll
# CHECK node 48 (sf:12 bw:125 freq:8.600038e+08) others: 1
# >> node 68 (sf:12 bw:125 freq:8.600040e+08)
# no frequency coll
# CHECK node 31 (sf:12 bw:125 freq:8.600022e+08) others: 2
# >> node 68 (sf:12 bw:125 freq:8.600040e+08)
# no frequency coll
# >> node 48 (sf:12 bw:125 freq:8.600038e+08)
# no frequency coll
# CHECK node 34 (sf:12 bw:125 freq:8.600031e+08) others: 3
# >> node 68 (sf:12 bw:125 freq:8.600040e+08)
# no frequency coll
# >> node 48 (sf:12 bw:125 freq:8.600038e+08)
# no frequency coll
# >> node 31 (sf:12 bw:125 freq:8.600022e+08)
# no frequency coll
# CHECK node 9 (sf:12 bw:125 freq:8.600029e+08) others: 1
# >> node 64 (sf:12 bw:125 freq:8.600046e+08)
# no frequency coll
# CHECK node 62 (sf:12 bw:125 freq:8.600065e+08) others: 2
# >> node 64 (sf:12 bw:125 freq:8.600046e+08)
# no frequency coll
# >> node 9 (sf:12 bw:125 freq:8.600029e+08)
# no frequency coll
# CHECK node 37 (sf:12 bw:125 freq:8.600006e+08) others: 1
# >> node 13 (sf:12 bw:125 freq:8.600054e+08)
# no frequency coll
# CHECK node 52 (sf:12 bw:125 freq:8.600045e+08) others: 1
# >> node 15 (sf:12 bw:125 freq:8.600002e+08)
# no frequency coll
# CHECK node 46 (sf:12 bw:125 freq:8.600012e+08) others: 1
# >> node 39 (sf:12 bw:125 freq:8.600040e+08)
# no frequency coll
# CHECK node 3 (sf:12 bw:125 freq:8.600045e+08) others: 1
# >> node 7 (sf:12 bw:125 freq:8.600062e+08)
# no frequency coll
# CHECK node 67 (sf:12 bw:125 freq:8.600056e+08) others: 1
# >> node 8 (sf:12 bw:125 freq:8.600018e+08)
# no frequency coll
# CHECK node 45 (sf:12 bw:125 freq:8.600078e+08) others: 1
# >> node 28 (sf:12 bw:125 freq:8.600044e+08)
# no frequency coll
# CHECK node 66 (sf:12 bw:125 freq:8.600005e+08) others: 1
# >> node 43 (sf:12 bw:125 freq:8.600072e+08)
# no frequency coll
# CHECK node 20 (sf:12 bw:125 freq:8.600054e+08) others: 1
# >> node 54 (sf:12 bw:125 freq:8.600018e+08)
# no frequency coll
# CHECK node 18 (sf:12 bw:125 freq:8.600034e+08) others: 1
# >> node 36 (sf:12 bw:125 freq:8.600071e+08)
# no frequency coll
# CHECK node 27 (sf:12 bw:125 freq:8.600064e+08) others: 1
# >> node 13 (sf:12 bw:125 freq:8.600054e+08)
# no frequency coll
# CHECK node 64 (sf:12 bw:125 freq:8.600046e+08) others: 1
# >> node 38 (sf:12 bw:125 freq:8.600018e+08)
# no frequency coll
# CHECK node 4 (sf:12 bw:125 freq:8.600052e+08) others: 1
# >> node 35 (sf:12 bw:125 freq:8.600025e+08)
# no frequency coll
# CHECK node 68 (sf:12 bw:125 freq:8.600040e+08) others: 1
# >> node 8 (sf:12 bw:125 freq:8.600018e+08)
# no frequency coll
# CHECK node 21 (sf:12 bw:125 freq:8.600056e+08) others: 1
# >> node 51 (sf:12 bw:125 freq:8.600059e+08)
# no frequency coll
# CHECK node 40 (sf:12 bw:125 freq:8.600049e+08) others: 1
# >> node 23 (sf:12 bw:125 freq:8.600041e+08)
# no frequency coll
# CHECK node 25 (sf:12 bw:125 freq:8.600041e+08) others: 1
# >> node 14 (sf:12 bw:125 freq:8.600048e+08)
# no frequency coll
# CHECK node 28 (sf:12 bw:125 freq:8.600044e+08) others: 1
# >> node 38 (sf:12 bw:125 freq:8.600018e+08)
# no frequency coll
# CHECK node 50 (sf:12 bw:125 freq:8.600034e+08) others: 1
# >> node 0 (sf:12 bw:125 freq:8.600026e+08)
# no frequency coll
# CHECK node 47 (sf:12 bw:125 freq:8.600028e+08) others: 2
# >> node 0 (sf:12 bw:125 freq:8.600026e+08)
# no frequency coll
# >> node 50 (sf:12 bw:125 freq:8.600034e+08)
# no frequency coll
# CHECK node 50 (sf:12 bw:125 freq:8.600034e+08) others: 1
# >> node 63 (sf:12 bw:125 freq:8.600076e+08)
# no frequency coll
# CHECK node 21 (sf:12 bw:125 freq:8.600056e+08) others: 1
# >> node 23 (sf:12 bw:125 freq:8.600041e+08)
# no frequency coll
# CHECK node 14 (sf:12 bw:125 freq:8.600048e+08) others: 1
# >> node 0 (sf:12 bw:125 freq:8.600026e+08)
# no frequency coll
# CHECK node 19 (sf:12 bw:125 freq:8.600009e+08) others: 2
# >> node 0 (sf:12 bw:125 freq:8.600026e+08)
# no frequency coll
# >> node 14 (sf:12 bw:125 freq:8.600048e+08)
# no frequency coll
# CHECK node 66 (sf:12 bw:125 freq:8.600005e+08) others: 1
# >> node 55 (sf:12 bw:125 freq:8.600015e+08)
# no frequency coll
# CHECK node 61 (sf:12 bw:125 freq:8.600022e+08) others: 1
# >> node 39 (sf:12 bw:125 freq:8.600040e+08)
# no frequency coll
# CHECK node 32 (sf:12 bw:125 freq:8.600031e+08) others: 1
# >> node 51 (sf:12 bw:125 freq:8.600059e+08)
# no frequency coll
# CHECK node 45 (sf:12 bw:125 freq:8.600078e+08) others: 1
# >> node 50 (sf:12 bw:125 freq:8.600034e+08)
# no frequency coll
# CHECK node 12 (sf:12 bw:125 freq:8.600061e+08) others: 1
# >> node 22 (sf:12 bw:125 freq:8.600024e+08)
# no frequency coll
# CHECK node 17 (sf:12 bw:125 freq:8.600025e+08) others: 1
# >> node 18 (sf:12 bw:125 freq:8.600034e+08)
# no frequency coll
# CHECK node 3 (sf:12 bw:125 freq:8.600045e+08) others: 2
# >> node 18 (sf:12 bw:125 freq:8.600034e+08)
# no frequency coll
# >> node 17 (sf:12 bw:125 freq:8.600025e+08)
# no frequency coll
# CHECK node 2 (sf:12 bw:125 freq:8.600010e+08) others: 1
# >> node 1 (sf:12 bw:125 freq:8.600058e+08)
# no frequency coll
# CHECK node 36 (sf:12 bw:125 freq:8.600071e+08) others: 1
# >> node 45 (sf:12 bw:125 freq:8.600078e+08)
# no frequency coll
# CHECK node 5 (sf:12 bw:125 freq:8.600015e+08) others: 2
# >> node 45 (sf:12 bw:125 freq:8.600078e+08)
# no frequency coll
# >> node 36 (sf:12 bw:125 freq:8.600071e+08)
# no frequency coll
# CHECK node 32 (sf:12 bw:125 freq:8.600031e+08) others: 3
# >> node 45 (sf:12 bw:125 freq:8.600078e+08)
# no frequency coll
# >> node 36 (sf:12 bw:125 freq:8.600071e+08)
# no frequency coll
# >> node 5 (sf:12 bw:125 freq:8.600015e+08)
# no frequency coll
# CHECK node 25 (sf:12 bw:125 freq:8.600041e+08) others: 1
# >> node 57 (sf:12 bw:125 freq:8.600021e+08)
# no frequency coll
# CHECK node 61 (sf:12 bw:125 freq:8.600022e+08) others: 1
# >> node 26 (sf:12 bw:125 freq:8.600029e+08)
# no frequency coll
# CHECK node 33 (sf:12 bw:125 freq:8.600010e+08) others: 1
# >> node 4 (sf:12 bw:125 freq:8.600052e+08)
# no frequency coll
# CHECK node 42 (sf:12 bw:125 freq:8.600051e+08) others: 1
# >> node 18 (sf:12 bw:125 freq:8.600034e+08)
# no frequency coll
# CHECK node 69 (sf:12 bw:125 freq:8.600058e+08) others: 1
# >> node 19 (sf:12 bw:125 freq:8.600009e+08)
# no frequency coll
# CHECK node 25 (sf:12 bw:125 freq:8.600041e+08) others: 1
# >> node 11 (sf:12 bw:125 freq:8.600072e+08)
# no frequency coll
# CHECK node 63 (sf:12 bw:125 freq:8.600076e+08) others: 1
# >> node 61 (sf:12 bw:125 freq:8.600022e+08)
# no frequency coll
# CHECK node 33 (sf:12 bw:125 freq:8.600010e+08) others: 1
# >> node 14 (sf:12 bw:125 freq:8.600048e+08)
# no frequency coll
# CHECK node 6 (sf:12 bw:125 freq:8.600059e+08) others: 1
# >> node 35 (sf:12 bw:125 freq:8.600025e+08)
# no frequency coll
# CHECK node 2 (sf:12 bw:125 freq:8.600010e+08) others: 1
# >> node 62 (sf:12 bw:125 freq:8.600065e+08)
# no frequency coll
# CHECK node 53 (sf:12 bw:125 freq:8.600025e+08) others: 1
# >> node 31 (sf:12 bw:125 freq:8.600022e+08)
# no frequency coll
# CHECK node 10 (sf:12 bw:125 freq:8.600072e+08) others: 2
# >> node 31 (sf:12 bw:125 freq:8.600022e+08)
# no frequency coll
# >> node 53 (sf:12 bw:125 freq:8.600025e+08)
# no frequency coll
# CHECK node 18 (sf:12 bw:125 freq:8.600034e+08) others: 1
# >> node 53 (sf:12 bw:125 freq:8.600025e+08)
# no frequency coll
# CHECK node 39 (sf:12 bw:125 freq:8.600040e+08) others: 1
# >> node 32 (sf:12 bw:125 freq:8.600031e+08)
# no frequency coll
# CHECK node 30 (sf:12 bw:125 freq:8.600001e+08) others: 1
# >> node 2 (sf:12 bw:125 freq:8.600010e+08)
# no frequency coll
# CHECK node 62 (sf:12 bw:125 freq:8.600065e+08) others: 2
# >> node 2 (sf:12 bw:125 freq:8.600010e+08)
# no frequency coll
# >> node 30 (sf:12 bw:125 freq:8.600001e+08)
# no frequency coll
# CHECK node 29 (sf:12 bw:125 freq:8.600021e+08) others: 1
# >> node 6 (sf:12 bw:125 freq:8.600059e+08)
# no frequency coll
# CHECK node 58 (sf:12 bw:125 freq:8.600022e+08) others: 1
# >> node 66 (sf:12 bw:125 freq:8.600005e+08)
# no frequency coll
# CHECK node 17 (sf:12 bw:125 freq:8.600025e+08) others: 1
# >> node 44 (sf:12 bw:125 freq:8.600070e+08)
# no frequency coll
# CHECK node 25 (sf:12 bw:125 freq:8.600041e+08) others: 1
# >> node 44 (sf:12 bw:125 freq:8.600070e+08)
# no frequency coll
# CHECK node 17 (sf:12 bw:125 freq:8.600025e+08) others: 1
# >> node 32 (sf:12 bw:125 freq:8.600031e+08)
# no frequency coll
# CHECK node 17 (sf:12 bw:125 freq:8.600025e+08) others: 1
# >> node 4 (sf:12 bw:125 freq:8.600052e+08)
# no frequency coll
# CHECK node 36 (sf:12 bw:125 freq:8.600071e+08) others: 1
# >> node 35 (sf:12 bw:125 freq:8.600025e+08)
# no frequency coll
# CHECK node 36 (sf:12 bw:125 freq:8.600071e+08) others: 1
# >> node 57 (sf:12 bw:125 freq:8.600021e+08)
# no frequency coll
# CHECK node 16 (sf:12 bw:125 freq:8.600080e+08) others: 1
# >> node 8 (sf:12 bw:125 freq:8.600018e+08)
# no frequency coll
# CHECK node 68 (sf:12 bw:125 freq:8.600040e+08) others: 1
# >> node 64 (sf:12 bw:125 freq:8.600046e+08)
# no frequency coll
# CHECK node 34 (sf:12 bw:125 freq:8.600031e+08) others: 1
# >> node 39 (sf:12 bw:125 freq:8.600040e+08)
# no frequency coll
# CHECK node 5 (sf:12 bw:125 freq:8.600015e+08) others: 1
# >> node 35 (sf:12 bw:125 freq:8.600025e+08)
# no frequency coll
# CHECK node 54 (sf:12 bw:125 freq:8.600018e+08) others: 1
# >> node 10 (sf:12 bw:125 freq:8.600072e+08)
# no frequency coll
# CHECK node 0 (sf:12 bw:125 freq:8.600026e+08) others: 1
# >> node 9 (sf:12 bw:125 freq:8.600029e+08)
# no frequency coll
# CHECK node 8 (sf:12 bw:125 freq:8.600018e+08) others: 1
# >> node 18 (sf:12 bw:125 freq:8.600034e+08)
# no frequency coll
# CHECK node 5 (sf:12 bw:125 freq:8.600015e+08) others: 1
# >> node 31 (sf:12 bw:125 freq:8.600022e+08)
# no frequency coll
# CHECK node 66 (sf:12 bw:125 freq:8.600005e+08) others: 1
# >> node 22 (sf:12 bw:125 freq:8.600024e+08)
# no frequency coll
# CHECK node 29 (sf:12 bw:125 freq:8.600021e+08) others: 1
# >> node 30 (sf:12 bw:125 freq:8.600001e+08)
# no frequency coll
# CHECK node 7 (sf:12 bw:125 freq:8.600062e+08) others: 1
# >> node 29 (sf:12 bw:125 freq:8.600021e+08)
# no frequency coll
# CHECK node 13 (sf:12 bw:125 freq:8.600054e+08) others: 1
# >> node 35 (sf:12 bw:125 freq:8.600025e+08)
# no frequency coll
# CHECK node 44 (sf:12 bw:125 freq:8.600070e+08) others: 1
# >> node 43 (sf:12 bw:125 freq:8.600072e+08)
# no frequency coll
# CHECK node 49 (sf:12 bw:125 freq:8.600034e+08) others: 1
# >> node 43 (sf:12 bw:125 freq:8.600072e+08)
# no frequency coll
# CHECK node 47 (sf:12 bw:125 freq:8.600028e+08) others: 1
# >> node 51 (sf:12 bw:125 freq:8.600059e+08)
# no frequency coll
# CHECK node 27 (sf:12 bw:125 freq:8.600064e+08) others: 1
# >> node 47 (sf:12 bw:125 freq:8.600028e+08)
# no frequency coll
# CHECK node 28 (sf:12 bw:125 freq:8.600044e+08) others: 1
# >> node 27 (sf:12 bw:125 freq:8.600064e+08)
# no frequency coll
# CHECK node 0 (sf:12 bw:125 freq:8.600026e+08) others: 1
# >> node 38 (sf:12 bw:125 freq:8.600018e+08)
# no frequency coll
# CHECK node 20 (sf:12 bw:125 freq:8.600054e+08) others: 1
# >> node 39 (sf:12 bw:125 freq:8.600040e+08)
# no frequency coll
# CHECK node 38 (sf:12 bw:125 freq:8.600018e+08) others: 1
# >> node 20 (sf:12 bw:125 freq:8.600054e+08)
# no frequency coll
# CHECK node 52 (sf:12 bw:125 freq:8.600045e+08) others: 1
# >> node 38 (sf:12 bw:125 freq:8.600018e+08)
# no frequency coll
# CHECK node 53 (sf:12 bw:125 freq:8.600025e+08) others: 1
# >> node 17 (sf:12 bw:125 freq:8.600025e+08)
# frequency coll 125
# collision sf node 53 and node 17
# CHECK node 30 (sf:12 bw:125 freq:8.600001e+08) others: 1
# >> node 56 (sf:12 bw:125 freq:8.600030e+08)
# no frequency coll
# CHECK node 46 (sf:12 bw:125 freq:8.600012e+08) others: 1
# >> node 50 (sf:12 bw:125 freq:8.600034e+08)
# no frequency coll
# CHECK node 65 (sf:12 bw:125 freq:8.600024e+08) others: 1
# >> node 48 (sf:12 bw:125 freq:8.600038e+08)
# no frequency coll
# CHECK node 33 (sf:12 bw:125 freq:8.600010e+08) others: 1
# >> node 58 (sf:12 bw:125 freq:8.600022e+08)
# no frequency coll
# CHECK node 29 (sf:12 bw:125 freq:8.600021e+08) others: 1
# >> node 62 (sf:12 bw:125 freq:8.600065e+08)
# no frequency coll
# CHECK node 1 (sf:12 bw:125 freq:8.600058e+08) others: 1
# >> node 58 (sf:12 bw:125 freq:8.600022e+08)
# no frequency coll
# CHECK node 40 (sf:12 bw:125 freq:8.600049e+08) others: 1
# >> node 33 (sf:12 bw:125 freq:8.600010e+08)
# no frequency coll
# CHECK node 48 (sf:12 bw:125 freq:8.600038e+08) others: 1
# >> node 52 (sf:12 bw:125 freq:8.600045e+08)
# no frequency coll
# CHECK node 38 (sf:12 bw:125 freq:8.600018e+08) others: 1
# >> node 51 (sf:12 bw:125 freq:8.600059e+08)
# no frequency coll
# CHECK node 64 (sf:12 bw:125 freq:8.600046e+08) others: 1
# >> node 21 (sf:12 bw:125 freq:8.600056e+08)
# no frequency coll
# CHECK node 64 (sf:12 bw:125 freq:8.600046e+08) others: 1
# >> node 11 (sf:12 bw:125 freq:8.600072e+08)
# no frequency coll
# CHECK node 27 (sf:12 bw:125 freq:8.600064e+08) others: 1
# >> node 48 (sf:12 bw:125 freq:8.600038e+08)
# no frequency coll
# CHECK node 61 (sf:12 bw:125 freq:8.600022e+08) others: 1
# >> node 13 (sf:12 bw:125 freq:8.600054e+08)
# no frequency coll
# CHECK node 45 (sf:12 bw:125 freq:8.600078e+08) others: 1
# >> node 44 (sf:12 bw:125 freq:8.600070e+08)
# no frequency coll
# CHECK node 51 (sf:12 bw:125 freq:8.600059e+08) others: 1
# >> node 0 (sf:12 bw:125 freq:8.600026e+08)
# no frequency coll
# CHECK node 16 (sf:12 bw:125 freq:8.600080e+08) others: 1
# >> node 68 (sf:12 bw:125 freq:8.600040e+08)
# no frequency coll
# CHECK node 21 (sf:12 bw:125 freq:8.600056e+08) others: 1
# >> node 19 (sf:12 bw:125 freq:8.600009e+08)
# no frequency coll
# CHECK node 18 (sf:12 bw:125 freq:8.600034e+08) others: 1
# >> node 40 (sf:12 bw:125 freq:8.600049e+08)
# no frequency coll
# CHECK node 55 (sf:12 bw:125 freq:8.600015e+08) others: 1
# >> node 67 (sf:12 bw:125 freq:8.600056e+08)
# no frequency coll
# CHECK node 65 (sf:12 bw:125 freq:8.600024e+08) others: 1
# >> node 6 (sf:12 bw:125 freq:8.600059e+08)
# no frequency coll
# CHECK node 20 (sf:12 bw:125 freq:8.600054e+08) others: 1
# >> node 57 (sf:12 bw:125 freq:8.600021e+08)
# no frequency coll
# CHECK node 50 (sf:12 bw:125 freq:8.600034e+08) others: 1
# >> node 13 (sf:12 bw:125 freq:8.600054e+08)
# no frequency coll
# CHECK node 35 (sf:12 bw:125 freq:8.600025e+08) others: 1
# >> node 14 (sf:12 bw:125 freq:8.600048e+08)
# no frequency coll
# CHECK node 15 (sf:12 bw:125 freq:8.600002e+08) others: 1
# >> node 47 (sf:12 bw:125 freq:8.600028e+08)
# no frequency coll
# CHECK node 51 (sf:12 bw:125 freq:8.600059e+08) others: 1
# >> node 24 (sf:12 bw:125 freq:8.600078e+08)
# no frequency coll
# CHECK node 33 (sf:12 bw:125 freq:8.600010e+08) others: 1
# >> node 19 (sf:12 bw:125 freq:8.600009e+08)
# no frequency coll
# CHECK node 55 (sf:12 bw:125 freq:8.600015e+08) others: 1
# >> node 67 (sf:12 bw:125 freq:8.600056e+08)
# no frequency coll
# ----------------------------
# ----------------------------
# nrCollisions  130
# energy (in J):  8185.14149376
# sent packets:  47015
# collisions:  130
# received packets:  46885
# processed packets:  47015
# lost packets:  0
# Total time to fly:  62008647.68
# DER: 0.997234925024
# DER method 2: 0.997234925024
# ----------------------------
# ----------------------------
