# %%
import simpy
import random
import numpy as np
import math
import sys
import matplotlib.pyplot as plt
# %matplotlib inline
import os

# random.seed(123)

# %%
# check for collisions at base station
# Note: called before a packet (or rather node) is inserted into the list
def checkcollision(packet):
    col = 0 # flag needed since there might be several collisions for packet
    processing = 0
    for i in range(0,len(packetsAtBS)):
        if packetsAtBS[i].packet.processed == 1:
            processing = processing + 1
    if (processing > maxBSReceives):
        print "too long:", len(packetsAtBS)
        packet.processed = 0
    else:
        packet.processed = 1

    if packetsAtBS:
        print "CHECK node {} (sf:{} bw:{} freq:{:.6e}) others: {}".format(
             packet.nodeid, packet.sf, packet.bw, packet.freq,
             len(packetsAtBS))
        for other in packetsAtBS:
            if other.nodeid != packet.nodeid:
                print ">> node {} (sf:{} bw:{} freq:{:.6e})".format(
                   other.nodeid, other.packet.sf, other.packet.bw, other.packet.freq)
               # simple collision
                if frequencyCollision(packet, other.packet) and sfCollision(packet, other.packet):
                    if full_collision:
                        if timingCollision(packet, other.packet):
                           # check who collides in the power domain
                            c = powerCollision(packet, other.packet)
                           # mark all the collided packets
                           # either this one, the other one, or both
                            for p in c:
                                p.collided = 1
                                if p == packet:
                                    col = 1
                        else:
                           # no timing collision, all fine
                           pass
                    else:
                        packet.collided = 1
                        other.packet.collided = 1  # other also got lost, if it wasn't lost already
                        col = 1
        return col
    return 0

def transmit(env,node):
    while True:
        yield env.timeout(random.expovariate(1.0/float(node.period)))
#         yield env.timeout(np.random.exponential(1.0/float(node.period)))

        # time sending and receiving
        # packet arrives -> add to base station

        node.sent = node.sent + 1
        node.transmitionTime = node.transmitionTime + node.packet.rectime
        if (node in packetsAtBS):
            print "ERROR: packet already in"
        else:
            sensitivity = sensi[node.packet.sf - 7, [125,250,500].index(node.packet.bw) + 1]
            if node.packet.rssi - np.abs(11.8*np.random.rand())< sensitivity:
                print "node {}: packet will be lost".format(node.nodeid)
                node.packet.lost = True
            else:
                node.packet.lost = False
                # adding packet if no collision
                if (checkcollision(node.packet)==1):
                    node.packet.collided = 1
                else:
                    node.packet.collided = 0
                packetsAtBS.append(node)
                node.packet.addTime = env.now

        yield env.timeout(node.packet.rectime)

        if node.packet.lost:
            global nrLost
            nrLost += 1
        if node.packet.collided == 1:
            global nrCollisions
            nrCollisions = nrCollisions +1
        if node.packet.collided == 0 and not node.packet.lost:
            global nrReceived
            nrReceived = nrReceived + 1
        if node.packet.processed == 1:
            global nrProcessed
            nrProcessed = nrProcessed + 1

        # complete packet has been received by base station
        # can remove it
        if (node in packetsAtBS):
            packetsAtBS.remove(node)
            # reset the packet
        node.packet.collided = 0
        node.packet.processed = 0
        node.packet.lost = False
        
def timingCollision(p1, p2):
    # assuming p1 is the freshly arrived packet and this is the last check
    # we've already determined that p1 is a weak packet, so the only
    # way we can win is by being late enough (only the first n - 5 preamble symbols overlap)

    # assuming 8 preamble symbols
    Npream = 8

    # we can lose at most (Npream - 5) * Tsym of our preamble
    Tpreamb = 2**p1.sf/(1.0*p1.bw) * (Npream - 5)

    # check whether p2 ends in p1's critical section
    p2_end = p2.addTime + p2.rectime
    p1_cs = env.now + Tpreamb
    print "collision timing node {} ({},{},{}) node {} ({},{})".format(
        p1.nodeid, env.now - env.now, p1_cs - env.now, p1.rectime,
        p2.nodeid, p2.addTime - env.now, p2_end - env.now
    )
    if p1_cs < p2_end:
        # p1 collided with p2 and lost
        print "not late enough"
        return True
    print "saved by the preamble"
    return False

# %%
# turn on/off graphics
graphics = 0

# do the full collision check
full_collision = False

# experiments:
# 0: packet with longest airtime, aloha-style experiment
# 0: one with 3 frequencies, 1 with 1 frequency
# 2: with shortest packets, still aloha-style
# 3: with shortest possible packets depending on distance



# this is an array with measured values for sensitivity
# see paper, Table 3
sf7 = np.array([7,-126.5,-124.25,-120.75])
sf8 = np.array([8,-127.25,-126.75,-124.0])
sf9 = np.array([9,-131.25,-128.25,-127.5])
sf10 = np.array([10,-132.75,-130.25,-128.75])
sf11 = np.array([11,-134.5,-132.75,-128.75])
sf12 = np.array([12,-133.25,-132.25,-132.25])

# %%
from loraDir import frequencyCollision, sfCollision, powerCollision, airtime#, timingCollision

# %%
class myNode():
    def __init__(self, nodeid, bs, period, packetlen, x, y):
        self.nodeid = nodeid
        self.period = period
        self.bs = bs
        assert np.sqrt((x-bsx)**2+(y-bsy)**2) < maxDist, "Max distance error"
        self.x = x
        self.y = y
        
        self.dist = np.sqrt((self.x-bsx)*(self.x-bsx)+(self.y-bsy)*(self.y-bsy))
        print('node %d' %nodeid, "x", self.x, "y", self.y, "dist: ", self.dist)
        
#         self.packet = myPacket(self.nodeid, packetlen, self.dist)
        self.packet = None
        self.setPacket(packetlen)
        self.sent = 0

        # graphics for node
        global graphics
        if (graphics == 1):
            global ax
            ax.add_artist(plt.Circle((self.x, self.y), 2, fill=True, color='blue'))
        
        self.transmitionTime = 0
        
    def setPacket(self, packetlen):
        if self.packet != None:
            assert self.packet == None, "ERROR: Existing Packet association\nfrequency: {}; symTime: {}\nbw: {}; sf: {}; cr: {}; rssi: {}".format(self.packet.freq, self.packet.symTime,
                                                                                                             self.packet.bw, self.packet.sf, self.packet.cr, self.packet.rssi)
        self.packet = myPacket(self.nodeid, packetlen, self.dist)

# %%
#
# this function creates a packet (associated with a node)
# it also sets all parameters, currently random
#
class myPacket():
    def __init__(self, nodeid, plen, distance):
        global experiment
        global Ptx
        global gamma
        global d0
        global var
        global Lpld0
        global GL

        self.nodeid = nodeid
        self.txpow = Ptx

        # randomize configuration values
        self.sf = random.randint(6,12)
        self.cr = random.randint(1,4)
        self.bw = random.choice([125, 250, 500])

        # for certain experiments override these
        if experiment==1 or experiment == 0:
            self.sf = 12
            self.cr = 4
            self.bw = 125

        # for certain experiments override these
        if experiment==2:
            self.sf = 6
            self.cr = 1
            self.bw = 500
        # lorawan
        if experiment == 4:
            self.sf = 12
            self.cr = 1
            self.bw = 125


        # for experiment 3 find the best setting
        # OBS, some hardcoded values
        Prx = self.txpow  ## zero path loss by default

        # log-shadow
        Lpl = Lpld0 + 10*gamma*math.log10(distance/d0)
        print "Lpl:", Lpl
        Prx = self.txpow - GL - Lpl

        if (experiment == 3) or (experiment == 5):
            minairtime = 9999
            minsf = 0
            minbw = 0

            print "Prx:", Prx

            for i in range(0,6):
                for j in range(1,4):
                    if (sensi[i,j] < Prx):
                        self.sf = int(sensi[i,0])
                        if j==1:
                            self.bw = 125
                        elif j==2:
                            self.bw = 250
                        else:
                            self.bw=500
                        at = airtime(self.sf, 1, plen, self.bw)
                        if at < minairtime:
                            minairtime = at
                            minsf = self.sf
                            minbw = self.bw
                            minsensi = sensi[i, j]
            if (minairtime == 9999):
                print "does not reach base station"
                exit(-1)
            print "best sf:", minsf, " best bw: ", minbw, "best airtime:", minairtime
            self.rectime = minairtime
            self.sf = minsf
            self.bw = minbw
            self.cr = 1

            if experiment == 5:
                # reduce the txpower if there's room left
                self.txpow = max(2, self.txpow - math.floor(Prx - minsensi))
                Prx = self.txpow - GL - Lpl
                print 'minsesi {} best txpow {}'.format(minsensi, self.txpow)

        # transmission range, needs update XXX
        self.transRange = 150
        self.pl = plen
        self.symTime = (2.0**self.sf)/self.bw
        self.arriveTime = 0
        self.rssi = Prx
        # frequencies: lower bound + number of 61 Hz steps
        self.freq = 860000000 + self.bw*random.randint(0,64)

#         # for certain experiments override these and
#         # choose some random frequences
#         if experiment == 1:
#             self.freq = random.choice([860000000, 864000000, 868000000])
#         else:
#             self.freq = 860000000

        print "frequency" ,self.freq, "symTime ", self.symTime
        print "bw", self.bw, "sf", self.sf, "cr", self.cr, "rssi", self.rssi
        self.rectime = airtime(self.sf,self.cr,self.pl,self.bw)
        print "rectime node ", self.nodeid, "  ", self.rectime
        # denote if packet is collided
        self.collided = 0
        self.processed = 0

# %%
nrNodes = 70
avgSendTime = 15*60*1000
experiment = 4
simtime = 7*24*60*60*1000

full_collision = False

print "Nodes:", nrNodes
print "AvgSendTime (exp. distributed):",avgSendTime
print "Experiment: ", experiment
print "Simtime: ", simtime
print "Full Collision: ", full_collision
# Out:
# Nodes: 70
# AvgSendTime (exp. distributed): 900000
# Experiment:  4
# Simtime:  604800000
# Full Collision:  False

# %%
# global stuff
#Rnd = random.seed(12345)
nodes = []
packetsAtBS = []
env = simpy.Environment()

# maximum number of packets the BS can receive at the same time
maxBSReceives = 8


# max distance: 300m in city, 3000 m outside (5 km Utz experiment)
# also more unit-disc like according to Utz
bsId = 1
nrCollisions = 0
nrReceived = 0
nrProcessed = 0
nrLost = 0

Ptx = 14
gamma = 2.08
d0 = 40.0
var = 0           # variance ignored for now
Lpld0 = 127.41
GL = 0

sensi = np.array([sf7,sf8,sf9,sf10,sf11,sf12])
if experiment in [0,1,4]:
    minsensi = sensi[5,2]  # 5th row is SF12, 2nd column is BW125
elif experiment == 2:
    minsensi = -112.0   # no experiments, so value from datasheet
elif experiment in [3,5]:
    minsensi = np.amin(sensi) ## Experiment 3 can use any setting, so take minimum
Lpl = Ptx - minsensi
print "amin", minsensi, "Lpl", Lpl
maxDist = d0*(math.e**((Lpl-Lpld0)/(10.0*gamma)))
print "maxDist:", maxDist

# base station placement
bsx = maxDist+10
bsy = maxDist+10
xmax = bsx + maxDist + 20
ymax = bsy + maxDist + 20
# Out:
# amin -132.25 Lpl 146.25
# maxDist: 98.9533656272

# %%
# prepare graphics and add sink
if (graphics == 1):
    plt.ion()
    plt.figure()
    ax = plt.gcf().gca()
    # XXX should be base station position
    ax.add_artist(plt.Circle((bsx, bsy), 3, fill=True, color='green'))
    ax.add_artist(plt.Circle((bsx, bsy), maxDist, fill=False, color='green'))

for i in range(0,nrNodes):
    # this is very complex prodecure for placing nodes
    # and ensure minimum distance between each pair of nodes
    found = 0
    rounds = 0
    while (found == 0 and rounds < 100):
        a = random.random()
        b = random.random()
        if b<a:
            a,b = b,a
        posx = b*maxDist*np.cos(2*math.pi*a/b)+bsx
        posy = b*maxDist*np.sin(2*math.pi*a/b)+bsy
        if len(nodes) > 0:
            for index, n in enumerate(nodes):
                dist = np.sqrt(((abs(n.x-posx))**2)+((abs(n.y-posy))**2))
                if dist >= 10:
                    found = 1
                else:
                    rounds = rounds + 1
                    if rounds == 100:
                        print "could not place new node, giving up"
                        exit(-1)
        else:
            print "first node"
            found = 1

    # myNode takes period (in ms), base station id packetlen (in Bytes)
    # 1000000 = 16 min
    node = myNode(i,bsId, avgSendTime,20, posx, posy)
    nodes.append(node)
    env.process(transmit(env,node))
# Out:
# first node
# ('node 0', 'x', 118.08188714911215, 'y', 132.66387440825403, 'dist: ', 25.407048861116273)
# Lpl: 123.310200014
# frequency 860002875 symTime  32.768
# bw 125 sf 12 cr 1 rssi -109.310200014
# sf 12  cr 1 pl 20 bw 125
# rectime node  0    1318.912
# ('node 1', 'x', 32.797548005521676, 'y', 146.96530672239047, 'dist: ', 85.115311333813935)
# Lpl: 134.231312175
# frequency 860006250 symTime  32.768
# bw 125 sf 12 cr 1 rssi -120.231312175
# sf 12  cr 1 pl 20 bw 125
# rectime node  1    1318.912
# ('node 2', 'x', 71.055858317778672, 'y', 120.00558384020283, 'dist: ', 39.476228134113072)
# Lpl: 127.290933703
# frequency 860002375 symTime  32.768
# bw 125 sf 12 cr 1 rssi -113.290933703
# sf 12  cr 1 pl 20 bw 125
# rectime node  2    1318.912
# ('node 3', 'x', 86.072089777894433, 'y', 190.68719515042287, 'dist: ', 84.876213823549733)
# Lpl: 134.205900943
# frequency 860001500 symTime  32.768
# bw 125 sf 12 cr 1 rssi -120.205900943
# sf 12  cr 1 pl 20 bw 125
# rectime node  3    1318.912
# ('node 4', 'x', 80.303941674374727, 'y', 134.17637713605336, 'dist: ', 38.170535788807101)
# Lpl: 126.987099906
# frequency 860006375 symTime  32.768
# bw 125 sf 12 cr 1 rssi -112.987099906
# sf 12  cr 1 pl 20 bw 125
# rectime node  4    1318.912
# ('node 5', 'x', 104.13360071681529, 'y', 87.201989615900175, 'dist: ', 22.278969728813319)
# Lpl: 122.123370331
# frequency 860008000 symTime  32.768
# bw 125 sf 12 cr 1 rssi -108.123370331
# sf 12  cr 1 pl 20 bw 125
# rectime node  5    1318.912
# ('node 6', 'x', 51.664580170452311, 'y', 36.946749304911322, 'dist: ', 92.016073233428571)
# Lpl: 134.935517055
# frequency 860006500 symTime  32.768
# bw 125 sf 12 cr 1 rssi -120.935517055
# sf 12  cr 1 pl 20 bw 125
# rectime node  6    1318.912
# ('node 7', 'x', 106.73162680762314, 'y', 17.157650482301008, 'dist: ', 91.82259766718424)
# Lpl: 134.916503337
# frequency 860003375 symTime  32.768
# bw 125 sf 12 cr 1 rssi -120.916503337
# sf 12  cr 1 pl 20 bw 125
# rectime node  7    1318.912
# ('node 8', 'x', 12.848759435287306, 'y', 118.50273164247986, 'dist: ', 96.577873876990282)
# Lpl: 135.3726071
# frequency 860006750 symTime  32.768
# bw 125 sf 12 cr 1 rssi -121.3726071
# sf 12  cr 1 pl 20 bw 125
# rectime node  8    1318.912
# ('node 9', 'x', 159.74251534236697, 'y', 191.1567542584383, 'dist: ', 96.62781603266609)
# Lpl: 135.377277187
# frequency 860007875 symTime  32.768
# bw 125 sf 12 cr 1 rssi -121.377277187
# sf 12  cr 1 pl 20 bw 125
# rectime node  9    1318.912
# ('node 10', 'x', 48.259956860997875, 'y', 45.156985357831786, 'dist: ', 88.054914701793209)
# Lpl: 134.538027075
# frequency 860001750 symTime  32.768
# bw 125 sf 12 cr 1 rssi -120.538027075
# sf 12  cr 1 pl 20 bw 125
# rectime node  10    1318.912
# ('node 11', 'x', 76.030442990141239, 'y', 151.13431365554788, 'dist: ', 53.508421874837367)
# Lpl: 130.038332744
# frequency 860005750 symTime  32.768
# bw 125 sf 12 cr 1 rssi -116.038332744
# sf 12  cr 1 pl 20 bw 125
# rectime node  11    1318.912
# ('node 12', 'x', 17.531468417811553, 'y', 77.706854196791028, 'dist: ', 96.614221344166182)
# Lpl: 135.376006188
# frequency 860002375 symTime  32.768
# bw 125 sf 12 cr 1 rssi -121.376006188
# sf 12  cr 1 pl 20 bw 125
# rectime node  12    1318.912
# ('node 13', 'x', 141.97646603992087, 'y', 196.17239452546926, 'dist: ', 93.261375514309236)
# Lpl: 135.056949965
# frequency 860006625 symTime  32.768
# bw 125 sf 12 cr 1 rssi -121.056949965
# sf 12  cr 1 pl 20 bw 125
# rectime node  13    1318.912
# ('node 14', 'x', 24.606911089044786, 'y', 101.27158919328475, 'dist: ', 84.695537558606915)
# Lpl: 134.18665118
# frequency 860006375 symTime  32.768
# bw 125 sf 12 cr 1 rssi -120.18665118
# sf 12  cr 1 pl 20 bw 125
# rectime node  14    1318.912
# ('node 15', 'x', 65.309041448278833, 'y', 98.150931398435048, 'dist: ', 44.961312461979105)
# Lpl: 128.466202969
# frequency 860002375 symTime  32.768
# bw 125 sf 12 cr 1 rssi -114.466202969
# sf 12  cr 1 pl 20 bw 125
# rectime node  15    1318.912
# ('node 16', 'x', 96.764207374648834, 'y', 46.633757027371331, 'dist: ', 63.500466100214837)
# Lpl: 131.584911972
# frequency 860000500 symTime  32.768
# bw 125 sf 12 cr 1 rssi -117.584911972
# sf 12  cr 1 pl 20 bw 125
# rectime node  16    1318.912
# ('node 17', 'x', 37.188522594682198, 'y', 67.124754252940889, 'dist: ', 83.06518780443001)
# Lpl: 134.011068448
# frequency 860005750 symTime  32.768
# bw 125 sf 12 cr 1 rssi -120.011068448
# sf 12  cr 1 pl 20 bw 125
# rectime node  17    1318.912
# ('node 18', 'x', 68.306324562640498, 'y', 125.40439563767514, 'dist: ', 43.849952516627667)
# Lpl: 128.240110031
# frequency 860003625 symTime  32.768
# bw 125 sf 12 cr 1 rssi -114.240110031
# sf 12  cr 1 pl 20 bw 125
# rectime node  18    1318.912
# ('node 19', 'x', 86.081015623728561, 'y', 126.71769062726057, 'dist: ', 28.960587656145371)
# Lpl: 124.492745479
# frequency 860003375 symTime  32.768
# bw 125 sf 12 cr 1 rssi -110.492745479
# sf 12  cr 1 pl 20 bw 125
# rectime node  19    1318.912
# ('node 20', 'x', 60.723507305929218, 'y', 173.02770935431874, 'dist: ', 80.197510919916866)
# Lpl: 133.693698679
# frequency 860000625 symTime  32.768
# bw 125 sf 12 cr 1 rssi -119.693698679
# sf 12  cr 1 pl 20 bw 125
# rectime node  20    1318.912
# ('node 21', 'x', 98.751108528666578, 'y', 102.52353423435721, 'dist: ', 12.059385624716651)
# Lpl: 116.578715984
# frequency 860006500 symTime  32.768
# bw 125 sf 12 cr 1 rssi -102.578715984
# sf 12  cr 1 pl 20 bw 125
# rectime node  21    1318.912
# ('node 22', 'x', 172.45535940469739, 'y', 165.35697415547457, 'dist: ', 84.934505760164427)
# Lpl: 134.21210279
# frequency 860001625 symTime  32.768
# bw 125 sf 12 cr 1 rssi -120.21210279
# sf 12  cr 1 pl 20 bw 125
# rectime node  22    1318.912
# ('node 23', 'x', 160.40959167990246, 'y', 115.83581792337091, 'dist: ', 51.914461850177815)
# Lpl: 129.765149994
# frequency 860000125 symTime  32.768
# bw 125 sf 12 cr 1 rssi -115.765149994
# sf 12  cr 1 pl 20 bw 125
# rectime node  23    1318.912
# ('node 24', 'x', 91.036492223936222, 'y', 130.58766799792579, 'dist: ', 28.090165389623909)
# Lpl: 124.217081542
# frequency 860004500 symTime  32.768
# bw 125 sf 12 cr 1 rssi -110.217081542
# sf 12  cr 1 pl 20 bw 125
# rectime node  24    1318.912
# ('node 25', 'x', 125.57952576448426, 'y', 131.34962399980469, 'dist: ', 27.893038378805855)
# Lpl: 124.153465328
# frequency 860004500 symTime  32.768
# bw 125 sf 12 cr 1 rssi -110.153465328
# sf 12  cr 1 pl 20 bw 125
# rectime node  25    1318.912
# ('node 26', 'x', 177.19745551925018, 'y', 149.6997431051152, 'dist: ', 79.482847726806156)
# Lpl: 133.612839289
# frequency 860008000 symTime  32.768
# bw 125 sf 12 cr 1 rssi -119.612839289
# sf 12  cr 1 pl 20 bw 125
# rectime node  26    1318.912
# ('node 27', 'x', 103.34585463218268, 'y', 175.16856759084726, 'dist: ', 66.452217048368141)
# Lpl: 131.995349258
# frequency 860004000 symTime  32.768
# bw 125 sf 12 cr 1 rssi -117.995349258
# sf 12  cr 1 pl 20 bw 125
# rectime node  27    1318.912
# ('node 28', 'x', 34.992232056457567, 'y', 87.189322495518013, 'dist: ', 77.09684074273548)
# Lpl: 133.337513086
# frequency 860003125 symTime  32.768
# bw 125 sf 12 cr 1 rssi -119.337513086
# sf 12  cr 1 pl 20 bw 125
# rectime node  28    1318.912
# ('node 29', 'x', 34.819045596346299, 'y', 156.00151134692197, 'dist: ', 87.80333377555948)
# Lpl: 134.512181101
# frequency 860002000 symTime  32.768
# bw 125 sf 12 cr 1 rssi -120.512181101
# sf 12  cr 1 pl 20 bw 125
# rectime node  29    1318.912
# ('node 30', 'x', 110.2589971561445, 'y', 171.59927282851169, 'dist: ', 62.659511351128415)
# Lpl: 131.464481858
# frequency 860005500 symTime  32.768
# bw 125 sf 12 cr 1 rssi -117.464481858
# sf 12  cr 1 pl 20 bw 125
# rectime node  30    1318.912
# ('node 31', 'x', 121.04212658862163, 'y', 148.99759934521006, 'dist: ', 41.829162024154101)
# Lpl: 127.813918798
# frequency 860000750 symTime  32.768
# bw 125 sf 12 cr 1 rssi -113.813918798
# sf 12  cr 1 pl 20 bw 125
# rectime node  31    1318.912
# ('node 32', 'x', 134.92166441364313, 'y', 193.31371366470626, 'dist: ', 88.266759671275963)
# Lpl: 134.5597336
# frequency 860006375 symTime  32.768
# bw 125 sf 12 cr 1 rssi -120.5597336
# sf 12  cr 1 pl 20 bw 125
# rectime node  32    1318.912
# ('node 33', 'x', 80.111450520922972, 'y', 114.32232083758819, 'dist: ', 29.337377985255902)
# Lpl: 124.609515145
# frequency 860006625 symTime  32.768
# bw 125 sf 12 cr 1 rssi -110.609515145
# sf 12  cr 1 pl 20 bw 125
# rectime node  33    1318.912
# ('node 34', 'x', 83.417383436736912, 'y', 105.29740794275821, 'dist: ', 25.796364337309939)
# Lpl: 123.447569024
# frequency 860001875 symTime  32.768
# bw 125 sf 12 cr 1 rssi -109.447569024
# sf 12  cr 1 pl 20 bw 125
# rectime node  34    1318.912
# ('node 35', 'x', 145.24638209914096, 'y', 19.79401286057157, 'dist: ', 96.263041871731701)
# Lpl: 135.343111467
# frequency 860003375 symTime  32.768
# bw 125 sf 12 cr 1 rssi -121.343111467
# sf 12  cr 1 pl 20 bw 125
# rectime node  35    1318.912
# ('node 36', 'x', 59.423384989371137, 'y', 145.47493004204708, 'dist: ', 61.538960417706463)
# Lpl: 131.301475413
# frequency 860006125 symTime  32.768
# bw 125 sf 12 cr 1 rssi -117.301475413
# sf 12  cr 1 pl 20 bw 125
# rectime node  36    1318.912
# ('node 37', 'x', 50.798015925121, 'y', 82.143886359512507, 'dist: ', 64.037433408741791)
# Lpl: 131.66097766
# frequency 860008000 symTime  32.768
# bw 125 sf 12 cr 1 rssi -117.66097766
# sf 12  cr 1 pl 20 bw 125
# rectime node  37    1318.912
# ('node 38', 'x', 170.41820623755194, 'y', 166.55966183014681, 'dist: ', 84.240204139548979)
# Lpl: 134.137955921
# frequency 860006125 symTime  32.768
# bw 125 sf 12 cr 1 rssi -120.137955921
# sf 12  cr 1 pl 20 bw 125
# rectime node  38    1318.912
# ('node 39', 'x', 79.608324577046091, 'y', 62.901250832523601, 'dist: ', 54.607039027036294)
# Lpl: 130.221923649
# frequency 860005625 symTime  32.768
# bw 125 sf 12 cr 1 rssi -116.221923649
# sf 12  cr 1 pl 20 bw 125
# rectime node  39    1318.912
# ('node 40', 'x', 26.024942196893392, 'y', 103.46421598351836, 'dist: ', 83.109892169647694)
# Lpl: 134.015928732
# frequency 860004000 symTime  32.768
# bw 125 sf 12 cr 1 rssi -120.015928732
# sf 12  cr 1 pl 20 bw 125
# rectime node  40    1318.912
# ('node 41', 'x', 68.144100726778021, 'y', 150.06876573835655, 'dist: ', 57.929890626629813)
# Lpl: 130.755528518
# frequency 860004500 symTime  32.768
# bw 125 sf 12 cr 1 rssi -116.755528518
# sf 12  cr 1 pl 20 bw 125
# rectime node  41    1318.912
# ('node 42', 'x', 197.87246543466614, 'y', 130.77932007920424, 'dist: ', 91.558607450674415)
# Lpl: 134.890495097
# frequency 860007250 symTime  32.768
# bw 125 sf 12 cr 1 rssi -120.890495097
# sf 12  cr 1 pl 20 bw 125
# rectime node  42    1318.912
# ('node 43', 'x', 45.518034571160385, 'y', 154.10560890457913, 'dist: ', 77.863767563416161)
# Lpl: 133.42692879
# frequency 860003625 symTime  32.768
# bw 125 sf 12 cr 1 rssi -119.42692879
# sf 12  cr 1 pl 20 bw 125
# rectime node  43    1318.912
# ('node 44', 'x', 199.56424606832695, 'y', 98.460828389802543, 'dist: ', 91.21636361964444)
# Lpl: 134.856665483
# frequency 860001250 symTime  32.768
# bw 125 sf 12 cr 1 rssi -120.856665483
# sf 12  cr 1 pl 20 bw 125
# rectime node  44    1318.912
# ('node 45', 'x', 90.846138487192647, 'y', 80.425573874150103, 'dist: ', 33.789148805601066)
# Lpl: 125.88571901
# frequency 860006750 symTime  32.768
# bw 125 sf 12 cr 1 rssi -111.88571901
# sf 12  cr 1 pl 20 bw 125
# rectime node  45    1318.912
# ('node 46', 'x', 33.341478906429913, 'y', 110.67393326418193, 'dist: ', 75.63146016355185)
# Lpl: 133.16416387
# frequency 860003625 symTime  32.768
# bw 125 sf 12 cr 1 rssi -119.16416387
# sf 12  cr 1 pl 20 bw 125
# rectime node  46    1318.912
# ('node 47', 'x', 201.33238264574956, 'y', 141.58045565975652, 'dist: ', 97.971474365251112)
# Lpl: 135.502024771
# frequency 860006750 symTime  32.768
# bw 125 sf 12 cr 1 rssi -121.502024771
# sf 12  cr 1 pl 20 bw 125
# rectime node  47    1318.912
# ('node 48', 'x', 26.328150459562607, 'y', 72.400535749909068, 'dist: ', 90.349518834032978)
# Lpl: 134.770409736
# frequency 860002625 symTime  32.768
# bw 125 sf 12 cr 1 rssi -120.770409736
# sf 12  cr 1 pl 20 bw 125
# rectime node  48    1318.912
# ('node 49', 'x', 100.86464691123473, 'y', 62.182445870778871, 'dist: ', 47.465211527283529)
# Lpl: 128.95576093
# frequency 860007250 symTime  32.768
# bw 125 sf 12 cr 1 rssi -114.95576093
# sf 12  cr 1 pl 20 bw 125
# rectime node  49    1318.912
# ('node 50', 'x', 172.76934693017483, 'y', 116.80151483814417, 'dist: ', 64.296756649896665)
# Lpl: 131.697484757
# frequency 860008000 symTime  32.768
# bw 125 sf 12 cr 1 rssi -117.697484757
# sf 12  cr 1 pl 20 bw 125
# rectime node  50    1318.912
# ('node 51', 'x', 31.313417241495515, 'y', 144.96311015972879, 'dist: ', 85.584246720027252)
# Lpl: 134.280943897
# frequency 860002500 symTime  32.768
# bw 125 sf 12 cr 1 rssi -120.280943897
# sf 12  cr 1 pl 20 bw 125
# rectime node  51    1318.912
# ('node 52', 'x', 106.60932599569533, 'y', 58.176820127903596, 'dist: ', 50.830621623567538)
# Lpl: 129.574560934
# frequency 860002250 symTime  32.768
# bw 125 sf 12 cr 1 rssi -115.574560934
# sf 12  cr 1 pl 20 bw 125
# rectime node  52    1318.912
# ('node 53', 'x', 63.950287668214656, 'y', 117.944177750346, 'dist: ', 45.892392925381991)
# Lpl: 128.651358809
# frequency 860007750 symTime  32.768
# bw 125 sf 12 cr 1 rssi -114.651358809
# sf 12  cr 1 pl 20 bw 125
# rectime node  53    1318.912
# ('node 54', 'x', 49.43944540472873, 'y', 75.220529771085594, 'dist: ', 68.40914350542576)
# Lpl: 132.257526563
# frequency 860005250 symTime  32.768
# bw 125 sf 12 cr 1 rssi -118.257526563
# sf 12  cr 1 pl 20 bw 125
# rectime node  54    1318.912
# ('node 55', 'x', 186.58833549341097, 'y', 74.445754873467394, 'dist: ', 84.958600188897265)
# Lpl: 134.214665023
# frequency 860000875 symTime  32.768
# bw 125 sf 12 cr 1 rssi -120.214665023
# sf 12  cr 1 pl 20 bw 125
# rectime node  55    1318.912
# ('node 56', 'x', 194.14156403557081, 'y', 142.27373995567896, 'dist: ', 91.47281833118079)
# Lpl: 134.882027032
# frequency 860001875 symTime  32.768
# bw 125 sf 12 cr 1 rssi -120.882027032
# sf 12  cr 1 pl 20 bw 125
# rectime node  56    1318.912
# ('node 57', 'x', 78.910111799174885, 'y', 119.0924681009938, 'dist: ', 31.708019483247885)
# Lpl: 125.311469801
# frequency 860006250 symTime  32.768
# bw 125 sf 12 cr 1 rssi -111.311469801
# sf 12  cr 1 pl 20 bw 125
# rectime node  57    1318.912
# ('node 58', 'x', 190.4220399989124, 'y', 98.295105129503256, 'dist: ', 82.162907815619931)
# Lpl: 133.912408839
# frequency 860004125 symTime  32.768
# bw 125 sf 12 cr 1 rssi -119.912408839
# sf 12  cr 1 pl 20 bw 125
# rectime node  58    1318.912
# ('node 59', 'x', 47.622437145696452, 'y', 101.31109719478692, 'dist: ', 61.805234852713724)
# Lpl: 131.34047761
# frequency 860006625 symTime  32.768
# bw 125 sf 12 cr 1 rssi -117.34047761
# sf 12  cr 1 pl 20 bw 125
# rectime node  59    1318.912
# ('node 60', 'x', 103.82233413636135, 'y', 189.43604355579797, 'dist: ', 80.646072010454517)
# Lpl: 133.744083141
# frequency 860000125 symTime  32.768
# bw 125 sf 12 cr 1 rssi -119.744083141
# sf 12  cr 1 pl 20 bw 125
# rectime node  60    1318.912
# ('node 61', 'x', 126.55908409003145, 'y', 100.6397698644595, 'dist: ', 19.469904907276049)
# Lpl: 120.905919853
# frequency 860003000 symTime  32.768
# bw 125 sf 12 cr 1 rssi -106.905919853
# sf 12  cr 1 pl 20 bw 125
# rectime node  61    1318.912
# ('node 62', 'x', 49.397139379044809, 'y', 94.652280586407983, 'dist: ', 61.249205041929706)
# Lpl: 131.258841672
# frequency 860005375 symTime  32.768
# bw 125 sf 12 cr 1 rssi -117.258841672
# sf 12  cr 1 pl 20 bw 125
# rectime node  62    1318.912
# ('node 63', 'x', 72.458635860109922, 'y', 104.12135015568134, 'dist: ', 36.81322689321825)
# Lpl: 126.660033041
# frequency 860000500 symTime  32.768
# bw 125 sf 12 cr 1 rssi -112.660033041
# sf 12  cr 1 pl 20 bw 125
# rectime node  63    1318.912
# ('node 64', 'x', 27.654140223432549, 'y', 129.28536603380866, 'dist: ', 83.80306851058225)
# Lpl: 134.090958536
# frequency 860003375 symTime  32.768
# bw 125 sf 12 cr 1 rssi -120.090958536
# sf 12  cr 1 pl 20 bw 125
# rectime node  64    1318.912
# ('node 65', 'x', 172.53326509388148, 'y', 181.02845396425016, 'dist: ', 96.110467561975383)
# Lpl: 135.328782533
# frequency 860005000 symTime  32.768
# bw 125 sf 12 cr 1 rssi -121.328782533
# sf 12  cr 1 pl 20 bw 125
# rectime node  65    1318.912
# ('node 66', 'x', 96.440223105317457, 'y', 112.62895803736508, 'dist: ', 13.041806444621045)
# Lpl: 117.286177391
# frequency 860002250 symTime  32.768
# bw 125 sf 12 cr 1 rssi -103.286177391
# sf 12  cr 1 pl 20 bw 125
# rectime node  66    1318.912
# ('node 67', 'x', 92.571930690879952, 'y', 100.16874556132694, 'dist: ', 18.588194110123386)
# Lpl: 120.48728592
# frequency 860001875 symTime  32.768
# bw 125 sf 12 cr 1 rssi -106.48728592
# sf 12  cr 1 pl 20 bw 125
# rectime node  67    1318.912
# ('node 68', 'x', 39.466696528688075, 'y', 127.1209530336675, 'dist: ', 71.822408860882447)
# Lpl: 132.697359492
# frequency 860001375 symTime  32.768
# bw 125 sf 12 cr 1 rssi -118.697359492
# sf 12  cr 1 pl 20 bw 125
# rectime node  68    1318.912
# ('node 69', 'x', 104.50527055751076, 'y', 181.26559190395446, 'dist: ', 72.448903503412922)
# Lpl: 132.775813972
# frequency 860007500 symTime  32.768
# bw 125 sf 12 cr 1 rssi -118.775813972
# sf 12  cr 1 pl 20 bw 125
# rectime node  69    1318.912

# %%
#prepare show
if (graphics == 1):
    plt.xlim([0, xmax])
    plt.ylim([0, ymax])
    plt.draw()
    plt.show()

# start simulation
env.run(until=simtime)
print("----------------------------")
print("----------------------------")

# print stats and save into file
print "nrCollisions ", nrCollisions

# compute energy
# Transmit consumption in mA from -2 to +17 dBm
TX = [22, 22, 22, 23,                                      # RFO/PA0: -2..1
      24, 24, 24, 25, 25, 25, 25, 26, 31, 32, 34, 35, 44,  # PA_BOOST/PA1: 2..14
      82, 85, 90,                                          # PA_BOOST/PA1: 15..17
      105, 115, 125]                                       # PA_BOOST/PA1+PA2: 18..20
# mA = 90    # current draw for TX = 17 dBm
V = 3.0     # voltage XXX
sent = sum(n.sent for n in nodes)
energy = sum(node.packet.rectime * TX[int(node.packet.txpow)+2] * V * node.sent for node in nodes) / 1e6
timeTotal = sum(n.transmitionTime for n in nodes)


print "energy (in J): ", energy
print "sent packets: ", sent
print "collisions: ", nrCollisions
print "received packets: ", nrReceived
print "processed packets: ", nrProcessed
print "lost packets: ", nrLost
print "Total time to fly: ", timeTotal

# data extraction rate
der = (sent-nrCollisions)/float(sent)
print "DER:", der
der = (nrReceived)/float(sent)
print "DER method 2:", der

# this can be done to keep graphics visible
if (graphics == 1):
    raw_input('Press Enter to continue ...')
# print("----------------------------")
# print("Saving at"),
# # save experiment data into a dat file that can be read by e.g. gnuplot
# # name of file would be:  exp0.dat for experiment 0
# fname = "exp" + str(experiment) + ".dat"
# print fname+'...',
# if os.path.isfile(fname):
#     res = "\n" + str(nrNodes) + " " + str(nrCollisions) + " "  + str(sent) + " " + str(energy) + " " + str(nrReceived) + " " + str(nrProcessed) + " " + str(timeTotal)
# else:
#     res = "#nrNodes nrCollisions nrTransmissions OverallEnergy nrReceived nrProcessed timeToFly\n" + str(nrNodes) + " " + str(nrCollisions) + " "  + str(sent) + " " + str(energy) + " " + str(nrReceived) + " " + str(nrProcessed) + " " + str(timeTotal)
# with open(fname, "a") as myfile:
#     myfile.write(res)
# myfile.close()
# print('done.')
print("----------------------------")
print("----------------------------")
# with open('nodes.txt','w') as nfile:
#     for n in nodes:
#         nfile.write("{} {} {}\n".format(n.x, n.y, n.nodeid))
# with open('basestation.txt', 'w') as bfile:
#     bfile.write("{} {} {}\n".format(bsx, bsy, 0))
# Out:
# CHECK node 27 (sf:12 bw:125 freq:8.600040e+08) others: 1
# >> node 45 (sf:12 bw:125 freq:8.600068e+08)
# no frequency coll
# CHECK node 14 (sf:12 bw:125 freq:8.600064e+08) others: 1
# >> node 5 (sf:12 bw:125 freq:8.600080e+08)
# no frequency coll
# CHECK node 26 (sf:12 bw:125 freq:8.600080e+08) others: 1
# >> node 51 (sf:12 bw:125 freq:8.600025e+08)
# no frequency coll
# CHECK node 4 (sf:12 bw:125 freq:8.600064e+08) others: 1
# >> node 32 (sf:12 bw:125 freq:8.600064e+08)
# frequency coll 125
# collision sf node 4 and node 32
# CHECK node 34 (sf:12 bw:125 freq:8.600019e+08) others: 1
# >> node 23 (sf:12 bw:125 freq:8.600001e+08)
# no frequency coll
# CHECK node 3 (sf:12 bw:125 freq:8.600015e+08) others: 1
# >> node 17 (sf:12 bw:125 freq:8.600058e+08)
# no frequency coll
# CHECK node 22 (sf:12 bw:125 freq:8.600016e+08) others: 1
# >> node 68 (sf:12 bw:125 freq:8.600014e+08)
# no frequency coll
# CHECK node 63 (sf:12 bw:125 freq:8.600005e+08) others: 1
# >> node 20 (sf:12 bw:125 freq:8.600006e+08)
# no frequency coll
# CHECK node 60 (sf:12 bw:125 freq:8.600001e+08) others: 1
# >> node 48 (sf:12 bw:125 freq:8.600026e+08)
# no frequency coll
# CHECK node 22 (sf:12 bw:125 freq:8.600016e+08) others: 1
# >> node 8 (sf:12 bw:125 freq:8.600068e+08)
# no frequency coll
# CHECK node 30 (sf:12 bw:125 freq:8.600055e+08) others: 1
# >> node 22 (sf:12 bw:125 freq:8.600016e+08)
# no frequency coll
# CHECK node 9 (sf:12 bw:125 freq:8.600079e+08) others: 2
# >> node 22 (sf:12 bw:125 freq:8.600016e+08)
# no frequency coll
# >> node 30 (sf:12 bw:125 freq:8.600055e+08)
# no frequency coll
# CHECK node 25 (sf:12 bw:125 freq:8.600045e+08) others: 1
# >> node 55 (sf:12 bw:125 freq:8.600009e+08)
# no frequency coll
# CHECK node 20 (sf:12 bw:125 freq:8.600006e+08) others: 1
# >> node 30 (sf:12 bw:125 freq:8.600055e+08)
# no frequency coll
# CHECK node 40 (sf:12 bw:125 freq:8.600040e+08) others: 1
# >> node 51 (sf:12 bw:125 freq:8.600025e+08)
# no frequency coll
# CHECK node 6 (sf:12 bw:125 freq:8.600065e+08) others: 1
# >> node 16 (sf:12 bw:125 freq:8.600005e+08)
# no frequency coll
# CHECK node 3 (sf:12 bw:125 freq:8.600015e+08) others: 1
# >> node 56 (sf:12 bw:125 freq:8.600019e+08)
# no frequency coll
# CHECK node 37 (sf:12 bw:125 freq:8.600080e+08) others: 1
# >> node 14 (sf:12 bw:125 freq:8.600064e+08)
# no frequency coll
# CHECK node 44 (sf:12 bw:125 freq:8.600012e+08) others: 1
# >> node 59 (sf:12 bw:125 freq:8.600066e+08)
# no frequency coll
# CHECK node 4 (sf:12 bw:125 freq:8.600064e+08) others: 1
# >> node 52 (sf:12 bw:125 freq:8.600022e+08)
# no frequency coll
# CHECK node 58 (sf:12 bw:125 freq:8.600041e+08) others: 1
# >> node 8 (sf:12 bw:125 freq:8.600068e+08)
# no frequency coll
# CHECK node 31 (sf:12 bw:125 freq:8.600008e+08) others: 1
# >> node 47 (sf:12 bw:125 freq:8.600068e+08)
# no frequency coll
# CHECK node 1 (sf:12 bw:125 freq:8.600062e+08) others: 1
# >> node 31 (sf:12 bw:125 freq:8.600008e+08)
# no frequency coll
# CHECK node 55 (sf:12 bw:125 freq:8.600009e+08) others: 1
# >> node 11 (sf:12 bw:125 freq:8.600058e+08)
# no frequency coll
# CHECK node 67 (sf:12 bw:125 freq:8.600019e+08) others: 1
# >> node 35 (sf:12 bw:125 freq:8.600034e+08)
# no frequency coll
# CHECK node 45 (sf:12 bw:125 freq:8.600068e+08) others: 1
# >> node 5 (sf:12 bw:125 freq:8.600080e+08)
# no frequency coll
# CHECK node 39 (sf:12 bw:125 freq:8.600056e+08) others: 1
# >> node 63 (sf:12 bw:125 freq:8.600005e+08)
# no frequency coll
# CHECK node 68 (sf:12 bw:125 freq:8.600014e+08) others: 1
# >> node 30 (sf:12 bw:125 freq:8.600055e+08)
# no frequency coll
# CHECK node 53 (sf:12 bw:125 freq:8.600078e+08) others: 1
# >> node 7 (sf:12 bw:125 freq:8.600034e+08)
# no frequency coll
# CHECK node 60 (sf:12 bw:125 freq:8.600001e+08) others: 1
# >> node 7 (sf:12 bw:125 freq:8.600034e+08)
# no frequency coll
# CHECK node 16 (sf:12 bw:125 freq:8.600005e+08) others: 1
# >> node 36 (sf:12 bw:125 freq:8.600061e+08)
# no frequency coll
# CHECK node 22 (sf:12 bw:125 freq:8.600016e+08) others: 1
# >> node 18 (sf:12 bw:125 freq:8.600036e+08)
# no frequency coll
# CHECK node 2 (sf:12 bw:125 freq:8.600024e+08) others: 1
# >> node 52 (sf:12 bw:125 freq:8.600022e+08)
# no frequency coll
# CHECK node 32 (sf:12 bw:125 freq:8.600064e+08) others: 1
# >> node 11 (sf:12 bw:125 freq:8.600058e+08)
# no frequency coll
# CHECK node 1 (sf:12 bw:125 freq:8.600062e+08) others: 1
# >> node 37 (sf:12 bw:125 freq:8.600080e+08)
# no frequency coll
# CHECK node 42 (sf:12 bw:125 freq:8.600072e+08) others: 1
# >> node 53 (sf:12 bw:125 freq:8.600078e+08)
# no frequency coll
# CHECK node 0 (sf:12 bw:125 freq:8.600029e+08) others: 1
# >> node 53 (sf:12 bw:125 freq:8.600078e+08)
# no frequency coll
# CHECK node 48 (sf:12 bw:125 freq:8.600026e+08) others: 1
# >> node 0 (sf:12 bw:125 freq:8.600029e+08)
# no frequency coll
# CHECK node 6 (sf:12 bw:125 freq:8.600065e+08) others: 1
# >> node 25 (sf:12 bw:125 freq:8.600045e+08)
# no frequency coll
# CHECK node 3 (sf:12 bw:125 freq:8.600015e+08) others: 1
# >> node 61 (sf:12 bw:125 freq:8.600030e+08)
# no frequency coll
# CHECK node 15 (sf:12 bw:125 freq:8.600024e+08) others: 1
# >> node 57 (sf:12 bw:125 freq:8.600062e+08)
# no frequency coll
# CHECK node 34 (sf:12 bw:125 freq:8.600019e+08) others: 1
# >> node 4 (sf:12 bw:125 freq:8.600064e+08)
# no frequency coll
# CHECK node 3 (sf:12 bw:125 freq:8.600015e+08) others: 1
# >> node 50 (sf:12 bw:125 freq:8.600080e+08)
# no frequency coll
# CHECK node 30 (sf:12 bw:125 freq:8.600055e+08) others: 1
# >> node 9 (sf:12 bw:125 freq:8.600079e+08)
# no frequency coll
# CHECK node 29 (sf:12 bw:125 freq:8.600020e+08) others: 1
# >> node 69 (sf:12 bw:125 freq:8.600075e+08)
# no frequency coll
# CHECK node 55 (sf:12 bw:125 freq:8.600009e+08) others: 1
# >> node 23 (sf:12 bw:125 freq:8.600001e+08)
# no frequency coll
# CHECK node 33 (sf:12 bw:125 freq:8.600066e+08) others: 1
# >> node 31 (sf:12 bw:125 freq:8.600008e+08)
# no frequency coll
# CHECK node 61 (sf:12 bw:125 freq:8.600030e+08) others: 1
# >> node 15 (sf:12 bw:125 freq:8.600024e+08)
# no frequency coll
# CHECK node 67 (sf:12 bw:125 freq:8.600019e+08) others: 1
# >> node 12 (sf:12 bw:125 freq:8.600024e+08)
# no frequency coll
# CHECK node 62 (sf:12 bw:125 freq:8.600054e+08) others: 1
# >> node 18 (sf:12 bw:125 freq:8.600036e+08)
# no frequency coll
# CHECK node 19 (sf:12 bw:125 freq:8.600034e+08) others: 1
# >> node 14 (sf:12 bw:125 freq:8.600064e+08)
# no frequency coll
# CHECK node 31 (sf:12 bw:125 freq:8.600008e+08) others: 1
# >> node 47 (sf:12 bw:125 freq:8.600068e+08)
# no frequency coll
# CHECK node 61 (sf:12 bw:125 freq:8.600030e+08) others: 1
# >> node 47 (sf:12 bw:125 freq:8.600068e+08)
# no frequency coll
# CHECK node 45 (sf:12 bw:125 freq:8.600068e+08) others: 1
# >> node 61 (sf:12 bw:125 freq:8.600030e+08)
# no frequency coll
# CHECK node 48 (sf:12 bw:125 freq:8.600026e+08) others: 1
# >> node 37 (sf:12 bw:125 freq:8.600080e+08)
# no frequency coll
# CHECK node 11 (sf:12 bw:125 freq:8.600058e+08) others: 1
# >> node 66 (sf:12 bw:125 freq:8.600022e+08)
# no frequency coll
# CHECK node 3 (sf:12 bw:125 freq:8.600015e+08) others: 1
# >> node 15 (sf:12 bw:125 freq:8.600024e+08)
# no frequency coll
# CHECK node 45 (sf:12 bw:125 freq:8.600068e+08) others: 1
# >> node 39 (sf:12 bw:125 freq:8.600056e+08)
# no frequency coll
# CHECK node 34 (sf:12 bw:125 freq:8.600019e+08) others: 1
# >> node 47 (sf:12 bw:125 freq:8.600068e+08)
# no frequency coll
# CHECK node 47 (sf:12 bw:125 freq:8.600068e+08) others: 1
# >> node 2 (sf:12 bw:125 freq:8.600024e+08)
# no frequency coll
# CHECK node 14 (sf:12 bw:125 freq:8.600064e+08) others: 1
# >> node 68 (sf:12 bw:125 freq:8.600014e+08)
# no frequency coll
# CHECK node 58 (sf:12 bw:125 freq:8.600041e+08) others: 1
# >> node 14 (sf:12 bw:125 freq:8.600064e+08)
# no frequency coll
# CHECK node 48 (sf:12 bw:125 freq:8.600026e+08) others: 1
# >> node 23 (sf:12 bw:125 freq:8.600001e+08)
# no frequency coll
# CHECK node 68 (sf:12 bw:125 freq:8.600014e+08) others: 1
# >> node 60 (sf:12 bw:125 freq:8.600001e+08)
# no frequency coll
# CHECK node 37 (sf:12 bw:125 freq:8.600080e+08) others: 1
# >> node 62 (sf:12 bw:125 freq:8.600054e+08)
# no frequency coll
# CHECK node 26 (sf:12 bw:125 freq:8.600080e+08) others: 1
# >> node 34 (sf:12 bw:125 freq:8.600019e+08)
# no frequency coll
# CHECK node 39 (sf:12 bw:125 freq:8.600056e+08) others: 1
# >> node 26 (sf:12 bw:125 freq:8.600080e+08)
# no frequency coll
# CHECK node 10 (sf:12 bw:125 freq:8.600018e+08) others: 1
# >> node 57 (sf:12 bw:125 freq:8.600062e+08)
# no frequency coll
# CHECK node 39 (sf:12 bw:125 freq:8.600056e+08) others: 1
# >> node 61 (sf:12 bw:125 freq:8.600030e+08)
# no frequency coll
# CHECK node 16 (sf:12 bw:125 freq:8.600005e+08) others: 1
# >> node 39 (sf:12 bw:125 freq:8.600056e+08)
# no frequency coll
# CHECK node 40 (sf:12 bw:125 freq:8.600040e+08) others: 1
# >> node 1 (sf:12 bw:125 freq:8.600062e+08)
# no frequency coll
# CHECK node 21 (sf:12 bw:125 freq:8.600065e+08) others: 1
# >> node 27 (sf:12 bw:125 freq:8.600040e+08)
# no frequency coll
# CHECK node 32 (sf:12 bw:125 freq:8.600064e+08) others: 1
# >> node 41 (sf:12 bw:125 freq:8.600045e+08)
# no frequency coll
# CHECK node 66 (sf:12 bw:125 freq:8.600022e+08) others: 1
# >> node 57 (sf:12 bw:125 freq:8.600062e+08)
# no frequency coll
# CHECK node 59 (sf:12 bw:125 freq:8.600066e+08) others: 1
# >> node 23 (sf:12 bw:125 freq:8.600001e+08)
# no frequency coll
# CHECK node 55 (sf:12 bw:125 freq:8.600009e+08) others: 1
# >> node 16 (sf:12 bw:125 freq:8.600005e+08)
# no frequency coll
# CHECK node 57 (sf:12 bw:125 freq:8.600062e+08) others: 1
# >> node 32 (sf:12 bw:125 freq:8.600064e+08)
# no frequency coll
# CHECK node 1 (sf:12 bw:125 freq:8.600062e+08) others: 1
# >> node 24 (sf:12 bw:125 freq:8.600045e+08)
# no frequency coll
# CHECK node 64 (sf:12 bw:125 freq:8.600034e+08) others: 1
# >> node 30 (sf:12 bw:125 freq:8.600055e+08)
# no frequency coll
# CHECK node 67 (sf:12 bw:125 freq:8.600019e+08) others: 1
# >> node 59 (sf:12 bw:125 freq:8.600066e+08)
# no frequency coll
# CHECK node 64 (sf:12 bw:125 freq:8.600034e+08) others: 1
# >> node 58 (sf:12 bw:125 freq:8.600041e+08)
# no frequency coll
# CHECK node 58 (sf:12 bw:125 freq:8.600041e+08) others: 1
# >> node 69 (sf:12 bw:125 freq:8.600075e+08)
# no frequency coll
# CHECK node 38 (sf:12 bw:125 freq:8.600061e+08) others: 1
# >> node 14 (sf:12 bw:125 freq:8.600064e+08)
# no frequency coll
# CHECK node 33 (sf:12 bw:125 freq:8.600066e+08) others: 1
# >> node 19 (sf:12 bw:125 freq:8.600034e+08)
# no frequency coll
# CHECK node 61 (sf:12 bw:125 freq:8.600030e+08) others: 1
# >> node 59 (sf:12 bw:125 freq:8.600066e+08)
# no frequency coll
# CHECK node 64 (sf:12 bw:125 freq:8.600034e+08) others: 1
# >> node 25 (sf:12 bw:125 freq:8.600045e+08)
# no frequency coll
# CHECK node 64 (sf:12 bw:125 freq:8.600034e+08) others: 1
# >> node 5 (sf:12 bw:125 freq:8.600080e+08)
# no frequency coll
# CHECK node 6 (sf:12 bw:125 freq:8.600065e+08) others: 1
# >> node 50 (sf:12 bw:125 freq:8.600080e+08)
# no frequency coll
# CHECK node 57 (sf:12 bw:125 freq:8.600062e+08) others: 1
# >> node 56 (sf:12 bw:125 freq:8.600019e+08)
# no frequency coll
# CHECK node 67 (sf:12 bw:125 freq:8.600019e+08) others: 1
# >> node 2 (sf:12 bw:125 freq:8.600024e+08)
# no frequency coll
# CHECK node 31 (sf:12 bw:125 freq:8.600008e+08) others: 1
# >> node 50 (sf:12 bw:125 freq:8.600080e+08)
# no frequency coll
# CHECK node 29 (sf:12 bw:125 freq:8.600020e+08) others: 1
# >> node 46 (sf:12 bw:125 freq:8.600036e+08)
# no frequency coll
# CHECK node 13 (sf:12 bw:125 freq:8.600066e+08) others: 1
# >> node 14 (sf:12 bw:125 freq:8.600064e+08)
# no frequency coll
# CHECK node 63 (sf:12 bw:125 freq:8.600005e+08) others: 1
# >> node 64 (sf:12 bw:125 freq:8.600034e+08)
# no frequency coll
# CHECK node 31 (sf:12 bw:125 freq:8.600008e+08) others: 1
# >> node 19 (sf:12 bw:125 freq:8.600034e+08)
# no frequency coll
# CHECK node 4 (sf:12 bw:125 freq:8.600064e+08) others: 1
# >> node 31 (sf:12 bw:125 freq:8.600008e+08)
# no frequency coll
# CHECK node 39 (sf:12 bw:125 freq:8.600056e+08) others: 1
# >> node 66 (sf:12 bw:125 freq:8.600022e+08)
# no frequency coll
# CHECK node 55 (sf:12 bw:125 freq:8.600009e+08) others: 1
# >> node 59 (sf:12 bw:125 freq:8.600066e+08)
# no frequency coll
# CHECK node 67 (sf:12 bw:125 freq:8.600019e+08) others: 1
# >> node 64 (sf:12 bw:125 freq:8.600034e+08)
# no frequency coll
# CHECK node 3 (sf:12 bw:125 freq:8.600015e+08) others: 1
# >> node 53 (sf:12 bw:125 freq:8.600078e+08)
# no frequency coll
# CHECK node 6 (sf:12 bw:125 freq:8.600065e+08) others: 1
# >> node 29 (sf:12 bw:125 freq:8.600020e+08)
# no frequency coll
# CHECK node 12 (sf:12 bw:125 freq:8.600024e+08) others: 1
# >> node 24 (sf:12 bw:125 freq:8.600045e+08)
# no frequency coll
# CHECK node 24 (sf:12 bw:125 freq:8.600045e+08) others: 1
# >> node 34 (sf:12 bw:125 freq:8.600019e+08)
# no frequency coll
# CHECK node 66 (sf:12 bw:125 freq:8.600022e+08) others: 1
# >> node 51 (sf:12 bw:125 freq:8.600025e+08)
# no frequency coll
# CHECK node 2 (sf:12 bw:125 freq:8.600024e+08) others: 1
# >> node 63 (sf:12 bw:125 freq:8.600005e+08)
# no frequency coll
# CHECK node 35 (sf:12 bw:125 freq:8.600034e+08) others: 1
# >> node 49 (sf:12 bw:125 freq:8.600072e+08)
# no frequency coll
# CHECK node 65 (sf:12 bw:125 freq:8.600050e+08) others: 1
# >> node 51 (sf:12 bw:125 freq:8.600025e+08)
# no frequency coll
# CHECK node 24 (sf:12 bw:125 freq:8.600045e+08) others: 1
# >> node 68 (sf:12 bw:125 freq:8.600014e+08)
# no frequency coll
# CHECK node 25 (sf:12 bw:125 freq:8.600045e+08) others: 1
# >> node 39 (sf:12 bw:125 freq:8.600056e+08)
# no frequency coll
# CHECK node 58 (sf:12 bw:125 freq:8.600041e+08) others: 1
# >> node 33 (sf:12 bw:125 freq:8.600066e+08)
# no frequency coll
# CHECK node 60 (sf:12 bw:125 freq:8.600001e+08) others: 1
# >> node 58 (sf:12 bw:125 freq:8.600041e+08)
# no frequency coll
# CHECK node 51 (sf:12 bw:125 freq:8.600025e+08) others: 2
# >> node 58 (sf:12 bw:125 freq:8.600041e+08)
# no frequency coll
# >> node 60 (sf:12 bw:125 freq:8.600001e+08)
# no frequency coll
# CHECK node 12 (sf:12 bw:125 freq:8.600024e+08) others: 1
# >> node 64 (sf:12 bw:125 freq:8.600034e+08)
# no frequency coll
# CHECK node 38 (sf:12 bw:125 freq:8.600061e+08) others: 1
# >> node 56 (sf:12 bw:125 freq:8.600019e+08)
# no frequency coll
# CHECK node 43 (sf:12 bw:125 freq:8.600036e+08) others: 2
# >> node 56 (sf:12 bw:125 freq:8.600019e+08)
# no frequency coll
# >> node 38 (sf:12 bw:125 freq:8.600061e+08)
# no frequency coll
# CHECK node 9 (sf:12 bw:125 freq:8.600079e+08) others: 1
# >> node 6 (sf:12 bw:125 freq:8.600065e+08)
# no frequency coll
# CHECK node 3 (sf:12 bw:125 freq:8.600015e+08) others: 1
# >> node 36 (sf:12 bw:125 freq:8.600061e+08)
# no frequency coll
# CHECK node 16 (sf:12 bw:125 freq:8.600005e+08) others: 1
# >> node 59 (sf:12 bw:125 freq:8.600066e+08)
# no frequency coll
# CHECK node 20 (sf:12 bw:125 freq:8.600006e+08) others: 1
# >> node 44 (sf:12 bw:125 freq:8.600012e+08)
# no frequency coll
# CHECK node 66 (sf:12 bw:125 freq:8.600022e+08) others: 1
# >> node 7 (sf:12 bw:125 freq:8.600034e+08)
# no frequency coll
# CHECK node 53 (sf:12 bw:125 freq:8.600078e+08) others: 1
# >> node 41 (sf:12 bw:125 freq:8.600045e+08)
# no frequency coll
# CHECK node 38 (sf:12 bw:125 freq:8.600061e+08) others: 1
# >> node 37 (sf:12 bw:125 freq:8.600080e+08)
# no frequency coll
# CHECK node 55 (sf:12 bw:125 freq:8.600009e+08) others: 1
# >> node 21 (sf:12 bw:125 freq:8.600065e+08)
# no frequency coll
# CHECK node 37 (sf:12 bw:125 freq:8.600080e+08) others: 1
# >> node 62 (sf:12 bw:125 freq:8.600054e+08)
# no frequency coll
# CHECK node 32 (sf:12 bw:125 freq:8.600064e+08) others: 1
# >> node 19 (sf:12 bw:125 freq:8.600034e+08)
# no frequency coll
# CHECK node 64 (sf:12 bw:125 freq:8.600034e+08) others: 1
# >> node 18 (sf:12 bw:125 freq:8.600036e+08)
# no frequency coll
# CHECK node 63 (sf:12 bw:125 freq:8.600005e+08) others: 1
# >> node 35 (sf:12 bw:125 freq:8.600034e+08)
# no frequency coll
# CHECK node 58 (sf:12 bw:125 freq:8.600041e+08) others: 1
# >> node 55 (sf:12 bw:125 freq:8.600009e+08)
# no frequency coll
# CHECK node 67 (sf:12 bw:125 freq:8.600019e+08) others: 1
# >> node 54 (sf:12 bw:125 freq:8.600052e+08)
# no frequency coll
# CHECK node 69 (sf:12 bw:125 freq:8.600075e+08) others: 1
# >> node 61 (sf:12 bw:125 freq:8.600030e+08)
# no frequency coll
# CHECK node 48 (sf:12 bw:125 freq:8.600026e+08) others: 1
# >> node 24 (sf:12 bw:125 freq:8.600045e+08)
# no frequency coll
# CHECK node 10 (sf:12 bw:125 freq:8.600018e+08) others: 1
# >> node 64 (sf:12 bw:125 freq:8.600034e+08)
# no frequency coll
# CHECK node 50 (sf:12 bw:125 freq:8.600080e+08) others: 1
# >> node 43 (sf:12 bw:125 freq:8.600036e+08)
# no frequency coll
# CHECK node 47 (sf:12 bw:125 freq:8.600068e+08) others: 1
# >> node 19 (sf:12 bw:125 freq:8.600034e+08)
# no frequency coll
# CHECK node 47 (sf:12 bw:125 freq:8.600068e+08) others: 1
# >> node 17 (sf:12 bw:125 freq:8.600058e+08)
# no frequency coll
# CHECK node 31 (sf:12 bw:125 freq:8.600008e+08) others: 1
# >> node 53 (sf:12 bw:125 freq:8.600078e+08)
# no frequency coll
# CHECK node 68 (sf:12 bw:125 freq:8.600014e+08) others: 1
# >> node 57 (sf:12 bw:125 freq:8.600062e+08)
# no frequency coll
# CHECK node 39 (sf:12 bw:125 freq:8.600056e+08) others: 1
# >> node 63 (sf:12 bw:125 freq:8.600005e+08)
# no frequency coll
# CHECK node 52 (sf:12 bw:125 freq:8.600022e+08) others: 1
# >> node 35 (sf:12 bw:125 freq:8.600034e+08)
# no frequency coll
# CHECK node 19 (sf:12 bw:125 freq:8.600034e+08) others: 1
# >> node 62 (sf:12 bw:125 freq:8.600054e+08)
# no frequency coll
# CHECK node 69 (sf:12 bw:125 freq:8.600075e+08) others: 1
# >> node 3 (sf:12 bw:125 freq:8.600015e+08)
# no frequency coll
# CHECK node 32 (sf:12 bw:125 freq:8.600064e+08) others: 1
# >> node 66 (sf:12 bw:125 freq:8.600022e+08)
# no frequency coll
# CHECK node 9 (sf:12 bw:125 freq:8.600079e+08) others: 1
# >> node 67 (sf:12 bw:125 freq:8.600019e+08)
# no frequency coll
# CHECK node 23 (sf:12 bw:125 freq:8.600001e+08) others: 1
# >> node 9 (sf:12 bw:125 freq:8.600079e+08)
# no frequency coll
# CHECK node 56 (sf:12 bw:125 freq:8.600019e+08) others: 1
# >> node 38 (sf:12 bw:125 freq:8.600061e+08)
# no frequency coll
# CHECK node 10 (sf:12 bw:125 freq:8.600018e+08) others: 1
# >> node 16 (sf:12 bw:125 freq:8.600005e+08)
# no frequency coll
# CHECK node 19 (sf:12 bw:125 freq:8.600034e+08) others: 1
# >> node 50 (sf:12 bw:125 freq:8.600080e+08)
# no frequency coll
# CHECK node 50 (sf:12 bw:125 freq:8.600080e+08) others: 1
# >> node 53 (sf:12 bw:125 freq:8.600078e+08)
# no frequency coll
# CHECK node 2 (sf:12 bw:125 freq:8.600024e+08) others: 1
# >> node 46 (sf:12 bw:125 freq:8.600036e+08)
# no frequency coll
# CHECK node 35 (sf:12 bw:125 freq:8.600034e+08) others: 1
# >> node 26 (sf:12 bw:125 freq:8.600080e+08)
# no frequency coll
# CHECK node 62 (sf:12 bw:125 freq:8.600054e+08) others: 1
# >> node 25 (sf:12 bw:125 freq:8.600045e+08)
# no frequency coll
# CHECK node 56 (sf:12 bw:125 freq:8.600019e+08) others: 1
# >> node 62 (sf:12 bw:125 freq:8.600054e+08)
# no frequency coll
# CHECK node 55 (sf:12 bw:125 freq:8.600009e+08) others: 1
# >> node 42 (sf:12 bw:125 freq:8.600072e+08)
# no frequency coll
# CHECK node 41 (sf:12 bw:125 freq:8.600045e+08) others: 1
# >> node 6 (sf:12 bw:125 freq:8.600065e+08)
# no frequency coll
# CHECK node 55 (sf:12 bw:125 freq:8.600009e+08) others: 1
# >> node 35 (sf:12 bw:125 freq:8.600034e+08)
# no frequency coll
# CHECK node 58 (sf:12 bw:125 freq:8.600041e+08) others: 1
# >> node 36 (sf:12 bw:125 freq:8.600061e+08)
# no frequency coll
# CHECK node 69 (sf:12 bw:125 freq:8.600075e+08) others: 1
# >> node 45 (sf:12 bw:125 freq:8.600068e+08)
# no frequency coll
# CHECK node 48 (sf:12 bw:125 freq:8.600026e+08) others: 1
# >> node 22 (sf:12 bw:125 freq:8.600016e+08)
# no frequency coll
# CHECK node 29 (sf:12 bw:125 freq:8.600020e+08) others: 2
# >> node 22 (sf:12 bw:125 freq:8.600016e+08)
# no frequency coll
# >> node 48 (sf:12 bw:125 freq:8.600026e+08)
# no frequency coll
# CHECK node 25 (sf:12 bw:125 freq:8.600045e+08) others: 1
# >> node 23 (sf:12 bw:125 freq:8.600001e+08)
# no frequency coll
# CHECK node 21 (sf:12 bw:125 freq:8.600065e+08) others: 1
# >> node 65 (sf:12 bw:125 freq:8.600050e+08)
# no frequency coll
# CHECK node 45 (sf:12 bw:125 freq:8.600068e+08) others: 1
# >> node 41 (sf:12 bw:125 freq:8.600045e+08)
# no frequency coll
# CHECK node 11 (sf:12 bw:125 freq:8.600058e+08) others: 1
# >> node 45 (sf:12 bw:125 freq:8.600068e+08)
# no frequency coll
# CHECK node 64 (sf:12 bw:125 freq:8.600034e+08) others: 1
# >> node 29 (sf:12 bw:125 freq:8.600020e+08)
# no frequency coll
# CHECK node 5 (sf:12 bw:125 freq:8.600080e+08) others: 1
# >> node 47 (sf:12 bw:125 freq:8.600068e+08)
# no frequency coll
# CHECK node 47 (sf:12 bw:125 freq:8.600068e+08) others: 1
# >> node 52 (sf:12 bw:125 freq:8.600022e+08)
# no frequency coll
# CHECK node 45 (sf:12 bw:125 freq:8.600068e+08) others: 1
# >> node 7 (sf:12 bw:125 freq:8.600034e+08)
# no frequency coll
# CHECK node 3 (sf:12 bw:125 freq:8.600015e+08) others: 1
# >> node 20 (sf:12 bw:125 freq:8.600006e+08)
# no frequency coll
# CHECK node 1 (sf:12 bw:125 freq:8.600062e+08) others: 1
# >> node 56 (sf:12 bw:125 freq:8.600019e+08)
# no frequency coll
# CHECK node 62 (sf:12 bw:125 freq:8.600054e+08) others: 1
# >> node 20 (sf:12 bw:125 freq:8.600006e+08)
# no frequency coll
# CHECK node 59 (sf:12 bw:125 freq:8.600066e+08) others: 1
# >> node 35 (sf:12 bw:125 freq:8.600034e+08)
# no frequency coll
# CHECK node 1 (sf:12 bw:125 freq:8.600062e+08) others: 1
# >> node 43 (sf:12 bw:125 freq:8.600036e+08)
# no frequency coll
# CHECK node 42 (sf:12 bw:125 freq:8.600072e+08) others: 1
# >> node 1 (sf:12 bw:125 freq:8.600062e+08)
# no frequency coll
# CHECK node 12 (sf:12 bw:125 freq:8.600024e+08) others: 1
# >> node 5 (sf:12 bw:125 freq:8.600080e+08)
# no frequency coll
# CHECK node 55 (sf:12 bw:125 freq:8.600009e+08) others: 2
# >> node 5 (sf:12 bw:125 freq:8.600080e+08)
# no frequency coll
# >> node 12 (sf:12 bw:125 freq:8.600024e+08)
# no frequency coll
# CHECK node 30 (sf:12 bw:125 freq:8.600055e+08) others: 1
# >> node 36 (sf:12 bw:125 freq:8.600061e+08)
# no frequency coll
# CHECK node 1 (sf:12 bw:125 freq:8.600062e+08) others: 2
# >> node 36 (sf:12 bw:125 freq:8.600061e+08)
# no frequency coll
# >> node 30 (sf:12 bw:125 freq:8.600055e+08)
# no frequency coll
# CHECK node 47 (sf:12 bw:125 freq:8.600068e+08) others: 1
# >> node 33 (sf:12 bw:125 freq:8.600066e+08)
# no frequency coll
# CHECK node 58 (sf:12 bw:125 freq:8.600041e+08) others: 1
# >> node 23 (sf:12 bw:125 freq:8.600001e+08)
# no frequency coll
# CHECK node 67 (sf:12 bw:125 freq:8.600019e+08) others: 1
# >> node 20 (sf:12 bw:125 freq:8.600006e+08)
# no frequency coll
# CHECK node 44 (sf:12 bw:125 freq:8.600012e+08) others: 2
# >> node 20 (sf:12 bw:125 freq:8.600006e+08)
# no frequency coll
# >> node 67 (sf:12 bw:125 freq:8.600019e+08)
# no frequency coll
# CHECK node 24 (sf:12 bw:125 freq:8.600045e+08) others: 1
# >> node 55 (sf:12 bw:125 freq:8.600009e+08)
# no frequency coll
# CHECK node 29 (sf:12 bw:125 freq:8.600020e+08) others: 1
# >> node 55 (sf:12 bw:125 freq:8.600009e+08)
# no frequency coll
# CHECK node 23 (sf:12 bw:125 freq:8.600001e+08) others: 1
# >> node 50 (sf:12 bw:125 freq:8.600080e+08)
# no frequency coll
# CHECK node 49 (sf:12 bw:125 freq:8.600072e+08) others: 1
# >> node 39 (sf:12 bw:125 freq:8.600056e+08)
# no frequency coll
# CHECK node 1 (sf:12 bw:125 freq:8.600062e+08) others: 1
# >> node 48 (sf:12 bw:125 freq:8.600026e+08)
# no frequency coll
# CHECK node 54 (sf:12 bw:125 freq:8.600052e+08) others: 1
# >> node 26 (sf:12 bw:125 freq:8.600080e+08)
# no frequency coll
# CHECK node 15 (sf:12 bw:125 freq:8.600024e+08) others: 1
# >> node 43 (sf:12 bw:125 freq:8.600036e+08)
# no frequency coll
# CHECK node 62 (sf:12 bw:125 freq:8.600054e+08) others: 2
# >> node 43 (sf:12 bw:125 freq:8.600036e+08)
# no frequency coll
# >> node 15 (sf:12 bw:125 freq:8.600024e+08)
# no frequency coll
# CHECK node 44 (sf:12 bw:125 freq:8.600012e+08) others: 1
# >> node 53 (sf:12 bw:125 freq:8.600078e+08)
# no frequency coll
# CHECK node 12 (sf:12 bw:125 freq:8.600024e+08) others: 1
# >> node 0 (sf:12 bw:125 freq:8.600029e+08)
# no frequency coll
# CHECK node 26 (sf:12 bw:125 freq:8.600080e+08) others: 1
# >> node 1 (sf:12 bw:125 freq:8.600062e+08)
# no frequency coll
# CHECK node 68 (sf:12 bw:125 freq:8.600014e+08) others: 1
# >> node 61 (sf:12 bw:125 freq:8.600030e+08)
# no frequency coll
# CHECK node 12 (sf:12 bw:125 freq:8.600024e+08) others: 1
# >> node 22 (sf:12 bw:125 freq:8.600016e+08)
# no frequency coll
# CHECK node 24 (sf:12 bw:125 freq:8.600045e+08) others: 1
# >> node 27 (sf:12 bw:125 freq:8.600040e+08)
# no frequency coll
# CHECK node 13 (sf:12 bw:125 freq:8.600066e+08) others: 2
# >> node 27 (sf:12 bw:125 freq:8.600040e+08)
# no frequency coll
# >> node 24 (sf:12 bw:125 freq:8.600045e+08)
# no frequency coll
# CHECK node 65 (sf:12 bw:125 freq:8.600050e+08) others: 1
# >> node 6 (sf:12 bw:125 freq:8.600065e+08)
# no frequency coll
# CHECK node 13 (sf:12 bw:125 freq:8.600066e+08) others: 1
# >> node 37 (sf:12 bw:125 freq:8.600080e+08)
# no frequency coll
# CHECK node 52 (sf:12 bw:125 freq:8.600022e+08) others: 1
# >> node 53 (sf:12 bw:125 freq:8.600078e+08)
# no frequency coll
# CHECK node 30 (sf:12 bw:125 freq:8.600055e+08) others: 1
# >> node 52 (sf:12 bw:125 freq:8.600022e+08)
# no frequency coll
# CHECK node 52 (sf:12 bw:125 freq:8.600022e+08) others: 1
# >> node 2 (sf:12 bw:125 freq:8.600024e+08)
# no frequency coll
# CHECK node 67 (sf:12 bw:125 freq:8.600019e+08) others: 1
# >> node 66 (sf:12 bw:125 freq:8.600022e+08)
# no frequency coll
# CHECK node 29 (sf:12 bw:125 freq:8.600020e+08) others: 1
# >> node 45 (sf:12 bw:125 freq:8.600068e+08)
# no frequency coll
# CHECK node 66 (sf:12 bw:125 freq:8.600022e+08) others: 1
# >> node 1 (sf:12 bw:125 freq:8.600062e+08)
# no frequency coll
# CHECK node 40 (sf:12 bw:125 freq:8.600040e+08) others: 1
# >> node 9 (sf:12 bw:125 freq:8.600079e+08)
# no frequency coll
# CHECK node 40 (sf:12 bw:125 freq:8.600040e+08) others: 1
# >> node 5 (sf:12 bw:125 freq:8.600080e+08)
# no frequency coll
# CHECK node 45 (sf:12 bw:125 freq:8.600068e+08) others: 1
# >> node 22 (sf:12 bw:125 freq:8.600016e+08)
# no frequency coll
# CHECK node 11 (sf:12 bw:125 freq:8.600058e+08) others: 1
# >> node 3 (sf:12 bw:125 freq:8.600015e+08)
# no frequency coll
# CHECK node 56 (sf:12 bw:125 freq:8.600019e+08) others: 1
# >> node 57 (sf:12 bw:125 freq:8.600062e+08)
# no frequency coll
# CHECK node 29 (sf:12 bw:125 freq:8.600020e+08) others: 1
# >> node 50 (sf:12 bw:125 freq:8.600080e+08)
# no frequency coll
# CHECK node 30 (sf:12 bw:125 freq:8.600055e+08) others: 2
# >> node 50 (sf:12 bw:125 freq:8.600080e+08)
# no frequency coll
# >> node 29 (sf:12 bw:125 freq:8.600020e+08)
# no frequency coll
# CHECK node 58 (sf:12 bw:125 freq:8.600041e+08) others: 1
# >> node 45 (sf:12 bw:125 freq:8.600068e+08)
# no frequency coll
# CHECK node 41 (sf:12 bw:125 freq:8.600045e+08) others: 1
# >> node 20 (sf:12 bw:125 freq:8.600006e+08)
# no frequency coll
# CHECK node 65 (sf:12 bw:125 freq:8.600050e+08) others: 1
# >> node 3 (sf:12 bw:125 freq:8.600015e+08)
# no frequency coll
# CHECK node 32 (sf:12 bw:125 freq:8.600064e+08) others: 1
# >> node 57 (sf:12 bw:125 freq:8.600062e+08)
# no frequency coll
# CHECK node 45 (sf:12 bw:125 freq:8.600068e+08) others: 1
# >> node 7 (sf:12 bw:125 freq:8.600034e+08)
# no frequency coll
# CHECK node 53 (sf:12 bw:125 freq:8.600078e+08) others: 1
# >> node 7 (sf:12 bw:125 freq:8.600034e+08)
# no frequency coll
# CHECK node 58 (sf:12 bw:125 freq:8.600041e+08) others: 1
# >> node 56 (sf:12 bw:125 freq:8.600019e+08)
# no frequency coll
# CHECK node 13 (sf:12 bw:125 freq:8.600066e+08) others: 1
# >> node 57 (sf:12 bw:125 freq:8.600062e+08)
# no frequency coll
# CHECK node 13 (sf:12 bw:125 freq:8.600066e+08) others: 1
# >> node 2 (sf:12 bw:125 freq:8.600024e+08)
# no frequency coll
# CHECK node 31 (sf:12 bw:125 freq:8.600008e+08) others: 1
# >> node 63 (sf:12 bw:125 freq:8.600005e+08)
# no frequency coll
# CHECK node 7 (sf:12 bw:125 freq:8.600034e+08) others: 1
# >> node 31 (sf:12 bw:125 freq:8.600008e+08)
# no frequency coll
# CHECK node 11 (sf:12 bw:125 freq:8.600058e+08) others: 1
# >> node 3 (sf:12 bw:125 freq:8.600015e+08)
# no frequency coll
# CHECK node 26 (sf:12 bw:125 freq:8.600080e+08) others: 1
# >> node 57 (sf:12 bw:125 freq:8.600062e+08)
# no frequency coll
# CHECK node 4 (sf:12 bw:125 freq:8.600064e+08) others: 1
# >> node 53 (sf:12 bw:125 freq:8.600078e+08)
# no frequency coll
# CHECK node 61 (sf:12 bw:125 freq:8.600030e+08) others: 1
# >> node 55 (sf:12 bw:125 freq:8.600009e+08)
# no frequency coll
# CHECK node 14 (sf:12 bw:125 freq:8.600064e+08) others: 1
# >> node 16 (sf:12 bw:125 freq:8.600005e+08)
# no frequency coll
# CHECK node 18 (sf:12 bw:125 freq:8.600036e+08) others: 1
# >> node 21 (sf:12 bw:125 freq:8.600065e+08)
# no frequency coll
# CHECK node 37 (sf:12 bw:125 freq:8.600080e+08) others: 1
# >> node 52 (sf:12 bw:125 freq:8.600022e+08)
# no frequency coll
# CHECK node 20 (sf:12 bw:125 freq:8.600006e+08) others: 1
# >> node 67 (sf:12 bw:125 freq:8.600019e+08)
# no frequency coll
# CHECK node 13 (sf:12 bw:125 freq:8.600066e+08) others: 1
# >> node 22 (sf:12 bw:125 freq:8.600016e+08)
# no frequency coll
# CHECK node 4 (sf:12 bw:125 freq:8.600064e+08) others: 1
# >> node 13 (sf:12 bw:125 freq:8.600066e+08)
# no frequency coll
# CHECK node 11 (sf:12 bw:125 freq:8.600058e+08) others: 1
# >> node 32 (sf:12 bw:125 freq:8.600064e+08)
# no frequency coll
# CHECK node 45 (sf:12 bw:125 freq:8.600068e+08) others: 1
# >> node 60 (sf:12 bw:125 freq:8.600001e+08)
# no frequency coll
# CHECK node 1 (sf:12 bw:125 freq:8.600062e+08) others: 1
# >> node 14 (sf:12 bw:125 freq:8.600064e+08)
# no frequency coll
# CHECK node 53 (sf:12 bw:125 freq:8.600078e+08) others: 1
# >> node 44 (sf:12 bw:125 freq:8.600012e+08)
# no frequency coll
# CHECK node 7 (sf:12 bw:125 freq:8.600034e+08) others: 1
# >> node 48 (sf:12 bw:125 freq:8.600026e+08)
# no frequency coll
# CHECK node 11 (sf:12 bw:125 freq:8.600058e+08) others: 1
# >> node 7 (sf:12 bw:125 freq:8.600034e+08)
# no frequency coll
# CHECK node 1 (sf:12 bw:125 freq:8.600062e+08) others: 1
# >> node 12 (sf:12 bw:125 freq:8.600024e+08)
# no frequency coll
# CHECK node 13 (sf:12 bw:125 freq:8.600066e+08) others: 1
# >> node 68 (sf:12 bw:125 freq:8.600014e+08)
# no frequency coll
# CHECK node 48 (sf:12 bw:125 freq:8.600026e+08) others: 1
# >> node 14 (sf:12 bw:125 freq:8.600064e+08)
# no frequency coll
# CHECK node 49 (sf:12 bw:125 freq:8.600072e+08) others: 1
# >> node 1 (sf:12 bw:125 freq:8.600062e+08)
# no frequency coll
# CHECK node 65 (sf:12 bw:125 freq:8.600050e+08) others: 1
# >> node 51 (sf:12 bw:125 freq:8.600025e+08)
# no frequency coll
# CHECK node 35 (sf:12 bw:125 freq:8.600034e+08) others: 1
# >> node 34 (sf:12 bw:125 freq:8.600019e+08)
# no frequency coll
# CHECK node 14 (sf:12 bw:125 freq:8.600064e+08) others: 1
# >> node 39 (sf:12 bw:125 freq:8.600056e+08)
# no frequency coll
# CHECK node 59 (sf:12 bw:125 freq:8.600066e+08) others: 1
# >> node 17 (sf:12 bw:125 freq:8.600058e+08)
# no frequency coll
# CHECK node 30 (sf:12 bw:125 freq:8.600055e+08) others: 1
# >> node 62 (sf:12 bw:125 freq:8.600054e+08)
# no frequency coll
# CHECK node 64 (sf:12 bw:125 freq:8.600034e+08) others: 1
# >> node 60 (sf:12 bw:125 freq:8.600001e+08)
# no frequency coll
# CHECK node 59 (sf:12 bw:125 freq:8.600066e+08) others: 1
# >> node 64 (sf:12 bw:125 freq:8.600034e+08)
# no frequency coll
# CHECK node 58 (sf:12 bw:125 freq:8.600041e+08) others: 1
# >> node 2 (sf:12 bw:125 freq:8.600024e+08)
# no frequency coll
# CHECK node 61 (sf:12 bw:125 freq:8.600030e+08) others: 1
# >> node 68 (sf:12 bw:125 freq:8.600014e+08)
# no frequency coll
# CHECK node 67 (sf:12 bw:125 freq:8.600019e+08) others: 1
# >> node 19 (sf:12 bw:125 freq:8.600034e+08)
# no frequency coll
# CHECK node 52 (sf:12 bw:125 freq:8.600022e+08) others: 1
# >> node 12 (sf:12 bw:125 freq:8.600024e+08)
# no frequency coll
# CHECK node 43 (sf:12 bw:125 freq:8.600036e+08) others: 1
# >> node 34 (sf:12 bw:125 freq:8.600019e+08)
# no frequency coll
# CHECK node 6 (sf:12 bw:125 freq:8.600065e+08) others: 1
# >> node 48 (sf:12 bw:125 freq:8.600026e+08)
# no frequency coll
# CHECK node 38 (sf:12 bw:125 freq:8.600061e+08) others: 1
# >> node 5 (sf:12 bw:125 freq:8.600080e+08)
# no frequency coll
# CHECK node 10 (sf:12 bw:125 freq:8.600018e+08) others: 1
# >> node 38 (sf:12 bw:125 freq:8.600061e+08)
# no frequency coll
# CHECK node 47 (sf:12 bw:125 freq:8.600068e+08) others: 1
# >> node 6 (sf:12 bw:125 freq:8.600065e+08)
# no frequency coll
# CHECK node 54 (sf:12 bw:125 freq:8.600052e+08) others: 1
# >> node 23 (sf:12 bw:125 freq:8.600001e+08)
# no frequency coll
# CHECK node 38 (sf:12 bw:125 freq:8.600061e+08) others: 1
# >> node 61 (sf:12 bw:125 freq:8.600030e+08)
# no frequency coll
# CHECK node 64 (sf:12 bw:125 freq:8.600034e+08) others: 1
# >> node 1 (sf:12 bw:125 freq:8.600062e+08)
# no frequency coll
# CHECK node 3 (sf:12 bw:125 freq:8.600015e+08) others: 1
# >> node 9 (sf:12 bw:125 freq:8.600079e+08)
# no frequency coll
# CHECK node 13 (sf:12 bw:125 freq:8.600066e+08) others: 1
# >> node 3 (sf:12 bw:125 freq:8.600015e+08)
# no frequency coll
# CHECK node 0 (sf:12 bw:125 freq:8.600029e+08) others: 1
# >> node 34 (sf:12 bw:125 freq:8.600019e+08)
# no frequency coll
# CHECK node 67 (sf:12 bw:125 freq:8.600019e+08) others: 2
# >> node 34 (sf:12 bw:125 freq:8.600019e+08)
# frequency coll 125
# collision sf node 67 and node 34
# >> node 0 (sf:12 bw:125 freq:8.600029e+08)
# no frequency coll
# CHECK node 31 (sf:12 bw:125 freq:8.600008e+08) others: 1
# >> node 33 (sf:12 bw:125 freq:8.600066e+08)
# no frequency coll
# CHECK node 67 (sf:12 bw:125 freq:8.600019e+08) others: 1
# >> node 31 (sf:12 bw:125 freq:8.600008e+08)
# no frequency coll
# CHECK node 6 (sf:12 bw:125 freq:8.600065e+08) others: 1
# >> node 56 (sf:12 bw:125 freq:8.600019e+08)
# no frequency coll
# CHECK node 55 (sf:12 bw:125 freq:8.600009e+08) others: 1
# >> node 37 (sf:12 bw:125 freq:8.600080e+08)
# no frequency coll
# CHECK node 48 (sf:12 bw:125 freq:8.600026e+08) others: 1
# >> node 65 (sf:12 bw:125 freq:8.600050e+08)
# no frequency coll
# CHECK node 9 (sf:12 bw:125 freq:8.600079e+08) others: 1
# >> node 45 (sf:12 bw:125 freq:8.600068e+08)
# no frequency coll
# CHECK node 64 (sf:12 bw:125 freq:8.600034e+08) others: 1
# >> node 25 (sf:12 bw:125 freq:8.600045e+08)
# no frequency coll
# CHECK node 52 (sf:12 bw:125 freq:8.600022e+08) others: 1
# >> node 0 (sf:12 bw:125 freq:8.600029e+08)
# no frequency coll
# CHECK node 16 (sf:12 bw:125 freq:8.600005e+08) others: 1
# >> node 31 (sf:12 bw:125 freq:8.600008e+08)
# no frequency coll
# CHECK node 15 (sf:12 bw:125 freq:8.600024e+08) others: 1
# >> node 9 (sf:12 bw:125 freq:8.600079e+08)
# no frequency coll
# CHECK node 15 (sf:12 bw:125 freq:8.600024e+08) others: 1
# >> node 42 (sf:12 bw:125 freq:8.600072e+08)
# no frequency coll
# CHECK node 60 (sf:12 bw:125 freq:8.600001e+08) others: 1
# >> node 6 (sf:12 bw:125 freq:8.600065e+08)
# no frequency coll
# CHECK node 25 (sf:12 bw:125 freq:8.600045e+08) others: 1
# >> node 69 (sf:12 bw:125 freq:8.600075e+08)
# no frequency coll
# CHECK node 45 (sf:12 bw:125 freq:8.600068e+08) others: 1
# >> node 11 (sf:12 bw:125 freq:8.600058e+08)
# no frequency coll
# CHECK node 34 (sf:12 bw:125 freq:8.600019e+08) others: 1
# >> node 39 (sf:12 bw:125 freq:8.600056e+08)
# no frequency coll
# CHECK node 61 (sf:12 bw:125 freq:8.600030e+08) others: 1
# >> node 28 (sf:12 bw:125 freq:8.600031e+08)
# no frequency coll
# CHECK node 26 (sf:12 bw:125 freq:8.600080e+08) others: 1
# >> node 61 (sf:12 bw:125 freq:8.600030e+08)
# no frequency coll
# CHECK node 49 (sf:12 bw:125 freq:8.600072e+08) others: 2
# >> node 61 (sf:12 bw:125 freq:8.600030e+08)
# no frequency coll
# >> node 26 (sf:12 bw:125 freq:8.600080e+08)
# no frequency coll
# CHECK node 37 (sf:12 bw:125 freq:8.600080e+08) others: 1
# >> node 22 (sf:12 bw:125 freq:8.600016e+08)
# no frequency coll
# CHECK node 19 (sf:12 bw:125 freq:8.600034e+08) others: 1
# >> node 36 (sf:12 bw:125 freq:8.600061e+08)
# no frequency coll
# CHECK node 36 (sf:12 bw:125 freq:8.600061e+08) others: 1
# >> node 25 (sf:12 bw:125 freq:8.600045e+08)
# no frequency coll
# CHECK node 48 (sf:12 bw:125 freq:8.600026e+08) others: 1
# >> node 16 (sf:12 bw:125 freq:8.600005e+08)
# no frequency coll
# CHECK node 57 (sf:12 bw:125 freq:8.600062e+08) others: 1
# >> node 25 (sf:12 bw:125 freq:8.600045e+08)
# no frequency coll
# CHECK node 50 (sf:12 bw:125 freq:8.600080e+08) others: 1
# >> node 40 (sf:12 bw:125 freq:8.600040e+08)
# no frequency coll
# CHECK node 13 (sf:12 bw:125 freq:8.600066e+08) others: 1
# >> node 38 (sf:12 bw:125 freq:8.600061e+08)
# no frequency coll
# CHECK node 69 (sf:12 bw:125 freq:8.600075e+08) others: 1
# >> node 6 (sf:12 bw:125 freq:8.600065e+08)
# no frequency coll
# CHECK node 3 (sf:12 bw:125 freq:8.600015e+08) others: 1
# >> node 0 (sf:12 bw:125 freq:8.600029e+08)
# no frequency coll
# CHECK node 11 (sf:12 bw:125 freq:8.600058e+08) others: 1
# >> node 53 (sf:12 bw:125 freq:8.600078e+08)
# no frequency coll
# CHECK node 6 (sf:12 bw:125 freq:8.600065e+08) others: 1
# >> node 26 (sf:12 bw:125 freq:8.600080e+08)
# no frequency coll
# CHECK node 14 (sf:12 bw:125 freq:8.600064e+08) others: 1
# >> node 44 (sf:12 bw:125 freq:8.600012e+08)
# no frequency coll
# CHECK node 29 (sf:12 bw:125 freq:8.600020e+08) others: 1
# >> node 5 (sf:12 bw:125 freq:8.600080e+08)
# no frequency coll
# CHECK node 20 (sf:12 bw:125 freq:8.600006e+08) others: 1
# >> node 66 (sf:12 bw:125 freq:8.600022e+08)
# no frequency coll
# CHECK node 23 (sf:12 bw:125 freq:8.600001e+08) others: 1
# >> node 4 (sf:12 bw:125 freq:8.600064e+08)
# no frequency coll
# CHECK node 40 (sf:12 bw:125 freq:8.600040e+08) others: 1
# >> node 36 (sf:12 bw:125 freq:8.600061e+08)
# no frequency coll
# CHECK node 25 (sf:12 bw:125 freq:8.600045e+08) others: 1
# >> node 55 (sf:12 bw:125 freq:8.600009e+08)
# no frequency coll
# CHECK node 68 (sf:12 bw:125 freq:8.600014e+08) others: 1
# >> node 45 (sf:12 bw:125 freq:8.600068e+08)
# no frequency coll
# CHECK node 63 (sf:12 bw:125 freq:8.600005e+08) others: 1
# >> node 50 (sf:12 bw:125 freq:8.600080e+08)
# no frequency coll
# CHECK node 65 (sf:12 bw:125 freq:8.600050e+08) others: 1
# >> node 19 (sf:12 bw:125 freq:8.600034e+08)
# no frequency coll
# CHECK node 42 (sf:12 bw:125 freq:8.600072e+08) others: 1
# >> node 36 (sf:12 bw:125 freq:8.600061e+08)
# no frequency coll
# CHECK node 37 (sf:12 bw:125 freq:8.600080e+08) others: 2
# >> node 36 (sf:12 bw:125 freq:8.600061e+08)
# no frequency coll
# >> node 42 (sf:12 bw:125 freq:8.600072e+08)
# no frequency coll
# CHECK node 36 (sf:12 bw:125 freq:8.600061e+08) others: 1
# >> node 3 (sf:12 bw:125 freq:8.600015e+08)
# no frequency coll
# CHECK node 53 (sf:12 bw:125 freq:8.600078e+08) others: 1
# >> node 18 (sf:12 bw:125 freq:8.600036e+08)
# no frequency coll
# CHECK node 47 (sf:12 bw:125 freq:8.600068e+08) others: 1
# >> node 56 (sf:12 bw:125 freq:8.600019e+08)
# no frequency coll
# CHECK node 33 (sf:12 bw:125 freq:8.600066e+08) others: 1
# >> node 7 (sf:12 bw:125 freq:8.600034e+08)
# no frequency coll
# CHECK node 46 (sf:12 bw:125 freq:8.600036e+08) others: 1
# >> node 37 (sf:12 bw:125 freq:8.600080e+08)
# no frequency coll
# CHECK node 19 (sf:12 bw:125 freq:8.600034e+08) others: 1
# >> node 26 (sf:12 bw:125 freq:8.600080e+08)
# no frequency coll
# CHECK node 49 (sf:12 bw:125 freq:8.600072e+08) others: 1
# >> node 59 (sf:12 bw:125 freq:8.600066e+08)
# no frequency coll
# CHECK node 44 (sf:12 bw:125 freq:8.600012e+08) others: 1
# >> node 49 (sf:12 bw:125 freq:8.600072e+08)
# no frequency coll
# CHECK node 24 (sf:12 bw:125 freq:8.600045e+08) others: 1
# >> node 54 (sf:12 bw:125 freq:8.600052e+08)
# no frequency coll
# CHECK node 4 (sf:12 bw:125 freq:8.600064e+08) others: 1
# >> node 22 (sf:12 bw:125 freq:8.600016e+08)
# no frequency coll
# CHECK node 16 (sf:12 bw:125 freq:8.600005e+08) others: 1
# >> node 15 (sf:12 bw:125 freq:8.600024e+08)
# no frequency coll
# CHECK node 11 (sf:12 bw:125 freq:8.600058e+08) others: 1
# >> node 53 (sf:12 bw:125 freq:8.600078e+08)
# no frequency coll
# CHECK node 43 (sf:12 bw:125 freq:8.600036e+08) others: 1
# >> node 52 (sf:12 bw:125 freq:8.600022e+08)
# no frequency coll
# CHECK node 22 (sf:12 bw:125 freq:8.600016e+08) others: 1
# >> node 34 (sf:12 bw:125 freq:8.600019e+08)
# no frequency coll
# CHECK node 46 (sf:12 bw:125 freq:8.600036e+08) others: 1
# >> node 22 (sf:12 bw:125 freq:8.600016e+08)
# no frequency coll
# CHECK node 68 (sf:12 bw:125 freq:8.600014e+08) others: 1
# >> node 69 (sf:12 bw:125 freq:8.600075e+08)
# no frequency coll
# CHECK node 67 (sf:12 bw:125 freq:8.600019e+08) others: 1
# >> node 40 (sf:12 bw:125 freq:8.600040e+08)
# no frequency coll
# CHECK node 12 (sf:12 bw:125 freq:8.600024e+08) others: 1
# >> node 36 (sf:12 bw:125 freq:8.600061e+08)
# no frequency coll
# CHECK node 15 (sf:12 bw:125 freq:8.600024e+08) others: 1
# >> node 47 (sf:12 bw:125 freq:8.600068e+08)
# no frequency coll
# CHECK node 50 (sf:12 bw:125 freq:8.600080e+08) others: 1
# >> node 28 (sf:12 bw:125 freq:8.600031e+08)
# no frequency coll
# CHECK node 22 (sf:12 bw:125 freq:8.600016e+08) others: 1
# >> node 18 (sf:12 bw:125 freq:8.600036e+08)
# no frequency coll
# CHECK node 23 (sf:12 bw:125 freq:8.600001e+08) others: 1
# >> node 63 (sf:12 bw:125 freq:8.600005e+08)
# no frequency coll
# CHECK node 48 (sf:12 bw:125 freq:8.600026e+08) others: 1
# >> node 32 (sf:12 bw:125 freq:8.600064e+08)
# no frequency coll
# CHECK node 59 (sf:12 bw:125 freq:8.600066e+08) others: 1
# >> node 38 (sf:12 bw:125 freq:8.600061e+08)
# no frequency coll
# CHECK node 31 (sf:12 bw:125 freq:8.600008e+08) others: 1
# >> node 54 (sf:12 bw:125 freq:8.600052e+08)
# no frequency coll
# CHECK node 60 (sf:12 bw:125 freq:8.600001e+08) others: 1
# >> node 58 (sf:12 bw:125 freq:8.600041e+08)
# no frequency coll
# CHECK node 14 (sf:12 bw:125 freq:8.600064e+08) others: 1
# >> node 51 (sf:12 bw:125 freq:8.600025e+08)
# no frequency coll
# CHECK node 49 (sf:12 bw:125 freq:8.600072e+08) others: 1
# >> node 58 (sf:12 bw:125 freq:8.600041e+08)
# no frequency coll
# CHECK node 10 (sf:12 bw:125 freq:8.600018e+08) others: 1
# >> node 63 (sf:12 bw:125 freq:8.600005e+08)
# no frequency coll
# CHECK node 27 (sf:12 bw:125 freq:8.600040e+08) others: 1
# >> node 33 (sf:12 bw:125 freq:8.600066e+08)
# no frequency coll
# CHECK node 34 (sf:12 bw:125 freq:8.600019e+08) others: 1
# >> node 17 (sf:12 bw:125 freq:8.600058e+08)
# no frequency coll
# CHECK node 1 (sf:12 bw:125 freq:8.600062e+08) others: 1
# >> node 36 (sf:12 bw:125 freq:8.600061e+08)
# no frequency coll
# CHECK node 27 (sf:12 bw:125 freq:8.600040e+08) others: 1
# >> node 68 (sf:12 bw:125 freq:8.600014e+08)
# no frequency coll
# CHECK node 54 (sf:12 bw:125 freq:8.600052e+08) others: 1
# >> node 16 (sf:12 bw:125 freq:8.600005e+08)
# no frequency coll
# CHECK node 63 (sf:12 bw:125 freq:8.600005e+08) others: 1
# >> node 67 (sf:12 bw:125 freq:8.600019e+08)
# no frequency coll
# CHECK node 63 (sf:12 bw:125 freq:8.600005e+08) others: 1
# >> node 39 (sf:12 bw:125 freq:8.600056e+08)
# no frequency coll
# CHECK node 23 (sf:12 bw:125 freq:8.600001e+08) others: 1
# >> node 2 (sf:12 bw:125 freq:8.600024e+08)
# no frequency coll
# CHECK node 22 (sf:12 bw:125 freq:8.600016e+08) others: 1
# >> node 52 (sf:12 bw:125 freq:8.600022e+08)
# no frequency coll
# CHECK node 55 (sf:12 bw:125 freq:8.600009e+08) others: 1
# >> node 57 (sf:12 bw:125 freq:8.600062e+08)
# no frequency coll
# CHECK node 32 (sf:12 bw:125 freq:8.600064e+08) others: 1
# >> node 63 (sf:12 bw:125 freq:8.600005e+08)
# no frequency coll
# CHECK node 62 (sf:12 bw:125 freq:8.600054e+08) others: 1
# >> node 59 (sf:12 bw:125 freq:8.600066e+08)
# no frequency coll
# CHECK node 37 (sf:12 bw:125 freq:8.600080e+08) others: 1
# >> node 18 (sf:12 bw:125 freq:8.600036e+08)
# no frequency coll
# CHECK node 34 (sf:12 bw:125 freq:8.600019e+08) others: 1
# >> node 47 (sf:12 bw:125 freq:8.600068e+08)
# no frequency coll
# CHECK node 48 (sf:12 bw:125 freq:8.600026e+08) others: 2
# >> node 47 (sf:12 bw:125 freq:8.600068e+08)
# no frequency coll
# >> node 34 (sf:12 bw:125 freq:8.600019e+08)
# no frequency coll
# CHECK node 1 (sf:12 bw:125 freq:8.600062e+08) others: 1
# >> node 18 (sf:12 bw:125 freq:8.600036e+08)
# no frequency coll
# CHECK node 57 (sf:12 bw:125 freq:8.600062e+08) others: 1
# >> node 14 (sf:12 bw:125 freq:8.600064e+08)
# no frequency coll
# CHECK node 42 (sf:12 bw:125 freq:8.600072e+08) others: 1
# >> node 20 (sf:12 bw:125 freq:8.600006e+08)
# no frequency coll
# CHECK node 50 (sf:12 bw:125 freq:8.600080e+08) others: 1
# >> node 2 (sf:12 bw:125 freq:8.600024e+08)
# no frequency coll
# CHECK node 58 (sf:12 bw:125 freq:8.600041e+08) others: 2
# >> node 2 (sf:12 bw:125 freq:8.600024e+08)
# no frequency coll
# >> node 50 (sf:12 bw:125 freq:8.600080e+08)
# no frequency coll
# CHECK node 64 (sf:12 bw:125 freq:8.600034e+08) others: 1
# >> node 66 (sf:12 bw:125 freq:8.600022e+08)
# no frequency coll
# CHECK node 52 (sf:12 bw:125 freq:8.600022e+08) others: 1
# >> node 0 (sf:12 bw:125 freq:8.600029e+08)
# no frequency coll
# CHECK node 46 (sf:12 bw:125 freq:8.600036e+08) others: 1
# >> node 21 (sf:12 bw:125 freq:8.600065e+08)
# no frequency coll
# CHECK node 39 (sf:12 bw:125 freq:8.600056e+08) others: 1
# >> node 25 (sf:12 bw:125 freq:8.600045e+08)
# no frequency coll
# CHECK node 58 (sf:12 bw:125 freq:8.600041e+08) others: 1
# >> node 37 (sf:12 bw:125 freq:8.600080e+08)
# no frequency coll
# CHECK node 27 (sf:12 bw:125 freq:8.600040e+08) others: 1
# >> node 20 (sf:12 bw:125 freq:8.600006e+08)
# no frequency coll
# CHECK node 0 (sf:12 bw:125 freq:8.600029e+08) others: 1
# >> node 10 (sf:12 bw:125 freq:8.600018e+08)
# no frequency coll
# CHECK node 50 (sf:12 bw:125 freq:8.600080e+08) others: 1
# >> node 29 (sf:12 bw:125 freq:8.600020e+08)
# no frequency coll
# CHECK node 23 (sf:12 bw:125 freq:8.600001e+08) others: 1
# >> node 51 (sf:12 bw:125 freq:8.600025e+08)
# no frequency coll
# CHECK node 33 (sf:12 bw:125 freq:8.600066e+08) others: 1
# >> node 52 (sf:12 bw:125 freq:8.600022e+08)
# no frequency coll
# CHECK node 61 (sf:12 bw:125 freq:8.600030e+08) others: 1
# >> node 33 (sf:12 bw:125 freq:8.600066e+08)
# no frequency coll
# CHECK node 65 (sf:12 bw:125 freq:8.600050e+08) others: 1
# >> node 47 (sf:12 bw:125 freq:8.600068e+08)
# no frequency coll
# CHECK node 57 (sf:12 bw:125 freq:8.600062e+08) others: 1
# >> node 31 (sf:12 bw:125 freq:8.600008e+08)
# no frequency coll
# CHECK node 23 (sf:12 bw:125 freq:8.600001e+08) others: 1
# >> node 14 (sf:12 bw:125 freq:8.600064e+08)
# no frequency coll
# CHECK node 69 (sf:12 bw:125 freq:8.600075e+08) others: 1
# >> node 59 (sf:12 bw:125 freq:8.600066e+08)
# no frequency coll
# CHECK node 0 (sf:12 bw:125 freq:8.600029e+08) others: 1
# >> node 10 (sf:12 bw:125 freq:8.600018e+08)
# no frequency coll
# CHECK node 1 (sf:12 bw:125 freq:8.600062e+08) others: 1
# >> node 50 (sf:12 bw:125 freq:8.600080e+08)
# no frequency coll
# CHECK node 3 (sf:12 bw:125 freq:8.600015e+08) others: 1
# >> node 44 (sf:12 bw:125 freq:8.600012e+08)
# no frequency coll
# CHECK node 46 (sf:12 bw:125 freq:8.600036e+08) others: 2
# >> node 44 (sf:12 bw:125 freq:8.600012e+08)
# no frequency coll
# >> node 3 (sf:12 bw:125 freq:8.600015e+08)
# no frequency coll
# CHECK node 13 (sf:12 bw:125 freq:8.600066e+08) others: 1
# >> node 34 (sf:12 bw:125 freq:8.600019e+08)
# no frequency coll
# CHECK node 60 (sf:12 bw:125 freq:8.600001e+08) others: 1
# >> node 31 (sf:12 bw:125 freq:8.600008e+08)
# no frequency coll
# CHECK node 44 (sf:12 bw:125 freq:8.600012e+08) others: 1
# >> node 21 (sf:12 bw:125 freq:8.600065e+08)
# no frequency coll
# CHECK node 57 (sf:12 bw:125 freq:8.600062e+08) others: 2
# >> node 21 (sf:12 bw:125 freq:8.600065e+08)
# no frequency coll
# >> node 44 (sf:12 bw:125 freq:8.600012e+08)
# no frequency coll
# CHECK node 69 (sf:12 bw:125 freq:8.600075e+08) others: 1
# >> node 11 (sf:12 bw:125 freq:8.600058e+08)
# no frequency coll
# CHECK node 0 (sf:12 bw:125 freq:8.600029e+08) others: 1
# >> node 33 (sf:12 bw:125 freq:8.600066e+08)
# no frequency coll
# CHECK node 43 (sf:12 bw:125 freq:8.600036e+08) others: 1
# >> node 47 (sf:12 bw:125 freq:8.600068e+08)
# no frequency coll
# CHECK node 69 (sf:12 bw:125 freq:8.600075e+08) others: 1
# >> node 0 (sf:12 bw:125 freq:8.600029e+08)
# no frequency coll
# CHECK node 48 (sf:12 bw:125 freq:8.600026e+08) others: 1
# >> node 69 (sf:12 bw:125 freq:8.600075e+08)
# no frequency coll
# CHECK node 65 (sf:12 bw:125 freq:8.600050e+08) others: 1
# >> node 50 (sf:12 bw:125 freq:8.600080e+08)
# no frequency coll
# CHECK node 20 (sf:12 bw:125 freq:8.600006e+08) others: 1
# >> node 65 (sf:12 bw:125 freq:8.600050e+08)
# no frequency coll
# CHECK node 48 (sf:12 bw:125 freq:8.600026e+08) others: 1
# >> node 7 (sf:12 bw:125 freq:8.600034e+08)
# no frequency coll
# CHECK node 29 (sf:12 bw:125 freq:8.600020e+08) others: 1
# >> node 4 (sf:12 bw:125 freq:8.600064e+08)
# no frequency coll
# CHECK node 58 (sf:12 bw:125 freq:8.600041e+08) others: 1
# >> node 69 (sf:12 bw:125 freq:8.600075e+08)
# no frequency coll
# CHECK node 39 (sf:12 bw:125 freq:8.600056e+08) others: 1
# >> node 9 (sf:12 bw:125 freq:8.600079e+08)
# no frequency coll
# CHECK node 19 (sf:12 bw:125 freq:8.600034e+08) others: 1
# >> node 32 (sf:12 bw:125 freq:8.600064e+08)
# no frequency coll
# CHECK node 2 (sf:12 bw:125 freq:8.600024e+08) others: 1
# >> node 21 (sf:12 bw:125 freq:8.600065e+08)
# no frequency coll
# CHECK node 39 (sf:12 bw:125 freq:8.600056e+08) others: 1
# >> node 9 (sf:12 bw:125 freq:8.600079e+08)
# no frequency coll
# CHECK node 10 (sf:12 bw:125 freq:8.600018e+08) others: 1
# >> node 46 (sf:12 bw:125 freq:8.600036e+08)
# no frequency coll
# CHECK node 63 (sf:12 bw:125 freq:8.600005e+08) others: 1
# >> node 10 (sf:12 bw:125 freq:8.600018e+08)
# no frequency coll
# CHECK node 58 (sf:12 bw:125 freq:8.600041e+08) others: 1
# >> node 9 (sf:12 bw:125 freq:8.600079e+08)
# no frequency coll
# CHECK node 38 (sf:12 bw:125 freq:8.600061e+08) others: 1
# >> node 45 (sf:12 bw:125 freq:8.600068e+08)
# ...
# >> node 61 (sf:12 bw:125 freq:8.600030e+08)
# no frequency coll
# CHECK node 5 (sf:12 bw:125 freq:8.600080e+08) others: 1
# >> node 21 (sf:12 bw:125 freq:8.600065e+08)
# no frequency coll
# CHECK node 33 (sf:12 bw:125 freq:8.600066e+08) others: 1
# >> node 54 (sf:12 bw:125 freq:8.600052e+08)
# no frequency coll
# CHECK node 49 (sf:12 bw:125 freq:8.600072e+08) others: 2
# >> node 54 (sf:12 bw:125 freq:8.600052e+08)
# no frequency coll
# >> node 33 (sf:12 bw:125 freq:8.600066e+08)
# no frequency coll
# CHECK node 28 (sf:12 bw:125 freq:8.600031e+08) others: 1
# >> node 47 (sf:12 bw:125 freq:8.600068e+08)
# no frequency coll
# CHECK node 64 (sf:12 bw:125 freq:8.600034e+08) others: 1
# >> node 28 (sf:12 bw:125 freq:8.600031e+08)
# no frequency coll
# CHECK node 38 (sf:12 bw:125 freq:8.600061e+08) others: 1
# >> node 33 (sf:12 bw:125 freq:8.600066e+08)
# no frequency coll
# CHECK node 34 (sf:12 bw:125 freq:8.600019e+08) others: 1
# >> node 27 (sf:12 bw:125 freq:8.600040e+08)
# no frequency coll
# CHECK node 57 (sf:12 bw:125 freq:8.600062e+08) others: 1
# >> node 67 (sf:12 bw:125 freq:8.600019e+08)
# no frequency coll
# CHECK node 16 (sf:12 bw:125 freq:8.600005e+08) others: 1
# >> node 44 (sf:12 bw:125 freq:8.600012e+08)
# no frequency coll
# CHECK node 18 (sf:12 bw:125 freq:8.600036e+08) others: 1
# >> node 43 (sf:12 bw:125 freq:8.600036e+08)
# frequency coll 125
# collision sf node 18 and node 43
# CHECK node 59 (sf:12 bw:125 freq:8.600066e+08) others: 1
# >> node 20 (sf:12 bw:125 freq:8.600006e+08)
# no frequency coll
# CHECK node 42 (sf:12 bw:125 freq:8.600072e+08) others: 1
# >> node 63 (sf:12 bw:125 freq:8.600005e+08)
# no frequency coll
# CHECK node 40 (sf:12 bw:125 freq:8.600040e+08) others: 1
# >> node 23 (sf:12 bw:125 freq:8.600001e+08)
# no frequency coll
# CHECK node 53 (sf:12 bw:125 freq:8.600078e+08) others: 1
# >> node 57 (sf:12 bw:125 freq:8.600062e+08)
# no frequency coll
# CHECK node 13 (sf:12 bw:125 freq:8.600066e+08) others: 1
# >> node 10 (sf:12 bw:125 freq:8.600018e+08)
# no frequency coll
# CHECK node 4 (sf:12 bw:125 freq:8.600064e+08) others: 1
# >> node 26 (sf:12 bw:125 freq:8.600080e+08)
# no frequency coll
# CHECK node 50 (sf:12 bw:125 freq:8.600080e+08) others: 2
# >> node 26 (sf:12 bw:125 freq:8.600080e+08)
# frequency coll 125
# collision sf node 50 and node 26
# >> node 4 (sf:12 bw:125 freq:8.600064e+08)
# no frequency coll
# CHECK node 8 (sf:12 bw:125 freq:8.600068e+08) others: 1
# >> node 56 (sf:12 bw:125 freq:8.600019e+08)
# no frequency coll
# CHECK node 24 (sf:12 bw:125 freq:8.600045e+08) others: 1
# >> node 3 (sf:12 bw:125 freq:8.600015e+08)
# no frequency coll
# CHECK node 51 (sf:12 bw:125 freq:8.600025e+08) others: 1
# >> node 15 (sf:12 bw:125 freq:8.600024e+08)
# no frequency coll
# CHECK node 14 (sf:12 bw:125 freq:8.600064e+08) others: 1
# >> node 67 (sf:12 bw:125 freq:8.600019e+08)
# no frequency coll
# CHECK node 24 (sf:12 bw:125 freq:8.600045e+08) others: 1
# >> node 6 (sf:12 bw:125 freq:8.600065e+08)
# no frequency coll
# CHECK node 54 (sf:12 bw:125 freq:8.600052e+08) others: 1
# >> node 57 (sf:12 bw:125 freq:8.600062e+08)
# no frequency coll
# CHECK node 27 (sf:12 bw:125 freq:8.600040e+08) others: 1
# >> node 5 (sf:12 bw:125 freq:8.600080e+08)
# no frequency coll
# CHECK node 46 (sf:12 bw:125 freq:8.600036e+08) others: 1
# >> node 58 (sf:12 bw:125 freq:8.600041e+08)
# no frequency coll
# CHECK node 15 (sf:12 bw:125 freq:8.600024e+08) others: 1
# >> node 54 (sf:12 bw:125 freq:8.600052e+08)
# no frequency coll
# CHECK node 40 (sf:12 bw:125 freq:8.600040e+08) others: 1
# >> node 27 (sf:12 bw:125 freq:8.600040e+08)
# frequency coll 125
# collision sf node 40 and node 27
# CHECK node 4 (sf:12 bw:125 freq:8.600064e+08) others: 1
# >> node 33 (sf:12 bw:125 freq:8.600066e+08)
# no frequency coll
# CHECK node 59 (sf:12 bw:125 freq:8.600066e+08) others: 1
# >> node 43 (sf:12 bw:125 freq:8.600036e+08)
# no frequency coll
# CHECK node 41 (sf:12 bw:125 freq:8.600045e+08) others: 1
# >> node 54 (sf:12 bw:125 freq:8.600052e+08)
# no frequency coll
# CHECK node 35 (sf:12 bw:125 freq:8.600034e+08) others: 1
# >> node 16 (sf:12 bw:125 freq:8.600005e+08)
# no frequency coll
# CHECK node 10 (sf:12 bw:125 freq:8.600018e+08) others: 1
# >> node 69 (sf:12 bw:125 freq:8.600075e+08)
# no frequency coll
# CHECK node 25 (sf:12 bw:125 freq:8.600045e+08) others: 1
# >> node 55 (sf:12 bw:125 freq:8.600009e+08)
# no frequency coll
# CHECK node 26 (sf:12 bw:125 freq:8.600080e+08) others: 1
# >> node 35 (sf:12 bw:125 freq:8.600034e+08)
# no frequency coll
# CHECK node 19 (sf:12 bw:125 freq:8.600034e+08) others: 1
# >> node 24 (sf:12 bw:125 freq:8.600045e+08)
# no frequency coll
# CHECK node 50 (sf:12 bw:125 freq:8.600080e+08) others: 1
# >> node 25 (sf:12 bw:125 freq:8.600045e+08)
# no frequency coll
# CHECK node 29 (sf:12 bw:125 freq:8.600020e+08) others: 1
# >> node 17 (sf:12 bw:125 freq:8.600058e+08)
# no frequency coll
# CHECK node 40 (sf:12 bw:125 freq:8.600040e+08) others: 1
# >> node 69 (sf:12 bw:125 freq:8.600075e+08)
# no frequency coll
# CHECK node 69 (sf:12 bw:125 freq:8.600075e+08) others: 1
# >> node 41 (sf:12 bw:125 freq:8.600045e+08)
# no frequency coll
# CHECK node 38 (sf:12 bw:125 freq:8.600061e+08) others: 1
# >> node 3 (sf:12 bw:125 freq:8.600015e+08)
# no frequency coll
# CHECK node 36 (sf:12 bw:125 freq:8.600061e+08) others: 2
# >> node 3 (sf:12 bw:125 freq:8.600015e+08)
# no frequency coll
# >> node 38 (sf:12 bw:125 freq:8.600061e+08)
# frequency coll 125
# collision sf node 36 and node 38
# CHECK node 41 (sf:12 bw:125 freq:8.600045e+08) others: 1
# >> node 62 (sf:12 bw:125 freq:8.600054e+08)
# no frequency coll
# CHECK node 38 (sf:12 bw:125 freq:8.600061e+08) others: 1
# >> node 53 (sf:12 bw:125 freq:8.600078e+08)
# no frequency coll
# CHECK node 10 (sf:12 bw:125 freq:8.600018e+08) others: 1
# >> node 39 (sf:12 bw:125 freq:8.600056e+08)
# no frequency coll
# CHECK node 60 (sf:12 bw:125 freq:8.600001e+08) others: 1
# >> node 3 (sf:12 bw:125 freq:8.600015e+08)
# no frequency coll
# CHECK node 24 (sf:12 bw:125 freq:8.600045e+08) others: 1
# >> node 41 (sf:12 bw:125 freq:8.600045e+08)
# frequency coll 125
# collision sf node 24 and node 41
# CHECK node 25 (sf:12 bw:125 freq:8.600045e+08) others: 1
# >> node 36 (sf:12 bw:125 freq:8.600061e+08)
# no frequency coll
# CHECK node 17 (sf:12 bw:125 freq:8.600058e+08) others: 1
# >> node 7 (sf:12 bw:125 freq:8.600034e+08)
# no frequency coll
# CHECK node 50 (sf:12 bw:125 freq:8.600080e+08) others: 1
# >> node 8 (sf:12 bw:125 freq:8.600068e+08)
# no frequency coll
# CHECK node 30 (sf:12 bw:125 freq:8.600055e+08) others: 1
# >> node 5 (sf:12 bw:125 freq:8.600080e+08)
# no frequency coll
# CHECK node 14 (sf:12 bw:125 freq:8.600064e+08) others: 1
# >> node 7 (sf:12 bw:125 freq:8.600034e+08)
# no frequency coll
# CHECK node 44 (sf:12 bw:125 freq:8.600012e+08) others: 1
# >> node 39 (sf:12 bw:125 freq:8.600056e+08)
# no frequency coll
# CHECK node 48 (sf:12 bw:125 freq:8.600026e+08) others: 1
# >> node 22 (sf:12 bw:125 freq:8.600016e+08)
# no frequency coll
# CHECK node 5 (sf:12 bw:125 freq:8.600080e+08) others: 1
# >> node 9 (sf:12 bw:125 freq:8.600079e+08)
# no frequency coll
# CHECK node 9 (sf:12 bw:125 freq:8.600079e+08) others: 1
# >> node 58 (sf:12 bw:125 freq:8.600041e+08)
# no frequency coll
# CHECK node 11 (sf:12 bw:125 freq:8.600058e+08) others: 1
# >> node 9 (sf:12 bw:125 freq:8.600079e+08)
# no frequency coll
# CHECK node 41 (sf:12 bw:125 freq:8.600045e+08) others: 1
# >> node 40 (sf:12 bw:125 freq:8.600040e+08)
# no frequency coll
# CHECK node 13 (sf:12 bw:125 freq:8.600066e+08) others: 1
# >> node 14 (sf:12 bw:125 freq:8.600064e+08)
# no frequency coll
# CHECK node 25 (sf:12 bw:125 freq:8.600045e+08) others: 1
# >> node 63 (sf:12 bw:125 freq:8.600005e+08)
# no frequency coll
# CHECK node 54 (sf:12 bw:125 freq:8.600052e+08) others: 1
# >> node 31 (sf:12 bw:125 freq:8.600008e+08)
# no frequency coll
# CHECK node 30 (sf:12 bw:125 freq:8.600055e+08) others: 2
# >> node 31 (sf:12 bw:125 freq:8.600008e+08)
# no frequency coll
# >> node 54 (sf:12 bw:125 freq:8.600052e+08)
# no frequency coll
# CHECK node 24 (sf:12 bw:125 freq:8.600045e+08) others: 1
# >> node 36 (sf:12 bw:125 freq:8.600061e+08)
# no frequency coll
# CHECK node 20 (sf:12 bw:125 freq:8.600006e+08) others: 1
# >> node 51 (sf:12 bw:125 freq:8.600025e+08)
# no frequency coll
# CHECK node 59 (sf:12 bw:125 freq:8.600066e+08) others: 1
# >> node 66 (sf:12 bw:125 freq:8.600022e+08)
# no frequency coll
# CHECK node 57 (sf:12 bw:125 freq:8.600062e+08) others: 1
# >> node 33 (sf:12 bw:125 freq:8.600066e+08)
# no frequency coll
# CHECK node 47 (sf:12 bw:125 freq:8.600068e+08) others: 1
# >> node 57 (sf:12 bw:125 freq:8.600062e+08)
# no frequency coll
# CHECK node 64 (sf:12 bw:125 freq:8.600034e+08) others: 1
# >> node 4 (sf:12 bw:125 freq:8.600064e+08)
# no frequency coll
# CHECK node 9 (sf:12 bw:125 freq:8.600079e+08) others: 1
# >> node 42 (sf:12 bw:125 freq:8.600072e+08)
# no frequency coll
# CHECK node 8 (sf:12 bw:125 freq:8.600068e+08) others: 1
# >> node 36 (sf:12 bw:125 freq:8.600061e+08)
# no frequency coll
# CHECK node 37 (sf:12 bw:125 freq:8.600080e+08) others: 1
# >> node 36 (sf:12 bw:125 freq:8.600061e+08)
# no frequency coll
# CHECK node 14 (sf:12 bw:125 freq:8.600064e+08) others: 1
# >> node 50 (sf:12 bw:125 freq:8.600080e+08)
# no frequency coll
# CHECK node 58 (sf:12 bw:125 freq:8.600041e+08) others: 1
# >> node 20 (sf:12 bw:125 freq:8.600006e+08)
# no frequency coll
# CHECK node 23 (sf:12 bw:125 freq:8.600001e+08) others: 1
# >> node 51 (sf:12 bw:125 freq:8.600025e+08)
# no frequency coll
# CHECK node 2 (sf:12 bw:125 freq:8.600024e+08) others: 1
# >> node 54 (sf:12 bw:125 freq:8.600052e+08)
# no frequency coll
# CHECK node 33 (sf:12 bw:125 freq:8.600066e+08) others: 1
# >> node 9 (sf:12 bw:125 freq:8.600079e+08)
# no frequency coll
# CHECK node 64 (sf:12 bw:125 freq:8.600034e+08) others: 1
# >> node 7 (sf:12 bw:125 freq:8.600034e+08)
# frequency coll 125
# collision sf node 64 and node 7
# CHECK node 66 (sf:12 bw:125 freq:8.600022e+08) others: 1
# >> node 53 (sf:12 bw:125 freq:8.600078e+08)
# no frequency coll
# CHECK node 11 (sf:12 bw:125 freq:8.600058e+08) others: 1
# >> node 41 (sf:12 bw:125 freq:8.600045e+08)
# no frequency coll
# CHECK node 35 (sf:12 bw:125 freq:8.600034e+08) others: 1
# >> node 18 (sf:12 bw:125 freq:8.600036e+08)
# no frequency coll
# CHECK node 67 (sf:12 bw:125 freq:8.600019e+08) others: 1
# >> node 32 (sf:12 bw:125 freq:8.600064e+08)
# no frequency coll
# CHECK node 1 (sf:12 bw:125 freq:8.600062e+08) others: 1
# >> node 67 (sf:12 bw:125 freq:8.600019e+08)
# no frequency coll
# CHECK node 40 (sf:12 bw:125 freq:8.600040e+08) others: 1
# >> node 63 (sf:12 bw:125 freq:8.600005e+08)
# no frequency coll
# CHECK node 34 (sf:12 bw:125 freq:8.600019e+08) others: 1
# >> node 5 (sf:12 bw:125 freq:8.600080e+08)
# no frequency coll
# CHECK node 31 (sf:12 bw:125 freq:8.600008e+08) others: 1
# >> node 55 (sf:12 bw:125 freq:8.600009e+08)
# no frequency coll
# CHECK node 43 (sf:12 bw:125 freq:8.600036e+08) others: 1
# >> node 63 (sf:12 bw:125 freq:8.600005e+08)
# no frequency coll
# CHECK node 61 (sf:12 bw:125 freq:8.600030e+08) others: 1
# >> node 64 (sf:12 bw:125 freq:8.600034e+08)
# no frequency coll
# CHECK node 38 (sf:12 bw:125 freq:8.600061e+08) others: 1
# >> node 26 (sf:12 bw:125 freq:8.600080e+08)
# no frequency coll
# CHECK node 32 (sf:12 bw:125 freq:8.600064e+08) others: 1
# >> node 55 (sf:12 bw:125 freq:8.600009e+08)
# no frequency coll
# CHECK node 9 (sf:12 bw:125 freq:8.600079e+08) others: 1
# >> node 2 (sf:12 bw:125 freq:8.600024e+08)
# no frequency coll
# CHECK node 6 (sf:12 bw:125 freq:8.600065e+08) others: 1
# >> node 48 (sf:12 bw:125 freq:8.600026e+08)
# no frequency coll
# CHECK node 21 (sf:12 bw:125 freq:8.600065e+08) others: 1
# >> node 67 (sf:12 bw:125 freq:8.600019e+08)
# no frequency coll
# CHECK node 30 (sf:12 bw:125 freq:8.600055e+08) others: 1
# >> node 45 (sf:12 bw:125 freq:8.600068e+08)
# no frequency coll
# CHECK node 64 (sf:12 bw:125 freq:8.600034e+08) others: 1
# >> node 32 (sf:12 bw:125 freq:8.600064e+08)
# no frequency coll
# CHECK node 36 (sf:12 bw:125 freq:8.600061e+08) others: 1
# >> node 34 (sf:12 bw:125 freq:8.600019e+08)
# no frequency coll
# CHECK node 57 (sf:12 bw:125 freq:8.600062e+08) others: 1
# >> node 46 (sf:12 bw:125 freq:8.600036e+08)
# no frequency coll
# CHECK node 51 (sf:12 bw:125 freq:8.600025e+08) others: 1
# >> node 26 (sf:12 bw:125 freq:8.600080e+08)
# no frequency coll
# CHECK node 33 (sf:12 bw:125 freq:8.600066e+08) others: 1
# >> node 4 (sf:12 bw:125 freq:8.600064e+08)
# no frequency coll
# CHECK node 54 (sf:12 bw:125 freq:8.600052e+08) others: 1
# >> node 68 (sf:12 bw:125 freq:8.600014e+08)
# no frequency coll
# CHECK node 13 (sf:12 bw:125 freq:8.600066e+08) others: 1
# >> node 62 (sf:12 bw:125 freq:8.600054e+08)
# no frequency coll
# CHECK node 11 (sf:12 bw:125 freq:8.600058e+08) others: 1
# >> node 31 (sf:12 bw:125 freq:8.600008e+08)
# no frequency coll
# CHECK node 4 (sf:12 bw:125 freq:8.600064e+08) others: 1
# >> node 12 (sf:12 bw:125 freq:8.600024e+08)
# no frequency coll
# CHECK node 64 (sf:12 bw:125 freq:8.600034e+08) others: 1
# >> node 6 (sf:12 bw:125 freq:8.600065e+08)
# no frequency coll
# CHECK node 1 (sf:12 bw:125 freq:8.600062e+08) others: 1
# >> node 41 (sf:12 bw:125 freq:8.600045e+08)
# no frequency coll
# CHECK node 21 (sf:12 bw:125 freq:8.600065e+08) others: 1
# >> node 30 (sf:12 bw:125 freq:8.600055e+08)
# no frequency coll
# CHECK node 29 (sf:12 bw:125 freq:8.600020e+08) others: 1
# >> node 38 (sf:12 bw:125 freq:8.600061e+08)
# no frequency coll
# CHECK node 20 (sf:12 bw:125 freq:8.600006e+08) others: 1
# >> node 39 (sf:12 bw:125 freq:8.600056e+08)
# no frequency coll
# CHECK node 21 (sf:12 bw:125 freq:8.600065e+08) others: 1
# >> node 44 (sf:12 bw:125 freq:8.600012e+08)
# no frequency coll
# CHECK node 57 (sf:12 bw:125 freq:8.600062e+08) others: 1
# >> node 40 (sf:12 bw:125 freq:8.600040e+08)
# no frequency coll
# CHECK node 48 (sf:12 bw:125 freq:8.600026e+08) others: 1
# >> node 36 (sf:12 bw:125 freq:8.600061e+08)
# no frequency coll
# CHECK node 27 (sf:12 bw:125 freq:8.600040e+08) others: 1
# >> node 46 (sf:12 bw:125 freq:8.600036e+08)
# no frequency coll
# CHECK node 2 (sf:12 bw:125 freq:8.600024e+08) others: 1
# >> node 12 (sf:12 bw:125 freq:8.600024e+08)
# frequency coll 125
# collision sf node 2 and node 12
# CHECK node 43 (sf:12 bw:125 freq:8.600036e+08) others: 1
# >> node 24 (sf:12 bw:125 freq:8.600045e+08)
# no frequency coll
# CHECK node 53 (sf:12 bw:125 freq:8.600078e+08) others: 1
# >> node 68 (sf:12 bw:125 freq:8.600014e+08)
# no frequency coll
# CHECK node 51 (sf:12 bw:125 freq:8.600025e+08) others: 1
# >> node 27 (sf:12 bw:125 freq:8.600040e+08)
# no frequency coll
# CHECK node 68 (sf:12 bw:125 freq:8.600014e+08) others: 1
# >> node 53 (sf:12 bw:125 freq:8.600078e+08)
# no frequency coll
# CHECK node 31 (sf:12 bw:125 freq:8.600008e+08) others: 1
# >> node 38 (sf:12 bw:125 freq:8.600061e+08)
# no frequency coll
# CHECK node 50 (sf:12 bw:125 freq:8.600080e+08) others: 1
# >> node 17 (sf:12 bw:125 freq:8.600058e+08)
# no frequency coll
# CHECK node 27 (sf:12 bw:125 freq:8.600040e+08) others: 1
# >> node 33 (sf:12 bw:125 freq:8.600066e+08)
# no frequency coll
# CHECK node 9 (sf:12 bw:125 freq:8.600079e+08) others: 1
# >> node 46 (sf:12 bw:125 freq:8.600036e+08)
# no frequency coll
# CHECK node 10 (sf:12 bw:125 freq:8.600018e+08) others: 1
# >> node 44 (sf:12 bw:125 freq:8.600012e+08)
# no frequency coll
# CHECK node 22 (sf:12 bw:125 freq:8.600016e+08) others: 1
# >> node 33 (sf:12 bw:125 freq:8.600066e+08)
# no frequency coll
# CHECK node 1 (sf:12 bw:125 freq:8.600062e+08) others: 1
# >> node 21 (sf:12 bw:125 freq:8.600065e+08)
# no frequency coll
# CHECK node 34 (sf:12 bw:125 freq:8.600019e+08) others: 1
# >> node 1 (sf:12 bw:125 freq:8.600062e+08)
# no frequency coll
# CHECK node 13 (sf:12 bw:125 freq:8.600066e+08) others: 1
# >> node 23 (sf:12 bw:125 freq:8.600001e+08)
# no frequency coll
# CHECK node 38 (sf:12 bw:125 freq:8.600061e+08) others: 1
# >> node 35 (sf:12 bw:125 freq:8.600034e+08)
# no frequency coll
# CHECK node 10 (sf:12 bw:125 freq:8.600018e+08) others: 1
# >> node 44 (sf:12 bw:125 freq:8.600012e+08)
# no frequency coll
# CHECK node 42 (sf:12 bw:125 freq:8.600072e+08) others: 1
# >> node 50 (sf:12 bw:125 freq:8.600080e+08)
# no frequency coll
# ----------------------------
# ----------------------------
# nrCollisions  167
# energy (in J):  8170.34330112
# sent packets:  46930
# collisions:  167
# received packets:  46759
# processed packets:  46926
# lost packets:  4
# Total time to fly:  61896540.16
# DER: 0.99644150863
# DER method 2: 0.996356275304
# ----------------------------
# ----------------------------

# %%
sensi[12-7,1]
# Out:
# -133.25
